# %%
# !pip install pyoptimus

# %%
# !pip install py-dateinfer url_parser
# !pip install -U pandas
# !pip install python-libmagic

# %%
# !mkdir /content/x
# !git clone https://github.com/PacktPublishing/Data-Processing-with-Optimus.git /content/x
# %cd /content

# %%
# !mv /content/x/Chapter01/foo.txt .
# !mv /content/x/Chapter01/path/to/file.csv .

# %%
import pandas as pd

pd.read_csv('file.csv')
# Out:
#         name                 function
# 0    optimus                   Leader
# 1  bumblebee                Espionage
# 2      eject  Electronic surveillance
# 3   megatron                  NEMESIS

# %%
from optimus import Optimus

# %%
op = Optimus('pandas')

# %% [markdown]
# ### Basics

# %%
# df = op.load.file('file.csv')
df = op.load.csv('file.csv')
df
# Out:
# name        function
# (object)    (object)
# ----------  -----------------------
# optimus     Leader
# bumblebee   Espionage
# eject       Electronic surveillance
# megatron    NEMESIS

# %%
df = df.cols.rename("function", "job")
df
# Out:
# name        job
# (object)    (object)
# ----------  -----------------------
# optimus     Leader
# bumblebee   Espionage
# eject       Electronic surveillance
# megatron    NEMESIS

# %%
df = df.cols.upper("name").cols.lower("job")
df
# Out:
# name        job
# (object)    (object)
# ----------  -----------------------
# OPTIMUS     leader
# BUMBLEBEE   espionage
# EJECT       electronic surveillance
# MEGATRON    nemesis

# %%
df.cols.drop("name")
# Out:
# job
# (object)
# -----------------------
# leader
# espionage
# electronic surveillance
# nemesis

# %%
df.rows.drop(df["name"]=="MEGATRON")
# Out:
# name        job
# (object)    (object)
# ----------  -----------------------
# OPTIMUS     leader
# BUMBLEBEE   espionage
# EJECT       electronic surveillance

# %%
df.display()
# Out:
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 4 of 4 rows / 2 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <span class="optimus_table_container" style="display: inline-flex; flex-direction: column;">
#     <table class="optimus_table" style="font-size: 12px; margin: 0;">
#         <thead style="font-family: sans-serif; border-bottom: 1px solid currentColor;">
#         <tr>
#
#             <th style="">
#                 <div class="column_name" style="font-size: 1.2em;">name</div>
#                 <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#
#             </th>
#
#             <th style="">
#                 <div class="column_name" style="font-size: 1.2em;">job</div>
#                 <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (object)</div>
#
#             </th>
#
#         </tr>
#
#         </thead>
#         <tbody style="font-family: monospace;">
#
#         <tr>
#
#             <td style="border: 0px; ">
#                 <div title="OPTIMUS" style="min-height: 14px;">
#
#                     OPTIMUS
#
#                 </div>
#             </td>
#
#             <td style="border: 0px; ">
#                 <div title="leader" style="min-height: 14px;">
#
#                     leader
#
#                 </div>
#             </td>
#
#         </tr>
#
#         <tr>
#
#             <td style="border: 0px; ">
#                 <div title="BUMBLEBEE" style="min-height: 14px;">
#
#                     BUMBLEBEE
#
#                 </div>
#             </td>
#
#             <td style="border: 0px; ">
#                 <div title="espionage" style="min-height: 14px;">
#
#                     espionage
#
#                 </div>
#             </td>
#
#         </tr>
#
#         <tr>
#
#             <td style="border: 0px; ">
#                 <div title="EJECT" style="min-height: 14px;">
#
#                     EJECT
#
#                 </div>
#             </td>
#
#             <td style="border: 0px; ">
#                 <div title="electronic&#8901;surveillance" style="min-height: 14px;">
#
#                     electronic&#8901;surveillance
#
#                 </div>
#             </td>
#
#         </tr>
#
#         <tr>
#
#             <td style="border: 0px; ">
#                 <div title="MEGATRON" style="min-height: 14px;">
#
#                     MEGATRON
#
#                 </div>
#             </td>
#
#             <td style="border: 0px; ">
#                 <div title="nemesis" style="min-height: 14px;">
#
#                     nemesis
#
#                 </div>
#             </td>
#
#         </tr>
#
#         </tbody>
#     </table>
#     <div class="optimus_table_border" style="background-color: currentColor; opacity: 0.2; height: 1px; width: 100%;"></div>
# </span>
#
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 4 of 4 rows / 2 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) &lt;class &#39;optimus.engines.pandas.dataframe.PandasDataFrame&#39;&gt;</div>

# %%
df.cols.capitalize("name", output_cols="cap_name")
# Out:
# name        cap_name    job
# (object)    (object)    (object)
# ----------  ----------  -----------------------
# OPTIMUS     Optimus     leader
# BUMBLEBEE   Bumblebee   espionage
# EJECT       Eject       electronic surveillance
# MEGATRON    Megatron    nemesis

# %%
df.profile(bins=10)
# Out:
# {'columns': {'name': {'stats': {'match': 4,
#     'missing': 0,
#     'mismatch': 0,
#     'inferred_type': {'data_type': 'str', 'categorical': True},
#     'frequency': [{'value': 'BUMBLEBEE', 'count': 1},
#      {'value': 'EJECT', 'count': 1},
#      {'value': 'MEGATRON', 'count': 1},
#      {'value': 'OPTIMUS', 'count': 1}],
#     'count_uniques': 4},
#    'data_type': 'object'},
#   'job': {'stats': {'match': 4,
#     'missing': 0,
#     'mismatch': 0,
#     'inferred_type': {'data_type': 'str', 'categorical': True},
#     'frequency': [{'value': 'electronic surveillance', 'count': 1},
#      {'value': 'espionage', 'count': 1},
#      {'value': 'leader', 'count': 1},
#      {'value': 'nemesis', 'count': 1}],
#     'count_uniques': 4},
#    'data_type': 'object'}},
#  'name': 'file.csv',
#  'file_name': ['file.csv'],
#  'summary': {'cols_count': 2,
#   'rows_count': 4,
#   'data_types_list': ['object'],
#   'total_count_data_types': 1,
#   'missing_count': 0,
#   'p_missing': 0.0}}

# %%
dfn = op.create.dataframe({"A":["1",2,"4","!",None]})
dfn
# Out:
# A
# (object)
# ----------
# 1
# 2
# 4
# !

# %%
dfn.cols.min("A"), dfn.cols.max("A")
# Out:
# (1.0, 4.0)

# %%
df = op.create.dataframe({
    "A":["1",2,"4","!",None],
    "B":["Optimus","Bumblebee", "Eject", None, None]
})  

df.profile(bins=10)
# Out:
# {'columns': {'A': {'stats': {'match': 0,
#     'missing': 1,
#     'mismatch': 4,
#     'inferred_type': {'data_type': 'int', 'categorical': True},
#     'frequency': [{'value': 2, 'count': 1},
#      {'value': '!', 'count': 1},
#      {'value': '1', 'count': 1},
#      {'value': '4', 'count': 1}],
#     'count_uniques': 4},
#    'data_type': 'object'},
#   'B': {'stats': {'match': 3,
#     'missing': 2,
#     'mismatch': 0,
#     'inferred_type': {'data_type': 'str', 'categorical': True},
#     'frequency': [{'value': 'Bumblebee', 'count': 1},
#      {'value': 'Eject', 'count': 1},
#      {'value': 'Optimus', 'count': 1}],
#     'count_uniques': 3},
#    'data_type': 'object'}},
#  'name': None,
#  'file_name': None,
#  'summary': {'cols_count': 2,
#   'rows_count': 5,
#   'data_types_list': ['object'],
#   'total_count_data_types': 1,
#   'missing_count': 0,
#   'p_missing': 0.0}}

# %%
df.columns_sample("*")
# Out:
# {'columns': [{'title': 'A'}, {'title': 'B'}],
#  'value': [['1', 'Optimus'],
#   [2, 'Bumblebee'],
#   ['4', 'Eject'],
#   ['!', None],
#   [None, None]]}

# %%
df.execute()
# Out:
# A           B
# (object)    (object)
# ----------  ----------
# 1           Optimus
# 2           Bumblebee
# 4           Eject
# !

# %%
df = op.load.csv("foo.txt", sep=",") 
type(df.data)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
# name        function
# (object)    (object)
# ----------  -----------------------
# Optimus     leader
# Bumblebee   espionage
# eject       ELECTRONIC SURVEILLANCE

# %%
df = df.cols.upper("*") 
df.meta["transformations"]
# Out:
# {'actions': [{'name': 'upper', 'columns': 'name'},
#   {'name': 'upper', 'columns': 'function'},
#   {'name': 'set', 'columns': 'name'},
#   {'name': 'set', 'columns': 'function'}]}

# %% [markdown]
# ### Read some rows from parquet

# %% [markdown]
# Pandas still doesn't support reading few of the rows, instead of full. So we can use Optimus in this case.

# %%
import pandas as pd

df = pd.read_csv('file.csv')
df.to_parquet('file.parquet.snappy', compression='snappy')
df
# Out:
#         name                 function
# 0    optimus                   Leader
# 1  bumblebee                Espionage
# 2      eject  Electronic surveillance
# 3   megatron                  NEMESIS

# %%
pd.read_parquet('file.parquet.snappy', nrows=2)

# %%
df = op.load.parquet('file.parquet.snappy', n_rows=2)
df
# Out:
# 'load.parquet' on Pandas loads the whole dataset and then truncates it
# name        function
# (object)    (object)
# ----------  ----------
# optimus     Leader
# bumblebee   Espionage

# %% [markdown]
# ### Optimize memory

# %%
df = op.create.dataframe({ 
    "a": [1000,2000,3000,4000,5000]*10000, 
    "b": [1,2,3,4,5]*10000 
}) 
df.size()
# Out:
# 800128

# %%
df = df.optimize()
df.size()
