# %%
import os
project_name = "reco-tut-rec"; branch = "main"; account = "sparsh-ai"
project_path = os.path.join('/content', project_name)

# %%
if not os.path.exists(project_path):
    # !cp -r /content/drive/MyDrive/git_credentials/. ~
    # !pip install -U -q dvc dvc[gdrive]
    path = "/content/" + project_name; 
    # !mkdir "{path}"
    # %cd "{path}"
    # !git init
    # !git remote add origin https://github.com/"{account}"/"{project_name}".git
    # !git pull origin "{branch}"
    # !git checkout main
else:
    # %cd "{project_path}"
# Out:
# /content/reco-tut-rec
# Initialized empty Git repository in /content/reco-tut-rec/.git/
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 16 (delta 0), reused 14 (delta 0), pack-reused 0
# Unpacking objects: 100% (16/16), done.
# From https://github.com/sparsh-ai/reco-tut-rec
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Switched to a new branch 'main'

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	data/bronze/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add . && git commit -m 'commit' && git push origin "{branch}"
# Out:
# [main c3b9856] commit
#  3 files changed, 24 insertions(+)
#  create mode 100644 data/bronze/olx/.gitignore
#  create mode 100644 data/bronze/olx/df_subset_items.parquet.snappy.dvc
#  create mode 100644 data/bronze/olx/df_subset_users.parquet.snappy.dvc
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (8/8), 1000 bytes | 1000.00 KiB/s, done.
# Total 8 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/sparsh-ai/reco-tut-rec.git
#    9b4d415..c3b9856  main -> main

# %%
# !git pull --rebase origin "{branch}"

# %% [markdown]
# ---

# %%
# !rm -r /content/reco-tut-rec/data/bronze/olx/df_subset_users.parquet.snappy

# %%
# !dvc init
# !dvc remote

# %%
# !mkdir -p ./data/bronze/olx
# !dvc import -o ./data/bronze/olx/df_subset_items.parquet.snappy https://github.com/sparsh-ai/reco-data olx/v1/df_subset_items.parquet.snappy
# !dvc import -o ./data/bronze/olx/df_subset_users.parquet.snappy https://github.com/sparsh-ai/reco-data olx/v1/df_subset_users.parquet.snappy
# Out:
# Importing 'olx/v1/df_subset_items.parquet.snappy (https://github.com/sparsh-ai/reco-data)' -> 'data/bronze/olx/df_subset_items.parquet.snappy'
#   0% 0/1 [00:00<?, ?file/s{'info': ''}]Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=710796635688-iivsgbgsb6uv1fap6635dhvuei09o66c.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.appdata&access_type=offline&response_type=code&approval_prompt=force
#
# Enter verification code: 4/1AX4XfWi2iYSSNLpNxWtFh5uh4StwmCG7UDPwhgeSL1lipwNouq0-WuTfBYU
# Authentication successful.
# Transferring:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#   0%|          |587fa7e947d34af53826160c9551de     0.00/? [00:00<?,        ?B/s]
# 587fa7e947d34af53826160c9551de:   0% 0.00/69.3M [00:00<?, ?B/s{'info': ''}]
#
# To track the changes with git, run:
#
# 	git add data/bronze/olx/df_subset_items.parquet.snappy.dvc data/bronze/olx/.gitignore
# Importing 'olx/v1/df_subset_users.parquet.snappy (https://github.com/sparsh-ai/reco-data)' -> 'data/bronze/olx/df_subset_users.parquet.snappy'
#   0% 0/1 [00:00<?, ?file/s{'info': ''}]Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=710796635688-iivsgbgsb6uv1fap6635dhvuei09o66c.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.appdata&access_type=offline&response_type=code&approval_prompt=force
#
# Enter verification code: 4/1AX4XfWjXIuaQI4sNAae_E9Oq8dXWYO0AzKJ2YKg1XBSFlhdsnWloHoQ_kn0
# Authentication successful.
# Transferring:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#   0%|          |9fa3db0fe36a5ea0de11913d593833     0.00/? [00:00<?,        ?B/s]
# 9fa3db0fe36a5ea0de11913d593833:   0% 0.00/68.8M [00:00<?, ?B/s{'info': ''}]
#
# To track the changes with git, run:
#
# 	git add data/bronze/olx/df_subset_users.parquet.snappy.dvc data/bronze/olx/.gitignore

# %%
# !cd ./data/bronze/olx && dvc get https://github.com/sparsh-ai/reco-data olx/v1/df_subset_users.parquet.snappy
# Out:
#   0% df_subset_users.parquet.snappy|          |0.00/? [00:00<?,        ?B/s]Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=710796635688-iivsgbgsb6uv1fap6635dhvuei09o66c.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.appdata&access_type=offline&response_type=code&approval_prompt=force
#
# Enter verification code: 4/1AX4XfWg5-CmpO1XUGnxtQWSXfhJmMweftu0x_g1mLo2_XpaSly6fF8Nt93o
# Authentication successful.

# %%
# !make
# Out:
# echo "Hello World"
# Hello World

# %%
# !rm -r /content/reco-tut-rec/data/bronze/olx/*

# %%
# !make olx
# Out:
# mkdir -p ./data/bronze/olx
# cd ./data/bronze/olx && dvc get https://github.com/sparsh-ai/reco-data olx/v1/df_subset_items.parquet.snappy
#   0% df_subset_items.parquet.snappy|          |0.00/? [00:00<?,        ?B/s]Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=710796635688-iivsgbgsb6uv1fap6635dhvuei09o66c.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.appdata&access_type=offline&response_type=code&approval_prompt=force
#
# ERROR: interrupted by the user
# Makefile:4: recipe for target 'olx_data_ingest' failed
# make: *** [olx_data_ingest] Interrupt
# ^C

# %%
# !rm -r /content/reco-tut-rec/data/bronze/olx/df_subset_items.parquet.snappy.dGB6iEgb7KZVKeBvU7GDb7.tmp
