# %%
import os
project_name = "reco-tut-mal"; branch = "main"; account = "sparsh-ai"
project_path = os.path.join('/content', project_name)

# %%
if not os.path.exists(project_path):
    # !cp /content/drive/MyDrive/mykeys.py /content
    import mykeys
    # !rm /content/mykeys.py
    path = "/content/" + project_name; 
    # !mkdir "{path}"
    # %cd "{path}"
    import sys; sys.path.append(path)
    # !git config --global user.email "recotut@recohut.com"
    # !git config --global user.name  "reco-tut"
    # !git init
    # !git remote add origin https://"{mykeys.git_token}":x-oauth-basic@github.com/"{account}"/"{project_name}".git
    # !git pull origin "{branch}"
    # !git checkout main
else:
    # %cd "{project_path}"
# Out:
# /content/reco-tut-mal
# Initialized empty Git repository in /content/reco-tut-mal/.git/
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 13 (delta 0), reused 11 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), done.
# From https://github.com/sparsh-ai/reco-tut-mal
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Switched to a new branch 'main'

# %%
# !git pull --rebase origin main

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	code/track1_data_ingestion.py
# 	data/bronze/anime_data.csv
# 	data/silver/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add . && git commit -m 'commit' && git push origin "{branch}"
# Out:
# [main 7de160f] commit
#  3 files changed, 12 insertions(+)
#  create mode 100644 code/track1_data_ingestion.py
#  create mode 100644 data/bronze/anime_data.csv
#  create mode 100644 data/silver/anime_data.csv
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (9/9), 4.24 MiB | 10.02 MiB/s, done.
# Total 9 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/sparsh-ai/reco-tut-mal.git
#    f01d23a..7de160f  main -> main

# %%
import glob
files = sorted(glob.glob(f'/content/drive/MyDrive/Colab Notebooks/{project_name}*.ipynb'))
files

# %%
from shutil import copy
for fpath in files[1:]:
    copy(fpath, './notebooks')

# %%
# %%sh
# mkdir -p ./code/nbs
# for file in ./notebooks/*.ipynb
# do
#     jupyter nbconvert --output-dir="./code/nbs" --to python "$file"
# done

# %%
# !sudo apt-get install -qq tree

# %%
# !tree -L 3 .

# %%
# %%writefile README.md
# #
#
# ## Project structure
# ```
# .
# ├── artifacts
# ```

# %%
xproject_name = "reco-nb-stage"; xbranch = "queued"; xaccount = "recohut"
xproject_path = os.path.join('/content', xproject_name)

if not os.path.exists(xproject_path):
    # !cp /content/drive/MyDrive/mykeys.py /content
    import mykeys
    # !rm /content/mykeys.py
    path = "/content/" + xproject_name; 
    # !mkdir "{path}"
    # %cd "{path}"
    import sys; sys.path.append(path)
    # !git config --global user.email "recotut@recohut.com"
    # !git config --global user.name  "reco-tut"
    # !git init
    # !git remote add origin https://"{mykeys.git_token}":x-oauth-basic@github.com/"{xaccount}"/"{xproject_name}".git
    # !git pull origin "{xbranch}"
else:
    # %cd "{xproject_path}"

# %%
# !git checkout -b queued
# !cp $project_path/notebooks/*.ipynb ./_notebooks
# !git add . && git commit -m 'commit' && git push origin queued
