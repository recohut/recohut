# %%
# !git clone https://github.com/zoulixin93/FMCTS.git
# Out:
# Cloning into 'FMCTS'...
# remote: Enumerating objects: 38, done.
# remote: Total 38 (delta 0), reused 0 (delta 0), pack-reused 38
# Unpacking objects: 100% (38/38), done.

# %%
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (88.3 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !tree --du -h ./FMCTS
# Out:
# ./FMCTS
# ├── [5.5K]  arguments.py
# ├── [975K]  data
# │   └── [971K]  ml-100k
# │       ├── [ 18K]  cat.dat
# │       └── [949K]  rat.dat
# ├── [8.5K]  env
# │   ├── [4.2K]  env.py
# │   └── [ 234]  __init__.py
# ├── [ 30K]  function_approximation
# │   ├── [5.2K]  base.py
# │   ├── [5.1K]  cells.py
# │   ├── [  32]  __init__.py
# │   └── [ 16K]  rnn_model.py
# ├── [6.2K]  metrics
# │   ├── [   1]  __init__.py
# │   └── [2.2K]  metrics.py
# ├── [ 719]  run.sh
# ├── [ 16K]  train
# │   ├── [  36]  __init__.py
# │   ├── [6.8K]  mcts.py
# │   └── [5.6K]  train.py
# ├── [ 615]  train_file.py
# └── [ 24K]  utils
#     ├── [ 954]  argument.py
#     ├── [1.5K]  common_util.py
#     ├── [ 405]  data_processing.py
#     ├── [1.6K]  data_structure.py
#     ├── [1.2K]  decorators.py
#     ├── [ 394]  functions.py
#     ├── [ 433]  __init__.py
#     ├── [ 996]  statistical_utils.py
#     ├── [2.4K]  sync_files.py
#     ├── [ 710]  time_analyse.py
#     ├── [1.1K]  util_tensorflow.py
#     ├── [1.0K]  zlog.py
#     └── [7.4K]  zpipe.py
#
#  1.0M used in 7 directories, 29 files

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install ipdb

# %%
# %cd FMCTS
# Out:
# /content/FMCTS

# %%
# !mkdir -p saved_model

# %%
# %%writefile run.sh
#
# m100k(){
#     python ./train_file.py -model $1 -log_path ./log/ -data_name m100k \
#     -root_path ./data/ml-100k/ -rating_path rat.dat -cat_path cat.dat -item_num 1683 \
#     -user_num 944 -cat_n1_num 20 -cat_n2_num 20 -c_puct $2 -n_playout $3 -temperature $4 \
#     -update_frequency $5 -batch_size $6 -epoch $7 -memory_capacity $8 -learning_rate $9 \
#     -optimizer_name ${10} -evaluate_num ${11} -latent_factor ${12} -delete_previous ${13} \
#     -job_ports ${14} -task ${15} -evaluate_num 500
# }
#
# name="m100k_hmcts"
# (m100k $name 20.0 50 20.0 1 60 10000 1000 0.005 sgd 100 20 False [40001] train) &
# (m100k $name 20.0 50 20.0 1 60 10000 1000 0.005 sgd 100 20 False [40001] evaluate) &
# Out:
# Overwriting run.sh

# %%
# !sh run.sh
# Out:
# 1
# 1
# WARNING:tensorflow:From /content/FMCTS/arguments.py:70: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# 2021-10-21_13:04:00 saving log file in ./log/m100k_m100k_hmcts_20_0_50_20_0_evaluate_2021-10-21_13:04:00.log
# 2021-10-21_13:04:00 ######################### config for experiments #########################
# 2021-10-21_13:04:00 model	m100k_hmcts
# 2021-10-21_13:04:00 data_name	m100k
# 2021-10-21_13:04:00 log_path	./log/
# 2021-10-21_13:04:00 root_path	./data/ml-100k/
# 2021-10-21_13:04:00 rating_path	rat.dat
# 2021-10-21_13:04:00 cat_path	cat.dat
# 2021-10-21_13:04:00 item_num	1683
# 2021-10-21_13:04:00 user_num	944
# 2021-10-21_13:04:00 rating_num	5
# 2021-10-21_13:04:00 cat_n1_num	7
# 2021-10-21_13:04:00 cat_n2_num	20
# WARNING:tensorflow:From /content/FMCTS/arguments.py:70: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# 2021-10-21_13:04:00 top_k	3
# 2021-10-21_13:04:00 used4train	0.85
# 2021-10-21_13:04:00 accuracy	<function ndcg at 0x7f5fe86a1830>
# 2021-10-21_13:04:00 diversity	<function alpha_ndcg at 0x7f5fe86a19e0>
# 2021-10-21_13:04:00 latent_factor	20
# 2021-10-21_13:04:00 cell_type	nlstm
# 2021-10-21_13:04:00 rnn_layer	1
# 2021-10-21_13:04:00 learning_rate	0.005
# 2021-10-21_13:04:00 saving log file in ./log/m100k_m100k_hmcts_20_0_50_20_0_train_2021-10-21_13:04:00.log
# 2021-10-21_13:04:00 optimizer_name	sgd
# 2021-10-21_13:04:00 memory_capacity	1000
# 2021-10-21_13:04:00 discount_factor	1.0
# 2021-10-21_13:04:00 ######################### config for experiments #########################
# 2021-10-21_13:04:00 c_puct	20.0
# 2021-10-21_13:04:00 n_playout	50
# 2021-10-21_13:04:00 model	m100k_hmcts
# 2021-10-21_13:04:00 temperature	20.0
# 2021-10-21_13:04:00 update_frequency	1
# 2021-10-21_13:04:00 batch_size	60
# 2021-10-21_13:04:00 data_name	m100k
# 2021-10-21_13:04:00 epoch	10000
# 2021-10-21_13:04:00 log_path	./log/
# 2021-10-21_13:04:00 evaluate_num	500
# 2021-10-21_13:04:00 delete_previous	False
# 2021-10-21_13:04:00 saved_model_path	saved_model
# 2021-10-21_13:04:00 root_path	./data/ml-100k/
# 2021-10-21_13:04:00 job_ports	[40001]
# 2021-10-21_13:04:00 task	evaluate
# 2021-10-21_13:04:00 rating_path	rat.dat
# 2021-10-21_13:04:00 jobs	{'local': ['localhost:40001']}
# 2021-10-21_13:04:00 key_words	['m100k', 'm100k_hmcts', 20.0, 50, 20.0]
# 2021-10-21_13:04:00 model_id	m100k_m100k_hmcts_20_0_50_20_0
# 2021-10-21_13:04:00 cat_path	cat.dat
# 2021-10-21_13:04:00 item_num	1683
# 2021-10-21_13:04:00 GPU_OPTION	allow_growth: true
# 2021-10-21_13:04:00 RANDOM_SEED	123
# 2021-10-21_13:04:00 user_num	944
# 2021-10-21_13:04:00 rating_num	5
# 2021-10-21_13:04:00 cat_n1_num	7
# 2021-10-21_13:04:00 RNN_LAYER	1
# 2021-10-21_13:04:00 ##########################################################################
# 2021-10-21_13:04:00 cat_n2_num	20
# 2021-10-21_13:04:00 top_k	3
# 2021-10-21_13:04:00 used4train	0.85
# 2021-10-21_13:04:00 accuracy	<function ndcg at 0x7f6eb7076830>
# 2021-10-21_13:04:00 diversity	<function alpha_ndcg at 0x7f6eb70769e0>
# 2021-10-21_13:04:00 latent_factor	20
# 2021-10-21_13:04:00 cell_type	nlstm
# 2021-10-21_13:04:00 rnn_layer	1
# 2021-10-21_13:04:00 learning_rate	0.005
# 2021-10-21_13:04:00 optimizer_name	sgd
# 2021-10-21_13:04:00 memory_capacity	1000
# 2021-10-21_13:04:00 discount_factor	1.0
# 2021-10-21_13:04:00 c_puct	20.0
# 2021-10-21_13:04:00 n_playout	50
# 2021-10-21_13:04:00 temperature	20.0
# 2021-10-21_13:04:00 update_frequency	1
# 2021-10-21_13:04:00 batch_size	60
# 2021-10-21_13:04:00 epoch	10000
# 2021-10-21_13:04:00 evaluate_num	500
# 2021-10-21_13:04:00 delete_previous	False
# 2021-10-21_13:04:00 saved_model_path	saved_model
# 2021-10-21_13:04:00 job_ports	[40001]
# 2021-10-21_13:04:00 task	train
# 2021-10-21_13:04:00 jobs	{'local': ['localhost:40001']}
# 2021-10-21_13:04:00 key_words	['m100k', 'm100k_hmcts', 20.0, 50, 20.0]
# 2021-10-21_13:04:00 model_id	m100k_m100k_hmcts_20_0_50_20_0
# 2021-10-21_13:04:00 GPU_OPTION	allow_growth: true
# 2021-10-21_13:04:00 RANDOM_SEED	123
# 2021-10-21_13:04:00 RNN_LAYER	1
# 2021-10-21_13:04:00 ##########################################################################
# 2021-10-21_13:04:03 CREATE MODEL	m100k_hmcts	GRAPH	DEFAULT	VARIABLE SCOPE	target
# 2021-10-21_13:04:03 Adding a new tensorflow graph:	DEFAULT
# <class 'function_approximation.rnn_model.rnn_model'>
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:95: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:27: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:64: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:80: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:91: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:122: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:122: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:124: The name tf.nn.rnn_cell.LSTMStateTuple is deprecated. Please use tf.compat.v1.nn.rnn_cell.LSTMStateTuple instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:127: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# ntlstm cell
# WARNING:tensorflow:From /content/FMCTS/function_approximation/cells.py:50: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# 2021-10-21_13:04:03 CREATE MODEL	m100k_hmcts	GRAPH	DEFAULT	VARIABLE SCOPE	target	jobs	{'local': ['localhost:40001']}	job	local	task_index	0
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:43: The name tf.train.Server is deprecated. Please use tf.distribute.Server instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:43: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2021-10-21 13:04:03.883886: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-10-21 13:04:03.884974: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6db4ca680 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-10-21 13:04:03.885227: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-10-21 13:04:03.896089: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-10-21 13:04:03.918021: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-10-21 13:04:03.918649: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (8f448b89f256): /proc/driver/nvidia/version does not exist
# 2021-10-21 13:04:03.926712: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:258] Initialize GrpcChannelCache for job local -> {0 -> localhost:40001}
# 2021-10-21 13:04:03.929654: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:365] Started server with target: grpc://localhost:40001
# 2021-10-21_13:04:03 Adding a new tensorflow graph:	DEFAULT
# <class 'function_approximation.rnn_model.rnn_model'>
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:95: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:27: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:64: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:Entity <bound method nlstm.call of <function_approximation.cells.nlstm object at 0x7f5fe0ad0710>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:80: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ntlstm cell
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:91: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:122: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:122: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:124: The name tf.nn.rnn_cell.LSTMStateTuple is deprecated. Please use tf.compat.v1.nn.rnn_cell.LSTMStateTuple instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:127: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:Entity <bound method nlstm.call of <function_approximation.cells.nlstm object at 0x7f5fe1d58cd0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# ntlstm cell
# WARNING:tensorflow:From /content/FMCTS/function_approximation/cells.py:50: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:22: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:124: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:30: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:Entity <bound method nlstm.call of <function_approximation.cells.nlstm object at 0x7f6eaf5a9390>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# ntlstm cell
# WARNING:tensorflow:Entity <bound method nlstm.call of <function_approximation.cells.nlstm object at 0x7f6eaf55d650>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:22: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/rnn_model.py:124: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:30: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:109: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:67: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:67: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2021-10-21 13:04:09.854620: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-10-21 13:04:09.855522: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x562bc37ac680 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-10-21 13:04:09.855977: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-10-21 13:04:09.859449: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-10-21 13:04:09.882759: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-10-21 13:04:09.883555: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (8f448b89f256): /proc/driver/nvidia/version does not exist
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:68: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:109: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:50: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/FMCTS/function_approximation/base.py:51: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# 0 collecting data
# Process Process-1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/FMCTS/train/train.py", line 58, in train
#     data,reward = collecting_training_samples(config,mcts,env,config.temperature/(e+0.000001))
#   File "/content/FMCTS/train/train.py", line 30, in collecting_training_samples
#     temp,training=True)
#   File "/content/FMCTS/train/mcts.py", line 155, in get_action
#     acts, probs = self.get_move_probs(env, temperature)
#   File "/content/FMCTS/train/mcts.py", line 145, in get_move_probs
#     self._playout(env_copy)
#   File "/content/FMCTS/train/mcts.py", line 118, in _playout
#     _action_probs, next_state_value = self._policy["model"].get_actions_probability(self._policy["sess"],env)
#   File "/content/FMCTS/function_approximation/rnn_model.py", line 197, in get_actions_probability
#     all_score = softmax([p_policy[0][item] for item in sensible_action],30)
#   File "/content/FMCTS/function_approximation/rnn_model.py", line 197, in <listcomp>
#     all_score = softmax([p_policy[0][item] for item in sensible_action],30)
# IndexError: index 9 is out of bounds for axis 0 with size 7
