# %%
# !git clone https://github.com/rootlu/MetaHIN.git
# Out:
# Cloning into 'MetaHIN'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (182/182), done.
# remote: Total 195 (delta 50), reused 107 (delta 9), pack-reused 0
# Receiving objects: 100% (195/195), 39.28 MiB | 19.49 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# %cd MetaHIN
# Out:
# /content/MetaHIN

# %%
# !python code/main.py

# %%
# %cd code
# Out:
# /content/MetaHIN/code

# %%
# %%writefile Config.py
# coding: utf-8
# author: lu yf
# create date: 2019-11-20 19:46

config_db = {
    'dataset': 'dbook',
    # 'mp': ['ub'],
    # 'mp': ['ub','ubab'],
    'mp': ['ub','ubab','ubub'],
    'use_cuda': False,
    'file_num': 10,  # each task contains 10 files

    # user
    'num_location': 453,
    'num_fea_item': 2,

    # item
    'num_publisher': 1698,
    'num_fea_user': 1,
    'item_fea_len': 1,

    # model setting
    # 'embedding_dim': 32,
    # 'user_embedding_dim': 32*1,  # 1 features
    # 'item_embedding_dim': 32*1,  # 1 features

    'embedding_dim': 32,
    'user_embedding_dim': 32*1,  # 1 features
    'item_embedding_dim': 32*1,  # 1 features

    'first_fc_hidden_dim': 64,
    'second_fc_hidden_dim': 64,

    'mp_update': 1,
    'local_update': 1,
    'lr': 5e-4,
    'mp_lr': 5e-3,
    'local_lr': 5e-3,
    'batch_size': 32,  # for each batch, the number of tasks
    'num_epoch': 50,
    'neigh_agg': 'mean',
    # 'neigh_agg': 'attention',
    'mp_agg': 'mean',
    # 'mp_agg': 'attention',
}


config_ml = {
    'dataset': 'movielens',
    # 'mp': ['um'],
    # 'mp': ['um','umdm'],
    # 'mp': ['um','umam','umdm'],
    'mp': ['um','umum','umam','umdm'],
    'use_cuda': False,
    'file_num': 12,  # each task contains 12 files for movielens

    # item
    'num_rate': 6,
    'num_genre': 25,
    'num_fea_item': 2,
    'item_fea_len': 26,

    # user
    'num_gender': 2,
    'num_age': 7,
    'num_occupation': 21,
    'num_zipcode': 3402,
    'num_fea_user': 4,

    # model setting
    'embedding_dim': 32,
    'user_embedding_dim': 32*4,  # 4 features
    'item_embedding_dim': 32*2,  # 2 features

    'first_fc_hidden_dim': 64,
    'second_fc_hidden_dim': 64,

    'mp_update': 1,
    'local_update': 1,
    'lr': 5e-4,
    'mp_lr': 5e-3,
    'local_lr': 5e-3,
    'batch_size': 32,  # for each batch, the number of tasks
    'num_epoch': 100,
    'neigh_agg': 'mean',
    # 'neigh_agg': 'max',
    'mp_agg': 'mean',
    # 'mp_agg': 'attention',
}


config_yelp = {
    'dataset': 'yelp',
    # 'mp': ['ubub'],
    'mp': ['ub','ubcb','ubtb','ubub'],
    'use_cuda': False,
    'file_num': 12,  # each task contains 12 files

    # item
    'num_stars': 9,
    'num_postalcode': 6127,
    'num_fea_item': 2,
    'item_fea_len': 2,

    # user
    'num_fans': 412,
    'num_avgrating': 359,
    'num_fea_user': 2,

    # model setting
    'embedding_dim': 32,
    'user_embedding_dim': 32*2,  # 1 features
    'item_embedding_dim': 32*2,  # 1 features

    'first_fc_hidden_dim': 64,
    'second_fc_hidden_dim': 64,

    'mp_update': 1,
    'local_update': 1,
    'lr': 5e-4,
    'mp_lr': 1e-3,
    'local_lr': 1e-3,
    'batch_size': 32,  # for each batch, the number of tasks
    'num_epoch': 50,
    'neigh_agg': 'mean',
    # 'neigh_agg': 'attention',
    'mp_agg': 'mean',
    # 'mp_agg': 'attention',
}


states = ["meta_training","warm_up", "user_cold_testing", "item_cold_testing", "user_and_item_cold_testing"]
# Out:
# Overwriting Config.py

# %%
# !cd ../data/movielens && gdown --id 1bTpwctr6ZgdosU8FU4sLqlC_Gt1-z77G
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bTpwctr6ZgdosU8FU4sLqlC_Gt1-z77G
# To: /content/MetaHIN/data/movielens/movielens.tar.bz2
# 100% 624M/624M [00:03<00:00, 175MB/s]

# %%
# !cd ../data/movielens && tar -xvf movielens.tar.bz2
# Out:
# movielens/meta_training/support_umum_2516.pkl
# movielens/meta_training/support_y_1450.pkl
# movielens/meta_training/support_umdm_1974.pkl
# movielens/meta_training/support_um_715.pkl
# movielens/meta_training/query_um_572.pkl
# movielens/meta_training/support_umam_1237.pkl
# movielens/meta_training/query_y_1333.pkl
# movielens/meta_training/query_umam_131.pkl
# movielens/meta_training/support_x_2071.pkl
# movielens/meta_training/query_umum_2672.pkl
# movielens/meta_training/query_x_1943.pkl
# movielens/meta_training/query_umam_787.pkl
# movielens/meta_training/support_um_610.pkl
# movielens/meta_training/query_x_202.pkl
# movielens/meta_training/support_umdm_1506.pkl
# movielens/meta_training/query_umam_2173.pkl
# movielens/meta_training/query_x_287.pkl
# movielens/meta_training/support_um_775.pkl
# movielens/meta_training/support_umam_2040.pkl
# movielens/meta_training/support_umum_2040.pkl
# movielens/meta_training/support_y_493.pkl
# movielens/meta_training/query_umdm_1073.pkl
# movielens/meta_training/query_um_2472.pkl
# movielens/meta_training/support_um_72.pkl
# movielens/meta_training/support_x_473.pkl
# movielens/meta_training/support_um_2333.pkl
# movielens/meta_training/query_umum_1630.pkl
# movielens/meta_training/support_y_1917.pkl
# movielens/meta_training/support_umum_1414.pkl
# movielens/meta_training/support_umam_564.pkl
# movielens/meta_training/support_um_1879.pkl
# movielens/meta_training/query_x_1443.pkl
# movielens/meta_training/query_umdm_2062.pkl
# movielens/meta_training/support_x_296.pkl
# movielens/meta_training/support_umdm_1528.pkl
# movielens/meta_training/query_umdm_1771.pkl
# movielens/meta_training/support_y_2252.pkl
# movielens/meta_training/query_umam_2670.pkl
# movielens/meta_training/query_y_1009.pkl
# movielens/meta_training/query_umam_1922.pkl
# movielens/meta_training/support_umum_1180.pkl
# movielens/meta_training/query_y_569.pkl
# movielens/meta_training/support_um_2262.pkl
# movielens/meta_training/support_um_2046.pkl
# movielens/meta_training/support_umdm_1779.pkl
# movielens/meta_training/query_um_509.pkl
# movielens/meta_training/query_umdm_758.pkl
# movielens/meta_training/support_x_207.pkl
# movielens/meta_training/support_umum_478.pkl
# movielens/meta_training/query_um_2252.pkl
# movielens/meta_training/support_y_76.pkl
# movielens/meta_training/support_umdm_991.pkl
# movielens/meta_training/support_x_743.pkl
# movielens/meta_training/query_um_1814.pkl
# movielens/meta_training/support_umum_1306.pkl
# movielens/meta_training/support_umam_2606.pkl
# movielens/meta_training/support_umdm_1464.pkl
# movielens/meta_training/support_y_2746.pkl
# movielens/meta_training/query_umdm_171.pkl
# movielens/meta_training/support_y_746.pkl
# movielens/meta_training/support_x_546.pkl
# movielens/meta_training/query_y_1310.pkl
# movielens/meta_training/support_umam_2483.pkl
# movielens/meta_training/query_umdm_1802.pkl
# movielens/meta_training/support_y_834.pkl
# movielens/meta_training/support_umdm_580.pkl
# movielens/meta_training/support_umum_2450.pkl
# movielens/meta_training/query_y_2607.pkl
# movielens/meta_training/query_y_1030.pkl
# movielens/meta_training/query_umam_502.pkl
# movielens/meta_training/support_x_815.pkl
# movielens/meta_training/support_umam_251.pkl
# movielens/meta_training/query_umdm_705.pkl
# movielens/meta_training/query_umdm_1720.pkl
# movielens/meta_training/support_y_644.pkl
# movielens/meta_training/query_y_2110.pkl
# movielens/meta_training/query_x_711.pkl
# movielens/meta_training/support_x_900.pkl
# movielens/meta_training/query_umdm_1086.pkl
# movielens/meta_training/support_x_930.pkl
# movielens/meta_training/support_x_125.pkl
# movielens/meta_training/query_um_640.pkl
# movielens/meta_training/query_umum_2055.pkl
# movielens/meta_training/support_y_2077.pkl
# movielens/meta_training/support_umdm_464.pkl
# movielens/meta_training/support_um_752.pkl
# movielens/meta_training/query_um_1990.pkl
# movielens/meta_training/support_y_1565.pkl
# movielens/meta_training/query_x_1735.pkl
# movielens/meta_training/query_umum_1225.pkl
# movielens/meta_training/query_y_1975.pkl
# movielens/meta_training/query_umum_2605.pkl
# movielens/meta_training/support_umam_359.pkl
# movielens/meta_training/query_um_2596.pkl
# movielens/meta_training/query_um_1129.pkl
# movielens/meta_training/support_umam_1453.pkl
# movielens/meta_training/support_y_2334.pkl
# movielens/meta_training/query_y_2337.pkl
# movielens/meta_training/support_umdm_1328.pkl
# movielens/meta_training/query_umum_2138.pkl
# movielens/meta_training/support_umum_1111.pkl
# movielens/meta_training/query_umdm_1081.pkl
# movielens/meta_training/support_umum_513.pkl
# movielens/meta_training/support_umam_1842.pkl
# movielens/meta_training/query_umum_120.pkl
# movielens/meta_training/support_um_123.pkl
# movielens/meta_training/query_y_667.pkl
# movielens/meta_training/query_umam_462.pkl
# movielens/meta_training/support_um_144.pkl
# movielens/meta_training/support_x_25.pkl
# movielens/meta_training/query_x_2191.pkl
# movielens/meta_training/query_y_2416.pkl
# movielens/meta_training/support_umam_1988.pkl
# movielens/meta_training/query_x_1598.pkl
# movielens/meta_training/support_x_132.pkl
# movielens/meta_training/query_um_891.pkl
# movielens/meta_training/support_umam_1521.pkl
# movielens/meta_training/query_x_2190.pkl
# movielens/meta_training/support_umam_2138.pkl
# movielens/meta_training/support_umam_348.pkl
# movielens/meta_training/support_y_1895.pkl
# movielens/meta_training/support_x_41.pkl
# movielens/meta_training/support_umdm_2102.pkl
# movielens/meta_training/query_um_969.pkl
# movielens/meta_training/query_x_2109.pkl
# movielens/meta_training/support_y_1295.pkl
# movielens/meta_training/support_um_1344.pkl
# movielens/meta_training/support_umdm_157.pkl
# movielens/meta_training/support_umdm_1047.pkl
# movielens/meta_training/support_umam_2643.pkl
# movielens/meta_training/query_umdm_254.pkl
# movielens/meta_training/query_um_2720.pkl
# movielens/meta_training/query_umam_2610.pkl
# movielens/meta_training/query_y_760.pkl
# movielens/meta_training/support_y_2398.pkl
# movielens/meta_training/support_y_1569.pkl
# movielens/meta_training/support_umdm_1394.pkl
# movielens/meta_training/query_umum_1495.pkl
# movielens/meta_training/query_y_844.pkl
# movielens/meta_training/query_umum_157.pkl
# movielens/meta_training/query_x_2026.pkl
# movielens/meta_training/support_x_2172.pkl
# movielens/meta_training/support_um_1266.pkl
# movielens/meta_training/query_umdm_2252.pkl
# movielens/meta_training/query_umum_868.pkl
# movielens/meta_training/support_um_2353.pkl
# movielens/meta_training/query_umdm_1538.pkl
# movielens/meta_training/support_umam_1871.pkl
# movielens/meta_training/query_y_1435.pkl
# movielens/meta_training/query_x_2086.pkl
# movielens/meta_training/support_umam_170.pkl
# movielens/meta_training/query_y_1867.pkl
# movielens/meta_training/query_um_2528.pkl
# movielens/meta_training/support_umam_880.pkl
# movielens/meta_training/query_umum_1900.pkl
# movielens/meta_training/support_y_1292.pkl
# movielens/meta_training/support_umam_297.pkl
# movielens/meta_training/support_x_2085.pkl
# movielens/meta_training/support_umdm_45.pkl
# movielens/meta_training/query_umum_674.pkl
# movielens/meta_training/support_umdm_589.pkl
# movielens/meta_training/support_umum_708.pkl
# movielens/meta_training/support_umam_2647.pkl
# movielens/meta_training/support_umdm_17.pkl
# movielens/meta_training/query_umum_6.pkl
# movielens/meta_training/query_umam_410.pkl
# movielens/meta_training/query_umum_2485.pkl
# movielens/meta_training/support_x_2367.pkl
# movielens/meta_training/query_umdm_1830.pkl
# movielens/meta_training/query_umam_1254.pkl
# movielens/meta_training/support_umum_6.pkl
# movielens/meta_training/support_umam_1463.pkl
# movielens/meta_training/query_um_294.pkl
# movielens/meta_training/query_y_1452.pkl
# movielens/meta_training/support_umdm_1924.pkl
# movielens/meta_training/query_y_1287.pkl
# movielens/meta_training/support_umam_2227.pkl
# movielens/meta_training/query_umam_2508.pkl
# movielens/meta_training/query_umam_345.pkl
# movielens/meta_training/query_umdm_1367.pkl
# movielens/meta_training/support_umam_599.pkl
# movielens/meta_training/support_um_1895.pkl
# movielens/meta_training/support_umum_682.pkl
# movielens/meta_training/query_x_1305.pkl
# movielens/meta_training/support_umam_471.pkl
# movielens/meta_training/query_um_1749.pkl
# movielens/meta_training/query_umdm_870.pkl
# movielens/meta_training/query_umam_778.pkl
# movielens/meta_training/support_y_684.pkl
# movielens/meta_training/support_y_2258.pkl
# movielens/meta_training/query_um_1496.pkl
# movielens/meta_training/query_umam_616.pkl
# movielens/meta_training/query_y_16.pkl
# movielens/meta_training/support_umdm_2019.pkl
# movielens/meta_training/support_umam_22.pkl
# movielens/meta_training/query_umdm_361.pkl
# movielens/meta_training/query_y_2473.pkl
# movielens/meta_training/query_umum_2050.pkl
# movielens/meta_training/query_um_2129.pkl
# movielens/meta_training/support_y_1643.pkl
# movielens/meta_training/support_umam_2078.pkl
# movielens/meta_training/query_y_679.pkl
# movielens/meta_training/query_um_102.pkl
# movielens/meta_training/query_umum_2052.pkl
# movielens/meta_training/query_x_1090.pkl
# movielens/meta_training/query_umdm_287.pkl
# movielens/meta_training/support_um_389.pkl
# movielens/meta_training/support_umdm_146.pkl
# movielens/meta_training/support_y_702.pkl
# movielens/meta_training/support_umam_298.pkl
# movielens/meta_training/support_umdm_2517.pkl
# movielens/meta_training/support_umdm_448.pkl
# movielens/meta_training/query_umum_971.pkl
# movielens/meta_training/query_um_800.pkl
# movielens/meta_training/support_umam_2491.pkl
# movielens/meta_training/support_y_495.pkl
# movielens/meta_training/support_x_1274.pkl
# movielens/meta_training/support_y_1807.pkl
# movielens/meta_training/support_y_1878.pkl
# movielens/meta_training/support_y_1778.pkl
# movielens/meta_training/support_um_2190.pkl
# movielens/meta_training/support_y_947.pkl
# movielens/meta_training/support_um_142.pkl
# movielens/meta_training/query_x_1431.pkl
# movielens/meta_training/query_umdm_1767.pkl
# movielens/meta_training/support_umam_1977.pkl
# movielens/meta_training/query_umum_1844.pkl
# movielens/meta_training/query_y_360.pkl
# movielens/meta_training/support_umdm_1928.pkl
# movielens/meta_training/support_y_1811.pkl
# movielens/meta_training/query_umdm_2259.pkl
# movielens/meta_training/query_um_1721.pkl
# movielens/meta_training/query_umdm_1128.pkl
# movielens/meta_training/support_umdm_1507.pkl
# movielens/meta_training/query_umum_651.pkl
# movielens/meta_training/support_x_2554.pkl
# movielens/meta_training/query_umam_1241.pkl
# movielens/meta_training/query_x_1468.pkl
# movielens/meta_training/support_umam_2658.pkl
# movielens/meta_training/query_x_1681.pkl
# movielens/meta_training/support_y_487.pkl
# movielens/meta_training/query_umdm_16.pkl
# movielens/meta_training/support_umum_2723.pkl
# movielens/meta_training/support_umam_2019.pkl
# movielens/meta_training/support_umum_1717.pkl
# movielens/meta_training/query_y_2702.pkl
# movielens/meta_training/query_um_1611.pkl
# movielens/meta_training/support_um_1741.pkl
# movielens/meta_training/query_y_1175.pkl
# movielens/meta_training/support_x_969.pkl
# movielens/meta_training/support_x_443.pkl
# movielens/meta_training/query_umum_589.pkl
# movielens/meta_training/support_umdm_2298.pkl
# movielens/meta_training/support_x_1240.pkl
# movielens/meta_training/query_umam_910.pkl
# movielens/meta_training/query_umum_789.pkl
# movielens/meta_training/query_y_1685.pkl
# movielens/meta_training/support_umdm_227.pkl
# movielens/meta_training/support_um_766.pkl
# movielens/meta_training/support_umam_2575.pkl
# movielens/meta_training/support_umdm_1452.pkl
# movielens/meta_training/query_y_1826.pkl
# movielens/meta_training/support_um_2692.pkl
# movielens/meta_training/support_umum_1297.pkl
# movielens/meta_training/support_umum_1207.pkl
# movielens/meta_training/query_um_295.pkl
# movielens/meta_training/support_y_98.pkl
# movielens/meta_training/support_umam_787.pkl
# movielens/meta_training/query_umdm_37.pkl
# movielens/meta_training/support_umdm_900.pkl
# movielens/meta_training/query_y_2083.pkl
# movielens/meta_training/query_umdm_2444.pkl
# movielens/meta_training/query_y_1617.pkl
# movielens/meta_training/support_umdm_2328.pkl
# movielens/meta_training/support_x_2740.pkl
# movielens/meta_training/query_umdm_1527.pkl
# movielens/meta_training/query_x_2384.pkl
# movielens/meta_training/query_umum_762.pkl
# movielens/meta_training/support_umdm_1976.pkl
# movielens/meta_training/support_x_1267.pkl
# movielens/meta_training/query_y_2071.pkl
# movielens/meta_training/query_x_898.pkl
# movielens/meta_training/query_umam_971.pkl
# movielens/meta_training/support_umam_256.pkl
# movielens/meta_training/support_umam_88.pkl
# movielens/meta_training/query_um_2281.pkl
# movielens/meta_training/support_umum_1978.pkl
# movielens/meta_training/support_x_750.pkl
# movielens/meta_training/support_y_2468.pkl
# movielens/meta_training/query_umam_1473.pkl
# movielens/meta_training/query_x_516.pkl
# movielens/meta_training/support_umam_1560.pkl
# movielens/meta_training/query_x_186.pkl
# movielens/meta_training/support_umam_1125.pkl
# movielens/meta_training/query_um_2733.pkl
# movielens/meta_training/query_um_215.pkl
# movielens/meta_training/query_x_2722.pkl
# movielens/meta_training/query_um_1331.pkl
# movielens/meta_training/query_umum_1673.pkl
# movielens/meta_training/support_x_2271.pkl
# movielens/meta_training/support_y_1685.pkl
# movielens/meta_training/support_umam_620.pkl
# movielens/meta_training/support_umam_2489.pkl
# movielens/meta_training/query_umdm_985.pkl
# movielens/meta_training/query_x_2270.pkl
# movielens/meta_training/query_y_350.pkl
# movielens/meta_training/query_umum_482.pkl
# movielens/meta_training/query_um_1963.pkl
# movielens/meta_training/support_um_2169.pkl
# movielens/meta_training/query_x_1120.pkl
# movielens/meta_training/support_y_2250.pkl
# movielens/meta_training/support_umdm_1878.pkl
# movielens/meta_training/support_umam_79.pkl
# movielens/meta_training/support_y_1049.pkl
# movielens/meta_training/support_umdm_267.pkl
# movielens/meta_training/query_um_878.pkl
# movielens/meta_training/query_umum_2185.pkl
# movielens/meta_training/support_umam_1074.pkl
# movielens/meta_training/query_umum_889.pkl
# movielens/meta_training/support_y_2101.pkl
# movielens/meta_training/query_umam_2632.pkl
# movielens/meta_training/support_x_2689.pkl
# movielens/meta_training/query_umdm_1537.pkl
# movielens/meta_training/support_umam_2270.pkl
# movielens/meta_training/query_umum_2192.pkl
# movielens/meta_training/support_umum_2236.pkl
# movielens/meta_training/query_umum_1518.pkl
# movielens/meta_training/support_umum_860.pkl
# movielens/meta_training/support_umum_2244.pkl
# movielens/meta_training/support_um_2411.pkl
# movielens/meta_training/support_umdm_989.pkl
# movielens/meta_training/support_um_2327.pkl
# movielens/meta_training/support_x_536.pkl
# movielens/meta_training/query_umum_1134.pkl
# movielens/meta_training/support_umum_1829.pkl
# movielens/meta_training/support_y_2646.pkl
# movielens/meta_training/support_y_794.pkl
# movielens/meta_training/support_y_2221.pkl
# movielens/meta_training/query_y_1396.pkl
# movielens/meta_training/support_umam_618.pkl
# movielens/meta_training/query_um_1687.pkl
# movielens/meta_training/support_umum_1986.pkl
# movielens/meta_training/query_umdm_1645.pkl
# movielens/meta_training/query_y_2151.pkl
# movielens/meta_training/support_umdm_1761.pkl
# movielens/meta_training/query_umam_114.pkl
# movielens/meta_training/support_um_2574.pkl
# movielens/meta_training/support_um_2069.pkl
# movielens/meta_training/query_um_2312.pkl
# movielens/meta_training/query_y_791.pkl
# movielens/meta_training/query_um_1398.pkl
# movielens/meta_training/query_umum_2194.pkl
# movielens/meta_training/support_x_1261.pkl
# movielens/meta_training/support_um_2085.pkl
# movielens/meta_training/query_um_300.pkl
# movielens/meta_training/query_umum_1767.pkl
# movielens/meta_training/support_umum_2714.pkl
# movielens/meta_training/query_x_2415.pkl
# movielens/meta_training/query_y_1085.pkl
# movielens/meta_training/query_x_2381.pkl
# movielens/meta_training/query_umum_1097.pkl
# movielens/meta_training/support_umdm_878.pkl
# movielens/meta_training/query_um_2311.pkl
# movielens/meta_training/query_umam_1570.pkl
# movielens/meta_training/support_umam_2291.pkl
# movielens/meta_training/support_x_553.pkl
# movielens/meta_training/query_y_1888.pkl
# movielens/meta_training/support_x_1883.pkl
# movielens/meta_training/support_umdm_911.pkl
# movielens/meta_training/query_um_1388.pkl
# movielens/meta_training/query_umam_2665.pkl
# movielens/meta_training/query_umam_2359.pkl
# movielens/meta_training/support_um_477.pkl
# movielens/meta_training/support_umum_1709.pkl
# movielens/meta_training/query_umam_222.pkl
# movielens/meta_training/support_umam_149.pkl
# movielens/meta_training/support_y_1870.pkl
# movielens/meta_training/support_x_1845.pkl
# movielens/meta_training/support_y_415.pkl
# movielens/meta_training/support_x_887.pkl
# movielens/meta_training/query_umam_812.pkl
# movielens/meta_training/query_um_979.pkl
# movielens/meta_training/query_x_2666.pkl
# movielens/meta_training/support_um_408.pkl
# movielens/meta_training/query_umdm_1958.pkl
# movielens/meta_training/query_x_1902.pkl
# movielens/meta_training/query_um_1737.pkl
# movielens/meta_training/query_um_934.pkl
# movielens/meta_training/query_umum_498.pkl
# movielens/meta_training/support_umam_2007.pkl
# movielens/meta_training/support_x_1620.pkl
# movielens/meta_training/query_umum_936.pkl
# movielens/meta_training/query_umam_1447.pkl
# movielens/meta_training/support_um_679.pkl
# movielens/meta_training/support_y_2358.pkl
# movielens/meta_training/query_umdm_1013.pkl
# movielens/meta_training/support_umam_2416.pkl
# movielens/meta_training/query_umdm_2245.pkl
# movielens/meta_training/query_y_2304.pkl
# movielens/meta_training/query_x_1038.pkl
# movielens/meta_training/query_umam_1779.pkl
# movielens/meta_training/support_y_1385.pkl
# movielens/meta_training/query_y_2645.pkl
# movielens/meta_training/support_x_406.pkl
# movielens/meta_training/query_umdm_1152.pkl
# movielens/meta_training/query_um_2376.pkl
# movielens/meta_training/support_um_1816.pkl
# movielens/meta_training/support_x_836.pkl
# movielens/meta_training/support_umam_1793.pkl
# movielens/meta_training/query_umam_674.pkl
# movielens/meta_training/query_umdm_1695.pkl
# movielens/meta_training/support_y_1143.pkl
# movielens/meta_training/support_y_2690.pkl
# movielens/meta_training/support_umdm_2263.pkl
# movielens/meta_training/support_umdm_1494.pkl
# movielens/meta_training/query_um_2382.pkl
# movielens/meta_training/query_y_1036.pkl
# movielens/meta_training/query_y_2174.pkl
# movielens/meta_training/query_um_1781.pkl
# movielens/meta_training/support_umdm_224.pkl
# movielens/meta_training/support_um_2166.pkl
# movielens/meta_training/query_um_1792.pkl
# movielens/meta_training/query_x_402.pkl
# movielens/meta_training/query_umam_165.pkl
# movielens/meta_training/query_x_2609.pkl
# movielens/meta_training/support_umum_139.pkl
# movielens/meta_training/support_um_1568.pkl
# movielens/meta_training/query_x_934.pkl
# movielens/meta_training/query_y_773.pkl
# movielens/meta_training/query_umum_2640.pkl
# movielens/meta_training/query_x_2155.pkl
# movielens/meta_training/query_y_1056.pkl
# movielens/meta_training/query_umum_2601.pkl
# movielens/meta_training/support_x_2700.pkl
# movielens/meta_training/query_umum_2660.pkl
# movielens/meta_training/support_y_1849.pkl
# movielens/meta_training/query_umdm_2216.pkl
# movielens/meta_training/query_umum_370.pkl
# movielens/meta_training/query_umam_1772.pkl
# movielens/meta_training/query_um_1643.pkl
# movielens/meta_training/query_y_1439.pkl
# movielens/meta_training/query_y_2386.pkl
# movielens/meta_training/query_um_1761.pkl
# movielens/meta_training/query_umdm_2694.pkl
# movielens/meta_training/query_umum_628.pkl
# movielens/meta_training/support_um_375.pkl
# movielens/meta_training/support_x_2338.pkl
# movielens/meta_training/support_y_1710.pkl
# movielens/meta_training/query_umam_1849.pkl
# movielens/meta_training/support_umdm_343.pkl
# movielens/meta_training/support_umam_1548.pkl
# movielens/meta_training/query_umam_1155.pkl
# movielens/meta_training/query_um_1187.pkl
# movielens/meta_training/query_umam_1971.pkl
# movielens/meta_training/query_x_1295.pkl
# movielens/meta_training/query_umdm_1250.pkl
# movielens/meta_training/query_x_1015.pkl
# movielens/meta_training/query_umam_1329.pkl
# movielens/meta_training/support_umum_325.pkl
# movielens/meta_training/support_y_2679.pkl
# movielens/meta_training/support_x_2072.pkl
# movielens/meta_training/query_umum_1811.pkl
# movielens/meta_training/query_y_33.pkl
# movielens/meta_training/support_y_1767.pkl
# movielens/meta_training/support_umdm_21.pkl
# movielens/meta_training/query_x_1370.pkl
# movielens/meta_training/support_umum_1918.pkl
# movielens/meta_training/support_x_831.pkl
# movielens/meta_training/support_umdm_2383.pkl
# movielens/meta_training/support_umam_1993.pkl
# movielens/meta_training/support_y_2020.pkl
# movielens/meta_training/query_um_2644.pkl
# movielens/meta_training/support_umam_773.pkl
# movielens/meta_training/query_y_622.pkl
# movielens/meta_training/query_umdm_1773.pkl
# movielens/meta_training/query_umum_615.pkl
# movielens/meta_training/query_um_362.pkl
# movielens/meta_training/support_umum_751.pkl
# movielens/meta_training/query_umum_1927.pkl
# movielens/meta_training/support_y_963.pkl
# movielens/meta_training/support_x_782.pkl
# movielens/meta_training/query_x_1794.pkl
# movielens/meta_training/query_um_2172.pkl
# movielens/meta_training/query_umam_1297.pkl
# movielens/meta_training/query_umum_2392.pkl
# movielens/meta_training/support_y_2416.pkl
# movielens/meta_training/support_umdm_139.pkl
# movielens/meta_training/query_y_289.pkl
# movielens/meta_training/support_y_1834.pkl
# movielens/meta_training/support_umam_1885.pkl
# movielens/meta_training/query_umum_858.pkl
# movielens/meta_training/support_umdm_1678.pkl
# movielens/meta_training/support_umam_281.pkl
# movielens/meta_training/support_x_875.pkl
# movielens/meta_training/query_umum_227.pkl
# movielens/meta_training/support_x_336.pkl
# movielens/meta_training/support_x_2438.pkl
# movielens/meta_training/support_umum_2700.pkl
# movielens/meta_training/query_umum_646.pkl
# movielens/meta_training/query_umdm_1810.pkl
# movielens/meta_training/support_y_596.pkl
# movielens/meta_training/query_um_1141.pkl
# movielens/meta_training/support_umam_376.pkl
# movielens/meta_training/support_x_565.pkl
# movielens/meta_training/support_y_2079.pkl
# movielens/meta_training/query_umam_106.pkl
# movielens/meta_training/query_umum_1567.pkl
# movielens/meta_training/query_um_2217.pkl
# movielens/meta_training/query_umum_1319.pkl
# movielens/meta_training/support_umdm_2284.pkl
# movielens/meta_training/query_umdm_1919.pkl
# movielens/meta_training/query_umdm_455.pkl
# movielens/meta_training/query_umum_514.pkl
# movielens/meta_training/support_um_2668.pkl
# movielens/meta_training/query_umam_818.pkl
# movielens/meta_training/query_umam_1239.pkl
# movielens/meta_training/support_um_824.pkl
# movielens/meta_training/query_x_2207.pkl
# movielens/meta_training/support_y_1227.pkl
# movielens/meta_training/support_x_2453.pkl
# movielens/meta_training/query_umdm_612.pkl
# movielens/meta_training/support_umdm_201.pkl
# movielens/meta_training/query_x_1583.pkl
# movielens/meta_training/support_umam_592.pkl
# movielens/meta_training/query_x_1529.pkl
# movielens/meta_training/support_umam_234.pkl
# movielens/meta_training/support_umum_2586.pkl
# movielens/meta_training/query_umdm_2282.pkl
# movielens/meta_training/query_umdm_1285.pkl
# movielens/meta_training/support_um_652.pkl
# movielens/meta_training/support_umum_1532.pkl
# movielens/meta_training/support_y_1430.pkl
# movielens/meta_training/query_umdm_305.pkl
# movielens/meta_training/query_umdm_1626.pkl
# movielens/meta_training/support_umam_2197.pkl
# movielens/meta_training/query_y_1362.pkl
# movielens/meta_training/support_x_466.pkl
# movielens/meta_training/query_umam_1320.pkl
# movielens/meta_training/query_umam_2307.pkl
# movielens/meta_training/support_umdm_914.pkl
# movielens/meta_training/query_x_2262.pkl
# movielens/meta_training/support_umam_2514.pkl
# movielens/meta_training/query_um_379.pkl
# movielens/meta_training/query_umdm_742.pkl
# movielens/meta_training/support_umdm_1035.pkl
# movielens/meta_training/query_umdm_1008.pkl
# movielens/meta_training/support_um_397.pkl
# movielens/meta_training/support_y_2182.pkl
# movielens/meta_training/support_y_1320.pkl
# movielens/meta_training/support_umdm_2364.pkl
# movielens/meta_training/support_umdm_123.pkl
# movielens/meta_training/query_y_982.pkl
# movielens/meta_training/support_umum_731.pkl
# movielens/meta_training/query_um_2732.pkl
# movielens/meta_training/query_umum_1146.pkl
# movielens/meta_training/support_umdm_1849.pkl
# movielens/meta_training/support_x_1167.pkl
# movielens/meta_training/support_umam_2569.pkl
# movielens/meta_training/query_y_1319.pkl
# movielens/meta_training/query_umam_1864.pkl
# movielens/meta_training/query_umum_9.pkl
# movielens/meta_training/support_umam_2476.pkl
# movielens/meta_training/query_umam_53.pkl
# movielens/meta_training/support_umdm_18.pkl
# movielens/meta_training/query_umum_1354.pkl
# movielens/meta_training/query_um_18.pkl
# movielens/meta_training/query_y_1796.pkl
# movielens/meta_training/query_umam_1194.pkl
# movielens/meta_training/support_x_654.pkl
# movielens/meta_training/query_um_477.pkl
# movielens/meta_training/query_um_1819.pkl
# movielens/meta_training/query_umum_45.pkl
# movielens/meta_training/support_x_1435.pkl
# movielens/meta_training/support_x_172.pkl
# movielens/meta_training/query_umum_691.pkl
# movielens/meta_training/query_um_562.pkl
# movielens/meta_training/query_umam_2493.pkl
# movielens/meta_training/support_umam_1276.pkl
# movielens/meta_training/support_umam_1179.pkl
# movielens/meta_training/query_umdm_1879.pkl
# movielens/meta_training/query_umum_814.pkl
# movielens/meta_training/support_y_1339.pkl
# movielens/meta_training/support_y_1563.pkl
# movielens/meta_training/support_um_932.pkl
# movielens/meta_training/support_umam_2508.pkl
# movielens/meta_training/query_umdm_379.pkl
# movielens/meta_training/query_umdm_197.pkl
# movielens/meta_training/support_um_2505.pkl
# movielens/meta_training/support_umam_812.pkl
# movielens/meta_training/query_um_615.pkl
# movielens/meta_training/support_umdm_2244.pkl
# movielens/meta_training/support_y_1432.pkl
# movielens/meta_training/query_umam_601.pkl
# movielens/meta_training/query_y_1028.pkl
# movielens/meta_training/support_um_2143.pkl
# movielens/meta_training/support_umam_221.pkl
# movielens/meta_training/support_umam_757.pkl
# movielens/meta_training/query_um_2482.pkl
# movielens/meta_training/query_x_2552.pkl
# movielens/meta_training/support_umam_503.pkl
# movielens/meta_training/query_um_2077.pkl
# movielens/meta_training/support_umam_1726.pkl
# movielens/meta_training/query_um_410.pkl
# movielens/meta_training/query_umdm_659.pkl
# movielens/meta_training/support_umum_322.pkl
# movielens/meta_training/support_umum_2117.pkl
# movielens/meta_training/query_y_74.pkl
# movielens/meta_training/support_umam_206.pkl
# movielens/meta_training/support_umdm_1444.pkl
# movielens/meta_training/query_um_2444.pkl
# movielens/meta_training/support_x_366.pkl
# movielens/meta_training/support_um_1530.pkl
# movielens/meta_training/support_umum_1643.pkl
# movielens/meta_training/support_umdm_1520.pkl
# movielens/meta_training/query_umum_2717.pkl
# movielens/meta_training/query_umum_769.pkl
# movielens/meta_training/query_y_2511.pkl
# movielens/meta_training/query_umum_1103.pkl
# movielens/meta_training/support_umam_1270.pkl
# movielens/meta_training/support_umdm_144.pkl
# movielens/meta_training/support_umdm_1148.pkl
# movielens/meta_training/query_umam_2371.pkl
# movielens/meta_training/support_umam_2673.pkl
# movielens/meta_training/support_umum_2526.pkl
# movielens/meta_training/support_x_1119.pkl
# movielens/meta_training/query_umdm_1346.pkl
# movielens/meta_training/support_umam_1541.pkl
# movielens/meta_training/query_y_2124.pkl
# movielens/meta_training/query_y_590.pkl
# movielens/meta_training/support_x_2346.pkl
# movielens/meta_training/support_y_2315.pkl
# movielens/meta_training/query_umdm_2408.pkl
# movielens/meta_training/query_um_2446.pkl
# movielens/meta_training/query_um_1857.pkl
# movielens/meta_training/query_y_1415.pkl
# movielens/meta_training/query_umdm_507.pkl
# movielens/meta_training/support_umam_1122.pkl
# movielens/meta_training/query_y_175.pkl
# movielens/meta_training/query_umdm_1659.pkl
# movielens/meta_training/query_um_2395.pkl
# movielens/meta_training/support_y_890.pkl
# movielens/meta_training/query_um_2289.pkl
# movielens/meta_training/query_x_822.pkl
# movielens/meta_training/query_umam_1521.pkl
# movielens/meta_training/support_umam_562.pkl
# movielens/meta_training/support_umdm_371.pkl
# movielens/meta_training/support_umam_1396.pkl
# movielens/meta_training/support_umam_1618.pkl
# movielens/meta_training/support_um_95.pkl
# movielens/meta_training/support_umdm_1290.pkl
# movielens/meta_training/support_y_373.pkl
# movielens/meta_training/query_y_2171.pkl
# movielens/meta_training/support_x_2000.pkl
# movielens/meta_training/support_y_2227.pkl
# movielens/meta_training/support_x_1950.pkl
# movielens/meta_training/support_umum_1641.pkl
# movielens/meta_training/query_umdm_2213.pkl
# movielens/meta_training/query_umdm_2604.pkl
# movielens/meta_training/support_um_914.pkl
# movielens/meta_training/support_umdm_563.pkl
# movielens/meta_training/query_um_1483.pkl
# movielens/meta_training/support_x_2169.pkl
# movielens/meta_training/support_y_2570.pkl
# movielens/meta_training/support_umam_586.pkl
# movielens/meta_training/query_umam_1948.pkl
# movielens/meta_training/query_umdm_143.pkl
# movielens/meta_training/support_umum_221.pkl
# movielens/meta_training/query_umdm_602.pkl
# movielens/meta_training/support_um_2707.pkl
# movielens/meta_training/query_umdm_2739.pkl
# movielens/meta_training/query_y_1323.pkl
# movielens/meta_training/query_umum_903.pkl
# movielens/meta_training/query_umum_1666.pkl
# movielens/meta_training/query_x_148.pkl
# movielens/meta_training/support_umum_848.pkl
# movielens/meta_training/query_umam_1512.pkl
# movielens/meta_training/query_umam_2499.pkl
# movielens/meta_training/support_y_2431.pkl
# movielens/meta_training/query_umdm_1703.pkl
# movielens/meta_training/query_umam_913.pkl
# movielens/meta_training/support_x_463.pkl
# movielens/meta_training/support_y_1497.pkl
# movielens/meta_training/query_um_928.pkl
# movielens/meta_training/support_umum_25.pkl
# movielens/meta_training/query_y_830.pkl
# movielens/meta_training/query_y_2169.pkl
# movielens/meta_training/support_y_856.pkl
# movielens/meta_training/query_y_2036.pkl
# movielens/meta_training/query_y_1241.pkl
# movielens/meta_training/support_x_2211.pkl
# movielens/meta_training/support_umdm_515.pkl
# movielens/meta_training/support_umum_2033.pkl
# movielens/meta_training/query_x_2301.pkl
# movielens/meta_training/query_umam_2641.pkl
# movielens/meta_training/support_umam_2052.pkl
# movielens/meta_training/support_um_2151.pkl
# movielens/meta_training/support_umam_2217.pkl
# movielens/meta_training/query_y_422.pkl
# movielens/meta_training/support_umam_2474.pkl
# movielens/meta_training/support_x_2654.pkl
# movielens/meta_training/support_umam_2460.pkl
# movielens/meta_training/support_umam_2031.pkl
# movielens/meta_training/query_um_115.pkl
# movielens/meta_training/query_y_656.pkl
# movielens/meta_training/query_x_826.pkl
# movielens/meta_training/query_umdm_673.pkl
# movielens/meta_training/query_umdm_2507.pkl
# movielens/meta_training/query_umam_436.pkl
# movielens/meta_training/query_umam_2311.pkl
# movielens/meta_training/query_y_1886.pkl
# movielens/meta_training/support_um_1583.pkl
# movielens/meta_training/query_y_2620.pkl
# movielens/meta_training/support_umdm_1602.pkl
# movielens/meta_training/query_y_2462.pkl
# movielens/meta_training/support_x_2734.pkl
# movielens/meta_training/query_x_799.pkl
# movielens/meta_training/query_y_1770.pkl
# movielens/meta_training/support_y_1219.pkl
# movielens/meta_training/query_umdm_236.pkl
# movielens/meta_training/query_um_2306.pkl
# movielens/meta_training/support_y_2555.pkl
# movielens/meta_training/query_umum_1710.pkl
# movielens/meta_training/query_umam_2190.pkl
# movielens/meta_training/support_umam_2355.pkl
# movielens/meta_training/query_umdm_838.pkl
# movielens/meta_training/query_umam_1848.pkl
# movielens/meta_training/support_y_2518.pkl
# movielens/meta_training/support_umam_1293.pkl
# movielens/meta_training/support_x_1823.pkl
# movielens/meta_training/query_umum_433.pkl
# movielens/meta_training/query_umum_516.pkl
# movielens/meta_training/support_y_128.pkl
# movielens/meta_training/query_umdm_1418.pkl
# movielens/meta_training/support_umdm_154.pkl
# movielens/meta_training/query_y_961.pkl
# movielens/meta_training/support_umam_803.pkl
# movielens/meta_training/query_x_2564.pkl
# movielens/meta_training/support_umum_1009.pkl
# movielens/meta_training/support_umam_430.pkl
# movielens/meta_training/support_umam_1536.pkl
# movielens/meta_training/query_x_1452.pkl
# movielens/meta_training/support_um_693.pkl
# movielens/meta_training/support_umum_993.pkl
# movielens/meta_training/query_umum_803.pkl
# movielens/meta_training/support_umdm_2388.pkl
# movielens/meta_training/support_umam_1974.pkl
# movielens/meta_training/query_um_745.pkl
# movielens/meta_training/query_umum_62.pkl
# movielens/meta_training/support_umdm_1953.pkl
# movielens/meta_training/support_umam_1318.pkl
# movielens/meta_training/query_x_1636.pkl
# movielens/meta_training/support_um_1911.pkl
# movielens/meta_training/query_umam_1743.pkl
# movielens/meta_training/support_umam_324.pkl
# movielens/meta_training/query_y_1710.pkl
# movielens/meta_training/query_umdm_2701.pkl
# movielens/meta_training/support_y_220.pkl
# movielens/meta_training/support_x_2401.pkl
# movielens/meta_training/query_y_15.pkl
# movielens/meta_training/query_x_680.pkl
# movielens/meta_training/query_um_2216.pkl
# movielens/meta_training/support_umum_2309.pkl
# movielens/meta_training/support_x_71.pkl
# movielens/meta_training/support_x_319.pkl
# movielens/meta_training/query_um_1702.pkl
# movielens/meta_training/query_umdm_716.pkl
# movielens/meta_training/support_y_1204.pkl
# movielens/meta_training/support_umam_1531.pkl
# movielens/meta_training/support_umdm_882.pkl
# movielens/meta_training/query_umam_1991.pkl
# movielens/meta_training/query_umum_2408.pkl
# movielens/meta_training/support_y_1182.pkl
# movielens/meta_training/support_y_875.pkl
# movielens/meta_training/support_umam_2262.pkl
# movielens/meta_training/query_y_868.pkl
# movielens/meta_training/support_y_874.pkl
# movielens/meta_training/query_um_1770.pkl
# movielens/meta_training/support_um_122.pkl
# movielens/meta_training/support_um_822.pkl
# movielens/meta_training/support_umam_2060.pkl
# movielens/meta_training/support_um_906.pkl
# movielens/meta_training/query_umdm_2414.pkl
# movielens/meta_training/query_um_2105.pkl
# movielens/meta_training/support_umum_2730.pkl
# movielens/meta_training/support_umum_2370.pkl
# movielens/meta_training/query_umam_1960.pkl
# movielens/meta_training/support_x_2088.pkl
# movielens/meta_training/query_y_1787.pkl
# movielens/meta_training/support_umdm_1151.pkl
# movielens/meta_training/support_y_765.pkl
# movielens/meta_training/query_um_657.pkl
# movielens/meta_training/support_umdm_635.pkl
# movielens/meta_training/query_umum_2024.pkl
# movielens/meta_training/query_x_2038.pkl
# movielens/meta_training/support_umdm_2120.pkl
# movielens/meta_training/query_umdm_1627.pkl
# movielens/meta_training/support_y_626.pkl
# movielens/meta_training/support_umdm_587.pkl
# movielens/meta_training/support_umam_2412.pkl
# movielens/meta_training/query_y_1891.pkl
# movielens/meta_training/support_um_2124.pkl
# movielens/meta_training/query_um_570.pkl
# movielens/meta_training/query_um_2131.pkl
# movielens/meta_training/query_umam_2357.pkl
# movielens/meta_training/query_umdm_36.pkl
# movielens/meta_training/support_umdm_1962.pkl
# movielens/meta_training/support_umdm_2510.pkl
# movielens/meta_training/support_y_78.pkl
# movielens/meta_training/query_um_701.pkl
# movielens/meta_training/query_umum_296.pkl
# movielens/meta_training/query_umdm_1253.pkl
# movielens/meta_training/query_y_125.pkl
# movielens/meta_training/query_um_157.pkl
# movielens/meta_training/query_umam_2390.pkl
# movielens/meta_training/query_umam_2047.pkl
# movielens/meta_training/query_umdm_820.pkl
# movielens/meta_training/support_umam_2732.pkl
# movielens/meta_training/support_umam_1540.pkl
# movielens/meta_training/query_umam_247.pkl
# movielens/meta_training/query_umum_340.pkl
# movielens/meta_training/support_umam_1648.pkl
# movielens/meta_training/query_um_1834.pkl
# movielens/meta_training/query_x_1641.pkl
# movielens/meta_training/support_umum_1449.pkl
# movielens/meta_training/query_y_434.pkl
# movielens/meta_training/query_umam_2273.pkl
# movielens/meta_training/support_x_396.pkl
# movielens/meta_training/query_umdm_7.pkl
# movielens/meta_training/support_um_22.pkl
# movielens/meta_training/support_y_155.pkl
# movielens/meta_training/query_umum_2093.pkl
# movielens/meta_training/support_umam_2681.pkl
# movielens/meta_training/support_y_1371.pkl
# movielens/meta_training/support_umdm_1643.pkl
# movielens/meta_training/query_y_2074.pkl
# movielens/meta_training/query_x_2203.pkl
# movielens/meta_training/support_y_322.pkl
# movielens/meta_training/support_y_1060.pkl
# movielens/meta_training/query_umdm_576.pkl
# movielens/meta_training/support_umdm_1205.pkl
# movielens/meta_training/query_umum_2532.pkl
# movielens/meta_training/support_umdm_317.pkl
# movielens/meta_training/query_x_66.pkl
# movielens/meta_training/support_umam_2645.pkl
# movielens/meta_training/support_y_2172.pkl
# movielens/meta_training/support_x_59.pkl
# movielens/meta_training/query_um_2177.pkl
# movielens/meta_training/query_y_2060.pkl
# movielens/meta_training/support_umam_2544.pkl
# movielens/meta_training/support_um_1671.pkl
# movielens/meta_training/support_um_1830.pkl
# movielens/meta_training/support_umum_1841.pkl
# movielens/meta_training/query_umam_1151.pkl
# movielens/meta_training/support_x_2094.pkl
# movielens/meta_training/support_umdm_552.pkl
# movielens/meta_training/query_x_1293.pkl
# movielens/meta_training/support_x_1057.pkl
# movielens/meta_training/support_umum_948.pkl
# movielens/meta_training/support_um_2059.pkl
# movielens/meta_training/query_um_51.pkl
# movielens/meta_training/query_umum_2512.pkl
# movielens/meta_training/query_umdm_2569.pkl
# movielens/meta_training/query_y_1324.pkl
# movielens/meta_training/support_umum_756.pkl
# movielens/meta_training/query_umum_2206.pkl
# movielens/meta_training/support_um_1034.pkl
# movielens/meta_training/support_umdm_323.pkl
# movielens/meta_training/support_um_247.pkl
# movielens/meta_training/support_umam_1642.pkl
# movielens/meta_training/support_y_2443.pkl
# movielens/meta_training/query_umam_1805.pkl
# movielens/meta_training/query_umum_2118.pkl
# movielens/meta_training/query_umdm_1214.pkl
# movielens/meta_training/query_y_1124.pkl
# movielens/meta_training/query_umum_854.pkl
# movielens/meta_training/support_umdm_1113.pkl
# movielens/meta_training/query_umdm_113.pkl
# movielens/meta_training/query_um_50.pkl
# movielens/meta_training/support_umum_1228.pkl
# movielens/meta_training/query_umam_1513.pkl
# movielens/meta_training/support_umam_417.pkl
# movielens/meta_training/query_umdm_1567.pkl
# movielens/meta_training/support_umam_1351.pkl
# movielens/meta_training/support_umam_2610.pkl
# movielens/meta_training/query_umam_1952.pkl
# movielens/meta_training/support_umam_2117.pkl
# movielens/meta_training/support_um_688.pkl
# movielens/meta_training/query_umam_1456.pkl
# movielens/meta_training/query_umdm_1194.pkl
# movielens/meta_training/support_y_1278.pkl
# movielens/meta_training/query_umdm_2166.pkl
# movielens/meta_training/query_umam_2709.pkl
# movielens/meta_training/query_umdm_63.pkl
# movielens/meta_training/query_y_838.pkl
# movielens/meta_training/query_umdm_2692.pkl
# movielens/meta_training/query_umdm_1353.pkl
# movielens/meta_training/support_um_755.pkl
# movielens/meta_training/query_umam_1147.pkl
# movielens/meta_training/query_umum_1262.pkl
# movielens/meta_training/support_y_1008.pkl
# movielens/meta_training/query_y_776.pkl
# movielens/meta_training/support_umdm_2597.pkl
# movielens/meta_training/query_y_1609.pkl
# movielens/meta_training/query_x_15.pkl
# movielens/meta_training/query_um_2373.pkl
# movielens/meta_training/support_x_2265.pkl
# movielens/meta_training/query_x_2680.pkl
# movielens/meta_training/support_um_921.pkl
# movielens/meta_training/query_y_528.pkl
# movielens/meta_training/support_umum_1477.pkl
# movielens/meta_training/query_um_2419.pkl
# movielens/meta_training/query_umum_398.pkl
# movielens/meta_training/support_um_1308.pkl
# movielens/meta_training/support_y_2670.pkl
# movielens/meta_training/support_umum_377.pkl
# movielens/meta_training/support_y_466.pkl
# movielens/meta_training/query_umam_792.pkl
# movielens/meta_training/query_umam_2007.pkl
# movielens/meta_training/support_umum_1855.pkl
# movielens/meta_training/query_umam_2728.pkl
# movielens/meta_training/query_um_45.pkl
# movielens/meta_training/query_umdm_1377.pkl
# movielens/meta_training/support_x_2199.pkl
# movielens/meta_training/query_um_2411.pkl
# movielens/meta_training/query_x_334.pkl
# movielens/meta_training/query_umum_1678.pkl
# movielens/meta_training/support_umum_173.pkl
# movielens/meta_training/query_umum_1007.pkl
# movielens/meta_training/support_umdm_382.pkl
# movielens/meta_training/query_x_180.pkl
# movielens/meta_training/query_um_485.pkl
# movielens/meta_training/query_um_1590.pkl
# movielens/meta_training/support_y_722.pkl
# movielens/meta_training/support_y_2698.pkl
# movielens/meta_training/query_x_1650.pkl
# movielens/meta_training/query_umdm_1483.pkl
# movielens/meta_training/query_y_716.pkl
# movielens/meta_training/query_um_226.pkl
# movielens/meta_training/support_umdm_35.pkl
# movielens/meta_training/query_y_975.pkl
# movielens/meta_training/query_umam_1035.pkl
# movielens/meta_training/support_umdm_67.pkl
# movielens/meta_training/query_umum_1360.pkl
# movielens/meta_training/query_x_459.pkl
# movielens/meta_training/support_umdm_566.pkl
# movielens/meta_training/support_umdm_943.pkl
# movielens/meta_training/query_um_2509.pkl
# movielens/meta_training/query_um_670.pkl
# movielens/meta_training/query_umum_1506.pkl
# movielens/meta_training/query_umam_825.pkl
# movielens/meta_training/query_umum_1201.pkl
# movielens/meta_training/support_um_402.pkl
# movielens/meta_training/support_y_1448.pkl
# movielens/meta_training/query_umum_1265.pkl
# movielens/meta_training/support_umum_92.pkl
# movielens/meta_training/support_umam_2202.pkl
# movielens/meta_training/query_umdm_299.pkl
# movielens/meta_training/query_y_1218.pkl
# movielens/meta_training/query_y_636.pkl
# movielens/meta_training/support_um_1149.pkl
# movielens/meta_training/support_umum_2611.pkl
# movielens/meta_training/query_umdm_1989.pkl
# movielens/meta_training/support_umam_1498.pkl
# movielens/meta_training/query_umam_30.pkl
# movielens/meta_training/query_umdm_1861.pkl
# movielens/meta_training/support_um_2405.pkl
# movielens/meta_training/support_um_337.pkl
# movielens/meta_training/support_umum_2553.pkl
# movielens/meta_training/query_umam_413.pkl
# movielens/meta_training/support_um_191.pkl
# movielens/meta_training/query_y_2694.pkl
# movielens/meta_training/query_um_373.pkl
# movielens/meta_training/query_umum_2274.pkl
# movielens/meta_training/support_x_2628.pkl
# movielens/meta_training/support_x_257.pkl
# movielens/meta_training/query_umum_2255.pkl
# movielens/meta_training/support_umum_2121.pkl
# movielens/meta_training/query_um_684.pkl
# movielens/meta_training/support_umum_2683.pkl
# movielens/meta_training/query_um_314.pkl
# movielens/meta_training/query_umdm_2669.pkl
# movielens/meta_training/query_umam_1112.pkl
# movielens/meta_training/support_umum_54.pkl
# movielens/meta_training/query_umum_366.pkl
# movielens/meta_training/query_um_113.pkl
# movielens/meta_training/support_umum_1189.pkl
# movielens/meta_training/support_umam_2524.pkl
# movielens/meta_training/support_umdm_1176.pkl
# movielens/meta_training/support_umam_2180.pkl
# movielens/meta_training/query_umum_2045.pkl
# movielens/meta_training/support_umdm_2417.pkl
# movielens/meta_training/query_um_472.pkl
# movielens/meta_training/query_y_1863.pkl
# movielens/meta_training/query_y_1569.pkl
# movielens/meta_training/query_umum_22.pkl
# movielens/meta_training/query_umdm_189.pkl
# movielens/meta_training/query_umdm_810.pkl
# movielens/meta_training/query_umum_2617.pkl
# movielens/meta_training/query_x_2434.pkl
# movielens/meta_training/support_y_2638.pkl
# movielens/meta_training/query_umam_2283.pkl
# movielens/meta_training/support_x_2048.pkl
# movielens/meta_training/support_umum_2303.pkl
# movielens/meta_training/query_umum_459.pkl
# movielens/meta_training/support_umam_1078.pkl
# movielens/meta_training/query_um_747.pkl
# movielens/meta_training/support_umdm_1125.pkl
# movielens/meta_training/query_x_250.pkl
# movielens/meta_training/query_umum_2400.pkl
# movielens/meta_training/query_umdm_2516.pkl
# movielens/meta_training/query_x_2374.pkl
# movielens/meta_training/support_y_1.pkl
# movielens/meta_training/support_x_2643.pkl
# movielens/meta_training/query_um_1245.pkl
# movielens/meta_training/support_umam_2337.pkl
# movielens/meta_training/query_y_2465.pkl
# movielens/meta_training/support_umdm_999.pkl
# movielens/meta_training/query_um_68.pkl
# movielens/meta_training/support_umam_1312.pkl
# movielens/meta_training/query_umam_386.pkl
# movielens/meta_training/query_um_607.pkl
# movielens/meta_training/support_y_1268.pkl
# movielens/meta_training/query_x_717.pkl
# movielens/meta_training/query_um_1031.pkl
# movielens/meta_training/query_umam_499.pkl
# movielens/meta_training/support_umam_672.pkl
# movielens/meta_training/support_um_1992.pkl
# movielens/meta_training/support_y_1535.pkl
# movielens/meta_training/query_x_2329.pkl
# movielens/meta_training/query_um_2338.pkl
# movielens/meta_training/support_y_1663.pkl
# movielens/meta_training/query_y_877.pkl
# movielens/meta_training/query_umum_31.pkl
# movielens/meta_training/query_umdm_1406.pkl
# movielens/meta_training/support_umum_1957.pkl
# movielens/meta_training/support_umdm_2189.pkl
# movielens/meta_training/query_um_455.pkl
# movielens/meta_training/query_um_2075.pkl
# movielens/meta_training/support_umam_2402.pkl
# movielens/meta_training/query_umum_1766.pkl
# movielens/meta_training/support_umdm_2660.pkl
# movielens/meta_training/support_umdm_1092.pkl
# movielens/meta_training/support_umum_331.pkl
# movielens/meta_training/query_y_2354.pkl
# movielens/meta_training/support_umdm_2010.pkl
# movielens/meta_training/support_umum_198.pkl
# movielens/meta_training/support_x_2745.pkl
# movielens/meta_training/query_umum_2459.pkl
# movielens/meta_training/support_x_1655.pkl
# movielens/meta_training/support_umam_2374.pkl
# movielens/meta_training/query_um_1336.pkl
# movielens/meta_training/support_umdm_1469.pkl
# movielens/meta_training/support_x_956.pkl
# movielens/meta_training/support_umam_2731.pkl
# movielens/meta_training/support_um_1645.pkl
# movielens/meta_training/support_umum_2575.pkl
# movielens/meta_training/query_y_475.pkl
# movielens/meta_training/support_um_1277.pkl
# movielens/meta_training/query_umdm_2419.pkl
# movielens/meta_training/support_umum_427.pkl
# movielens/meta_training/query_umum_562.pkl
# movielens/meta_training/query_umam_2633.pkl
# movielens/meta_training/support_umum_1952.pkl
# movielens/meta_training/query_y_2330.pkl
# movielens/meta_training/support_umdm_1128.pkl
# movielens/meta_training/query_x_1403.pkl
# movielens/meta_training/support_um_1119.pkl
# movielens/meta_training/query_um_1433.pkl
# movielens/meta_training/support_y_2211.pkl
# movielens/meta_training/support_umum_1832.pkl
# movielens/meta_training/query_x_136.pkl
# movielens/meta_training/query_umdm_340.pkl
# movielens/meta_training/support_y_2739.pkl
# movielens/meta_training/query_x_883.pkl
# movielens/meta_training/support_umam_2132.pkl
# movielens/meta_training/query_um_2550.pkl
# movielens/meta_training/support_umam_1291.pkl
# movielens/meta_training/query_umdm_1391.pkl
# movielens/meta_training/query_umdm_1478.pkl
# movielens/meta_training/query_umdm_2622.pkl
# movielens/meta_training/query_y_901.pkl
# movielens/meta_training/support_y_2108.pkl
# movielens/meta_training/query_umdm_2340.pkl
# movielens/meta_training/support_umdm_2465.pkl
# movielens/meta_training/query_umdm_899.pkl
# movielens/meta_training/query_x_655.pkl
# movielens/meta_training/query_y_1709.pkl
# movielens/meta_training/query_umam_628.pkl
# movielens/meta_training/support_umam_1462.pkl
# movielens/meta_training/query_umum_66.pkl
# movielens/meta_training/query_umdm_2311.pkl
# movielens/meta_training/support_y_2335.pkl
# movielens/meta_training/support_y_2219.pkl
# movielens/meta_training/support_umum_2001.pkl
# movielens/meta_training/query_um_2673.pkl
# movielens/meta_training/support_umam_145.pkl
# movielens/meta_training/query_umdm_2231.pkl
# movielens/meta_training/support_y_1761.pkl
# movielens/meta_training/query_umdm_1339.pkl
# movielens/meta_training/query_x_464.pkl
# movielens/meta_training/support_um_1130.pkl
# movielens/meta_training/query_x_1886.pkl
# movielens/meta_training/support_umam_244.pkl
# movielens/meta_training/support_umdm_2706.pkl
# movielens/meta_training/query_umum_2618.pkl
# movielens/meta_training/support_x_739.pkl
# movielens/meta_training/query_umum_1218.pkl
# movielens/meta_training/query_umdm_2493.pkl
# movielens/meta_training/query_um_1718.pkl
# ...
# movielens/meta_training/support_um_1176.pkl
# movielens/meta_training/support_um_2467.pkl
# movielens/meta_training/query_um_2666.pkl
# movielens/meta_training/query_x_157.pkl
# movielens/meta_training/support_umam_2462.pkl
# movielens/meta_training/support_x_2287.pkl
# movielens/meta_training/support_um_1058.pkl
# movielens/meta_training/support_x_2470.pkl
# movielens/meta_training/query_umum_2020.pkl
# movielens/meta_training/query_umum_1930.pkl
# movielens/meta_training/support_x_1703.pkl
# movielens/meta_training/support_umdm_588.pkl
# movielens/meta_training/query_um_501.pkl
# movielens/meta_training/query_umam_827.pkl
# movielens/meta_training/query_x_1476.pkl
# movielens/meta_training/support_umdm_2745.pkl
# movielens/meta_training/support_x_1035.pkl
# movielens/meta_training/support_umam_822.pkl
# movielens/meta_training/query_umdm_364.pkl
# movielens/meta_training/query_umum_2529.pkl
# movielens/meta_training/support_umum_743.pkl
# movielens/meta_training/query_y_8.pkl
# movielens/meta_training/support_x_2055.pkl
# movielens/meta_training/support_umum_962.pkl
# movielens/meta_training/query_x_434.pkl
# movielens/meta_training/query_umdm_1036.pkl
# movielens/meta_training/support_umdm_573.pkl
# movielens/meta_training/support_y_2141.pkl
# movielens/meta_training/support_y_2508.pkl
# movielens/meta_training/query_y_1754.pkl
# movielens/meta_training/query_umdm_1650.pkl
# movielens/meta_training/support_x_1336.pkl
# movielens/meta_training/query_um_1511.pkl
# movielens/meta_training/support_x_1170.pkl
# movielens/meta_training/query_y_632.pkl
# movielens/meta_training/query_x_2696.pkl
# movielens/meta_training/query_umum_1774.pkl
# movielens/meta_training/support_um_1332.pkl
# movielens/meta_training/query_umum_1226.pkl
# movielens/meta_training/support_y_2255.pkl
# movielens/meta_training/support_x_2091.pkl
# movielens/meta_training/support_y_383.pkl
# movielens/meta_training/support_um_1664.pkl
# movielens/meta_training/query_umum_2331.pkl
# movielens/meta_training/query_x_2031.pkl
# movielens/meta_training/query_umam_1615.pkl
# movielens/meta_training/query_umdm_1592.pkl
# movielens/meta_training/query_umdm_580.pkl
# movielens/meta_training/support_x_2588.pkl
# movielens/meta_training/query_um_2659.pkl
# movielens/meta_training/support_x_790.pkl
# movielens/meta_training/support_um_1139.pkl
# movielens/meta_training/support_x_928.pkl
# movielens/meta_training/support_umdm_32.pkl
# movielens/meta_training/query_um_659.pkl
# movielens/meta_training/query_umdm_1463.pkl
# movielens/meta_training/query_umum_1264.pkl
# movielens/meta_training/query_x_432.pkl
# movielens/meta_training/support_um_149.pkl
# movielens/meta_training/support_y_2022.pkl
# movielens/meta_training/query_umam_1899.pkl
# movielens/meta_training/query_y_25.pkl
# movielens/meta_training/support_um_1202.pkl
# movielens/meta_training/support_x_2168.pkl
# movielens/meta_training/support_umdm_1916.pkl
# movielens/meta_training/query_y_1922.pkl
# movielens/meta_training/support_y_521.pkl
# movielens/meta_training/support_umdm_1909.pkl
# movielens/meta_training/support_umum_2311.pkl
# movielens/meta_training/support_umam_915.pkl
# movielens/meta_training/support_umum_1752.pkl
# movielens/meta_training/query_um_816.pkl
# movielens/meta_training/query_umam_2333.pkl
# movielens/meta_training/support_umum_1588.pkl
# movielens/meta_training/support_x_766.pkl
# movielens/meta_training/query_umdm_1725.pkl
# movielens/meta_training/support_um_1649.pkl
# movielens/meta_training/support_x_1650.pkl
# movielens/meta_training/query_umum_1086.pkl
# movielens/meta_training/query_um_1276.pkl
# movielens/meta_training/query_umdm_2528.pkl
# movielens/meta_training/support_umam_1458.pkl
# movielens/meta_training/support_x_2638.pkl
# movielens/meta_training/query_umam_1094.pkl
# movielens/meta_training/support_umum_96.pkl
# movielens/meta_training/query_umam_1370.pkl
# movielens/meta_training/support_umdm_2306.pkl
# movielens/meta_training/support_y_2340.pkl
# movielens/meta_training/query_umdm_967.pkl
# movielens/meta_training/support_y_2139.pkl
# movielens/meta_training/support_y_1904.pkl
# movielens/meta_training/query_x_384.pkl
# movielens/meta_training/support_x_1967.pkl
# movielens/meta_training/query_um_2346.pkl
# movielens/meta_training/support_y_2500.pkl
# movielens/meta_training/support_um_1173.pkl
# movielens/meta_training/query_y_1899.pkl
# movielens/meta_training/query_umum_733.pkl
# movielens/meta_training/support_y_2448.pkl
# movielens/meta_training/support_x_1752.pkl
# movielens/meta_training/support_y_1359.pkl
# movielens/meta_training/query_y_1091.pkl
# movielens/meta_training/query_um_1632.pkl
# movielens/meta_training/query_umum_1372.pkl
# movielens/meta_training/support_umam_2516.pkl
# movielens/meta_training/support_x_2600.pkl
# movielens/meta_training/query_umdm_2667.pkl
# movielens/meta_training/support_umdm_1316.pkl
# movielens/meta_training/query_y_969.pkl
# movielens/meta_training/query_um_1096.pkl
# movielens/meta_training/query_y_1521.pkl
# movielens/meta_training/query_umum_220.pkl
# movielens/meta_training/support_umum_2399.pkl
# movielens/meta_training/support_umam_321.pkl
# movielens/meta_training/support_umdm_218.pkl
# movielens/meta_training/support_y_2476.pkl
# movielens/meta_training/support_umdm_1458.pkl
# movielens/meta_training/query_umam_156.pkl
# movielens/meta_training/query_umum_2042.pkl
# movielens/meta_training/query_umum_1015.pkl
# movielens/meta_training/query_umum_1385.pkl
# movielens/meta_training/query_umdm_2324.pkl
# movielens/meta_training/support_umdm_1889.pkl
# movielens/meta_training/support_umdm_353.pkl
# movielens/meta_training/support_um_2168.pkl
# movielens/meta_training/query_umam_904.pkl
# movielens/meta_training/support_x_1148.pkl
# movielens/meta_training/support_umam_368.pkl
# movielens/meta_training/query_y_164.pkl
# movielens/meta_training/query_umam_1753.pkl
# movielens/meta_training/query_x_2665.pkl
# movielens/meta_training/support_umum_1626.pkl
# movielens/meta_training/query_um_329.pkl
# movielens/meta_training/query_umum_585.pkl
# movielens/meta_training/support_umam_1873.pkl
# movielens/meta_training/query_umam_457.pkl
# movielens/meta_training/query_umum_2153.pkl
# movielens/meta_training/query_umum_720.pkl
# movielens/meta_training/query_umum_93.pkl
# movielens/meta_training/support_umam_419.pkl
# movielens/meta_training/support_umdm_2610.pkl
# movielens/meta_training/support_y_1723.pkl
# movielens/meta_training/support_umdm_1630.pkl
# movielens/meta_training/query_um_1271.pkl
# movielens/meta_training/support_x_318.pkl
# movielens/meta_training/query_x_1994.pkl
# movielens/meta_training/query_umum_414.pkl
# movielens/meta_training/support_y_2578.pkl
# movielens/meta_training/support_umdm_966.pkl
# movielens/meta_training/support_x_1789.pkl
# movielens/meta_training/support_y_1036.pkl
# movielens/meta_training/support_um_326.pkl
# movielens/meta_training/query_umdm_474.pkl
# movielens/meta_training/query_um_2074.pkl
# movielens/meta_training/support_um_2395.pkl
# movielens/meta_training/query_umam_595.pkl
# movielens/meta_training/support_umam_2568.pkl
# movielens/meta_training/support_umam_2411.pkl
# movielens/meta_training/support_um_1025.pkl
# movielens/meta_training/support_y_2494.pkl
# movielens/meta_training/query_umum_1150.pkl
# movielens/meta_training/query_umdm_1934.pkl
# movielens/meta_training/support_um_2744.pkl
# movielens/meta_training/support_y_1814.pkl
# movielens/meta_training/query_umdm_2325.pkl
# movielens/meta_training/query_um_1473.pkl
# movielens/meta_training/support_umum_1346.pkl
# movielens/meta_training/support_um_2253.pkl
# movielens/meta_training/support_umdm_2664.pkl
# movielens/meta_training/query_x_2091.pkl
# movielens/meta_training/support_um_2564.pkl
# movielens/meta_training/query_umum_1612.pkl
# movielens/meta_training/support_umam_1546.pkl
# movielens/meta_training/query_y_1694.pkl
# movielens/meta_training/query_umum_471.pkl
# movielens/meta_training/query_umam_550.pkl
# movielens/meta_training/support_um_2448.pkl
# movielens/meta_training/query_um_1224.pkl
# movielens/meta_training/query_y_518.pkl
# movielens/meta_training/query_umam_117.pkl
# movielens/meta_training/support_umam_260.pkl
# movielens/meta_training/support_umdm_1790.pkl
# movielens/meta_training/query_x_521.pkl
# movielens/meta_training/query_um_658.pkl
# movielens/meta_training/query_x_320.pkl
# movielens/meta_training/support_umum_963.pkl
# movielens/meta_training/query_um_949.pkl
# movielens/meta_training/query_um_2086.pkl
# movielens/meta_training/support_umum_1483.pkl
# movielens/meta_training/query_umam_1972.pkl
# movielens/meta_training/query_um_2378.pkl
# movielens/meta_training/query_um_492.pkl
# movielens/meta_training/support_x_2028.pkl
# movielens/meta_training/query_x_1454.pkl
# movielens/meta_training/support_umdm_988.pkl
# movielens/meta_training/support_umam_17.pkl
# movielens/meta_training/support_umum_719.pkl
# movielens/meta_training/query_x_2096.pkl
# movielens/meta_training/query_um_991.pkl
# movielens/meta_training/query_um_313.pkl
# movielens/meta_training/query_umdm_2201.pkl
# movielens/meta_training/support_um_874.pkl
# movielens/meta_training/support_um_2305.pkl
# movielens/meta_training/query_umam_1380.pkl
# movielens/meta_training/query_y_2579.pkl
# movielens/meta_training/query_y_993.pkl
# movielens/meta_training/query_umum_488.pkl
# movielens/meta_training/query_umam_2009.pkl
# movielens/meta_training/support_umam_1693.pkl
# movielens/meta_training/query_y_762.pkl
# movielens/meta_training/query_um_2280.pkl
# movielens/meta_training/query_umum_437.pkl
# movielens/meta_training/query_um_987.pkl
# movielens/meta_training/support_umam_264.pkl
# movielens/meta_training/support_umam_529.pkl
# movielens/meta_training/query_x_890.pkl
# movielens/meta_training/support_umum_2147.pkl
# movielens/meta_training/query_um_645.pkl
# movielens/meta_training/query_x_2747.pkl
# movielens/meta_training/support_um_1282.pkl
# movielens/meta_training/query_um_319.pkl
# movielens/meta_training/query_umdm_1340.pkl
# movielens/meta_training/query_y_427.pkl
# movielens/meta_training/support_umam_1979.pkl
# movielens/meta_training/query_x_1976.pkl
# movielens/meta_training/support_y_2132.pkl
# movielens/meta_training/support_umum_1903.pkl
# movielens/meta_training/support_y_2510.pkl
# movielens/meta_training/support_umum_1070.pkl
# movielens/meta_training/query_x_2315.pkl
# movielens/meta_training/support_umdm_2604.pkl
# movielens/meta_training/support_x_2267.pkl
# movielens/meta_training/support_x_417.pkl
# movielens/meta_training/query_umum_519.pkl
# movielens/meta_training/query_umdm_2473.pkl
# movielens/meta_training/query_y_2618.pkl
# movielens/meta_training/query_y_146.pkl
# movielens/meta_training/support_umum_2651.pkl
# movielens/meta_training/support_y_2742.pkl
# movielens/meta_training/support_umdm_507.pkl
# movielens/meta_training/support_y_2659.pkl
# movielens/meta_training/query_umam_1857.pkl
# movielens/meta_training/support_um_2029.pkl
# movielens/meta_training/support_y_2373.pkl
# movielens/meta_training/query_um_2275.pkl
# movielens/meta_training/query_umam_809.pkl
# movielens/meta_training/support_umam_1027.pkl
# movielens/meta_training/query_umdm_1289.pkl
# movielens/meta_training/query_y_1749.pkl
# movielens/meta_training/query_umum_208.pkl
# movielens/meta_training/query_umum_1206.pkl
# movielens/meta_training/support_x_1106.pkl
# movielens/meta_training/query_umam_1781.pkl
# movielens/meta_training/query_um_234.pkl
# movielens/meta_training/support_umdm_2688.pkl
# movielens/meta_training/support_umam_615.pkl
# movielens/meta_training/support_um_1808.pkl
# movielens/meta_training/query_y_1761.pkl
# movielens/meta_training/query_y_1807.pkl
# movielens/meta_training/support_um_33.pkl
# movielens/meta_training/query_x_1165.pkl
# movielens/meta_training/query_y_580.pkl
# movielens/meta_training/query_umdm_2175.pkl
# movielens/meta_training/support_umam_1733.pkl
# movielens/meta_training/query_y_2660.pkl
# movielens/meta_training/query_um_2342.pkl
# movielens/meta_training/query_x_763.pkl
# movielens/meta_training/support_um_2315.pkl
# movielens/meta_training/query_umum_569.pkl
# movielens/meta_training/support_x_2471.pkl
# movielens/meta_training/query_x_1044.pkl
# movielens/meta_training/support_umdm_285.pkl
# movielens/meta_training/support_um_1208.pkl
# movielens/meta_training/support_y_446.pkl
# movielens/meta_training/support_x_711.pkl
# movielens/meta_training/support_umum_1877.pkl
# movielens/meta_training/query_um_1885.pkl
# movielens/meta_training/query_x_1965.pkl
# movielens/meta_training/query_umum_2718.pkl
# movielens/meta_training/support_umum_1396.pkl
# movielens/meta_training/query_umum_2706.pkl
# movielens/meta_training/support_y_1113.pkl
# movielens/meta_training/support_umum_1945.pkl
# movielens/meta_training/support_x_756.pkl
# movielens/meta_training/support_umam_1184.pkl
# movielens/meta_training/support_umum_2233.pkl
# movielens/meta_training/support_y_687.pkl
# movielens/meta_training/support_y_813.pkl
# movielens/meta_training/support_umam_2153.pkl
# movielens/meta_training/support_umum_1582.pkl
# movielens/meta_training/query_umum_1496.pkl
# movielens/meta_training/support_um_2384.pkl
# movielens/meta_training/query_umdm_711.pkl
# movielens/meta_training/query_y_740.pkl
# movielens/meta_training/query_umam_1196.pkl
# movielens/meta_training/query_y_1293.pkl
# movielens/meta_training/support_x_2081.pkl
# movielens/meta_training/query_umam_2280.pkl
# movielens/meta_training/query_y_236.pkl
# movielens/meta_training/query_umdm_959.pkl
# movielens/meta_training/query_y_953.pkl
# movielens/meta_training/support_umum_2138.pkl
# movielens/meta_training/query_um_2672.pkl
# movielens/meta_training/support_um_2725.pkl
# movielens/meta_training/support_umdm_2570.pkl
# movielens/meta_training/query_um_2524.pkl
# movielens/meta_training/query_umum_185.pkl
# movielens/meta_training/support_umum_2380.pkl
# movielens/meta_training/support_y_1056.pkl
# movielens/meta_training/support_umum_1868.pkl
# movielens/meta_training/support_y_317.pkl
# movielens/meta_training/query_umdm_1929.pkl
# movielens/meta_training/support_um_1046.pkl
# movielens/meta_training/query_x_2494.pkl
# movielens/meta_training/query_um_1396.pkl
# movielens/meta_training/query_umam_750.pkl
# movielens/meta_training/support_um_1422.pkl
# movielens/meta_training/query_umam_1970.pkl
# movielens/meta_training/query_umdm_638.pkl
# movielens/meta_training/query_um_505.pkl
# movielens/meta_training/query_umam_914.pkl
# movielens/meta_training/support_umam_1182.pkl
# movielens/meta_training/support_um_2132.pkl
# movielens/meta_training/support_um_189.pkl
# movielens/meta_training/query_x_467.pkl
# movielens/meta_training/query_x_1087.pkl
# movielens/meta_training/query_umam_186.pkl
# movielens/meta_training/support_um_557.pkl
# movielens/meta_training/query_umam_926.pkl
# movielens/meta_training/support_y_1271.pkl
# movielens/meta_training/support_um_1051.pkl
# movielens/meta_training/support_um_471.pkl
# movielens/meta_training/query_umam_1736.pkl
# movielens/meta_training/query_um_22.pkl
# movielens/meta_training/query_um_697.pkl
# movielens/meta_training/support_y_2581.pkl
# movielens/meta_training/support_y_1137.pkl
# movielens/meta_training/query_um_2079.pkl
# movielens/meta_training/support_x_2467.pkl
# movielens/meta_training/support_umum_1309.pkl
# movielens/meta_training/query_umum_1209.pkl
# movielens/meta_training/support_x_1793.pkl
# movielens/meta_training/query_umdm_25.pkl
# movielens/meta_training/support_x_1134.pkl
# movielens/meta_training/query_um_2083.pkl
# movielens/meta_training/support_umum_1601.pkl
# movielens/meta_training/support_y_2052.pkl
# movielens/meta_training/query_umum_1406.pkl
# movielens/meta_training/support_y_1650.pkl
# movielens/meta_training/support_x_786.pkl
# movielens/meta_training/support_um_2096.pkl
# movielens/meta_training/query_y_2105.pkl
# movielens/meta_training/query_x_2296.pkl
# movielens/meta_training/query_x_2569.pkl
# movielens/meta_training/support_y_585.pkl
# movielens/meta_training/support_umam_192.pkl
# movielens/meta_training/support_umam_1692.pkl
# movielens/meta_training/support_umdm_1955.pkl
# movielens/meta_training/query_um_692.pkl
# movielens/meta_training/support_umam_484.pkl
# movielens/meta_training/support_y_950.pkl
# movielens/meta_training/query_umdm_1590.pkl
# movielens/meta_training/support_umam_1867.pkl
# movielens/meta_training/query_y_86.pkl
# movielens/meta_training/query_umdm_1683.pkl
# movielens/meta_training/query_umdm_1028.pkl
# movielens/meta_training/support_umum_260.pkl
# movielens/meta_training/query_umam_2742.pkl
# movielens/meta_training/query_y_1221.pkl
# movielens/meta_training/support_umum_1695.pkl

# %%
import gc
import glob
import random
import time
import numpy as np
import torch
from HeteML_new import HML
from DataHelper import DataHelper
from tqdm.notebook import tqdm
# from Config import states
# random.seed(13)
np.random.seed(13)
torch.manual_seed(13)


def training(model, model_save=True, model_file=None, device='cpu'):
    print('training model...')
    if config['use_cuda']:
        model.cuda()
    model.train()

    batch_size = config['batch_size']
    num_epoch = config['num_epoch']

    for _ in range(num_epoch):  # 20
        loss, mae, rmse = [], [], []
        ndcg_at_5 = []
        start = time.time()

        random.shuffle(train_data)
        num_batch = int(len(train_data) / batch_size)  # ~80
        supp_xs_s, supp_ys_s, supp_mps_s, query_xs_s, query_ys_s, query_mps_s = zip(*train_data)  # supp_um_s:(list,list,...,2553)
        for i in range(num_batch):  # each batch contains some tasks (each task contains a support set and a query set)
            support_xs = list(supp_xs_s[batch_size * i:batch_size * (i + 1)])
            support_ys = list(supp_ys_s[batch_size * i:batch_size * (i + 1)])
            support_mps = list(supp_mps_s[batch_size * i:batch_size * (i + 1)])
            query_xs = list(query_xs_s[batch_size * i:batch_size * (i + 1)])
            query_ys = list(query_ys_s[batch_size * i:batch_size * (i + 1)])
            query_mps = list(query_mps_s[batch_size * i:batch_size * (i + 1)])

            _loss, _mae, _rmse, _ndcg_5 = model.global_update(support_xs,support_ys,support_mps,
                                                              query_xs,query_ys,query_mps,device)
            loss.append(_loss)
            mae.append(_mae)
            rmse.append(_rmse)
            ndcg_at_5.append(_ndcg_5)

        print('epoch: {}, loss: {:.6f}, cost time: {:.1f}s, mae: {:.5f}, rmse: {:.5f}, ndcg@5: {:.5f}'.
              format(_, np.mean(loss), time.time() - start,
                     np.mean(mae), np.mean(rmse), np.mean(ndcg_at_5)))
        if _ % 10 == 0 and _ != 0:
            testing(model, device)
            model.train()

    if model_save:
        print('saving model...')
        torch.save(model.state_dict(), model_file)


def testing(model, device='cpu'):
    # testing
    print('evaluating model...')
    if config['use_cuda']:
        model.cuda()
    model.eval()
    for state in states:
        if state == 'meta_training':
            continue
        print(state + '...')
        evaluate(model, state, device)


def evaluate(model, state, device='cpu'):
    test_data = data_helper.load_data(data_set=data_set, state=state,
                                      load_from_file=True)
    supp_xs_s, supp_ys_s, supp_mps_s, query_xs_s, query_ys_s, query_mps_s = zip(*test_data)  # supp_um_s:(list,list,...,2553)
    loss, mae, rmse = [], [], []
    ndcg_at_5 = []

    for i in range(len(test_data)):  # each task
        _mae, _rmse, _ndcg_5 = model.evaluation(supp_xs_s[i], supp_ys_s[i], supp_mps_s[i],
                                                query_xs_s[i], query_ys_s[i], query_mps_s[i],device)
        mae.append(_mae)
        rmse.append(_rmse)
        ndcg_at_5.append(_ndcg_5)
    print('mae: {:.5f}, rmse: {:.5f}, ndcg@5: {:.5f}'.
          format(np.mean(mae), np.mean(rmse),np.mean(ndcg_at_5)))

    # print('fine tuning...')
    # model.train()
    # for i in range(len(test_data)):
    #     model.fine_tune(supp_xs_s[i], supp_ys_s[i], supp_mps_s[i])
    # model.eval()
    # for i in range(len(test_data)):  # each task
    #     _mae, _rmse, _ndcg_5 = model.evaluation(supp_xs_s[i], supp_ys_s[i], supp_mps_s[i],
    #                                             query_xs_s[i], query_ys_s[i], query_mps_s[i],device)
    #     mae.append(_mae)
    #     rmse.append(_rmse)
    #     ndcg_at_5.append(_ndcg_5)
    # print('mae: {:.5f}, rmse: {:.5f}, ndcg@5: {:.5f}'.
    #       format(np.mean(mae), np.mean(rmse), np.mean(ndcg_at_5)))


if __name__ == "__main__":
    # data_set = 'dbook'
    data_set = 'movielens'
    # data_set = 'yelp'

    input_dir = '../data/'
    output_dir = '../data/'
    res_dir = '../res/'+data_set
    load_model = False

    if data_set == 'movielens':
        from Config import config_ml as config
    elif data_set == 'yelp':
        from Config import config_yelp as config
    elif data_set == 'dbook':
        from Config import config_db as config
    cuda_or_cpu = torch.device("cuda" if config['use_cuda'] else "cpu")
    print (time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    print(config)

    model_filename = "{}/hml.pkl".format(res_dir)
    data_helper = DataHelper(input_dir, output_dir, config)

    # training model.
    model_name = 'mp_update'
    # model_name = 'mp_MAML'
    # model_name = 'mp_update_multi_MAML'
    # model_name = 'mp_update_no_f'
    # model_name = 'no_MAML'
    # model_name = 'no_MAML_with_finetuning'
    hml = HML(config, model_name)

    print('--------------- {} ---------------'.format(model_name))

    if not load_model:
        # Load training dataset
        print('loading train data...')
        train_data = data_helper.load_data(data_set=data_set,state='meta_training',load_from_file=True)
        # print('loading warm data...')
        # warm_data = data_helper.load_data(data_set=data_set, state='warm_up',load_from_file=True)
        training(hml, model_save=True, model_file=model_filename,device=cuda_or_cpu)
    else:
        trained_state_dict = torch.load(model_filename)
        hml.load_state_dict(trained_state_dict)

    # testing
    testing(hml, device=cuda_or_cpu)
    print('--------------- {} ---------------'.format(model_name))
# Out:
# 2021-11-01 09:25:26
# {'dataset': 'movielens', 'mp': ['um', 'umum', 'umam', 'umdm'], 'use_cuda': True, 'file_num': 12, 'num_rate': 6, 'num_genre': 25, 'num_fea_item': 2, 'item_fea_len': 26, 'num_gender': 2, 'num_age': 7, 'num_occupation': 21, 'num_zipcode': 3402, 'num_fea_user': 4, 'embedding_dim': 32, 'user_embedding_dim': 128, 'item_embedding_dim': 64, 'first_fc_hidden_dim': 64, 'second_fc_hidden_dim': 64, 'mp_update': 1, 'local_update': 1, 'lr': 0.0005, 'mp_lr': 0.005, 'local_lr': 0.005, 'batch_size': 32, 'num_epoch': 100, 'neigh_agg': 'mean', 'mp_agg': 'mean'}
# --------------- mp_update ---------------
# loading train data...
# 0it [00:00, ?it/s]
# #support set: 0, #query set: 0
# training model...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-cbe590150c44> in <module>()
#     142         # print('loading warm data...')
#     143         # warm_data = data_helper.load_data(data_set=data_set, state='warm_up',load_from_file=True)
# --> 144         training(hml, model_save=True, model_file=model_filename,device=cuda_or_cpu)
#     145     else:
#     146         trained_state_dict = torch.load(model_filename)
#
# <ipython-input-5-cbe590150c44> in training(model, model_save, model_file, device)
#      30         random.shuffle(train_data)
#      31         num_batch = int(len(train_data) / batch_size)  # ~80
# ---> 32         supp_xs_s, supp_ys_s, supp_mps_s, query_xs_s, query_ys_s, query_mps_s = zip(*train_data)  # supp_um_s:(list,list,...,2553)
#      33         for i in range(num_batch):  # each batch contains some tasks (each task contains a support set and a query set)
#      34             support_xs = list(supp_xs_s[batch_size * i:batch_size * (i + 1)])
#
# ValueError: not enough values to unpack (expected 6, got 0)
