# %%
# !git clone https://github.com/rapidsai/deeplearning.git
# Out:
# Cloning into 'deeplearning'...
# remote: Enumerating objects: 566, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 566 (delta 6), reused 26 (delta 4), pack-reused 536
# Receiving objects: 100% (566/566), 4.32 MiB | 33.74 MiB/s, done.
# Resolving deltas: 100% (272/272), done.

# %%
# !zip -r rapidsai.zip /content/deeplearning/WSDM2021/*
# Out:
# updating: content/deeplearning/WSDM2021/00_Data/ (stored 0%)
# updating: content/deeplearning/WSDM2021/01_Preprocess/ (stored 0%)
# updating: content/deeplearning/WSDM2021/02_Models/ (stored 0%)
# updating: content/deeplearning/WSDM2021/03_Ensemble/ (stored 0%)
# updating: content/deeplearning/WSDM2021/CLA.md (deflated 61%)
# updating: content/deeplearning/WSDM2021/img/ (stored 0%)
# updating: content/deeplearning/WSDM2021/LICENSE (deflated 41%)
# updating: content/deeplearning/WSDM2021/README.md (deflated 58%)
#   adding: content/deeplearning/WSDM2021/00_Data/.gitkeep (stored 0%)
#   adding: content/deeplearning/WSDM2021/01_Preprocess/Preprocess.ipynb (deflated 89%)
#   adding: content/deeplearning/WSDM2021/02_Models/XLNet_SMF/ (stored 0%)
#   adding: content/deeplearning/WSDM2021/02_Models/XLNet_SMF/.git_keep (stored 0%)
#   adding: content/deeplearning/WSDM2021/02_Models/GRU_MS_SMF/ (stored 0%)
#   adding: content/deeplearning/WSDM2021/02_Models/GRU_MS_SMF/GRU-MS-SMF-Ensemble.ipynb (deflated 79%)
#   adding: content/deeplearning/WSDM2021/02_Models/GRU_MS_SMF/GRU-MS-SMF.ipynb (deflated 78%)
#   adding: content/deeplearning/WSDM2021/02_Models/MLP_SMF/ (stored 0%)
#   adding: content/deeplearning/WSDM2021/02_Models/MLP_SMF/MLP-SMF-Ensemble.ipynb (deflated 77%)
#   adding: content/deeplearning/WSDM2021/02_Models/MLP_SMF/MLP-SMF.ipynb (deflated 82%)
#   adding: content/deeplearning/WSDM2021/03_Ensemble/Ensemble.ipynb (deflated 77%)
#   adding: content/deeplearning/WSDM2021/img/mlp-smf.png (deflated 14%)
#   adding: content/deeplearning/WSDM2021/img/gru-ms-smf.png (deflated 11%)
#   adding: content/deeplearning/WSDM2021/img/xlnet-smf.png (deflated 14%)
