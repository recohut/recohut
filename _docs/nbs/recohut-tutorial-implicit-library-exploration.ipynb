# %%
# !pip install implicit
# Out:
# ...
#      |████████████████████████████████| 1.1MB 29.3MB/s
# ...
#   Created wheel for implicit: filename=implicit-0.4.4-cp37-cp37m-linux_x86_64.whl size=3406333 sha256=60bd1461597bed48e369a47ecee5346f7394cd94278dafd0eb5bf4b374b6a857
#   Stored in directory: /root/.cache/pip/wheels/bf/d4/ec/fd4f622fcbefb7521f149905295b2c26adecb23af38aa28217
# Successfully built implicit
# ...
