# %%
# %%writefile requirements.txt
#
# appnope==0.1.0
# backcall==0.1.0
# boto==2.49.0
# boto3==1.10.26
# botocore==1.13.26
# certifi==2019.9.11
# chardet==3.0.4
# cPython==0.0.5
# decorator==4.4.1
# docutils==0.15.2
# gensim==3.8.1
# idna==2.8
# ipykernel==5.1.3
# ipython==7.9.0
# ipython-genutils==0.2.0
# jedi==0.15.1
# jmespath==0.9.4
# joblib==0.14.0
# jupyter-client==5.3.4
# jupyter-core==4.6.1
# networkx==2.4
# node2vec==0.3.1
# numpy==1.17.3
# pandas==0.25.3
# parso==0.5.1
# pexpect==4.7.0
# pickleshare==0.7.5
# prompt-toolkit==2.0.10
# ptyprocess==0.6.0
# Pygments==2.7.4
# pymongo==3.9.0
# python-dateutil==2.8.0
# pytz==2019.3
# pyzmq==18.1.0
# requests==2.22.0
# s3transfer==0.2.1
# scikit-learn==0.21.3
# scipy==1.3.1
# six==1.13.0
# smart-open==1.9.0
# tornado==6.0.3
# tqdm==4.39.0
# traitlets==4.3.3
# urllib3==1.25.8
# wcwidth==0.1.7
# Out:
# Writing requirements.txt

# %%
# !pip install -r requirements.txt

# %%
# !wget http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/meta_Books.json.gz
# !wget http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/meta_Electronics.json.gz
# Out:
# --2021-05-17 14:13:03--  http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/meta_Electronics.json.gz
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 186594679 (178M) [application/x-gzip]
# Saving to: ‘meta_Electronics.json.gz’
#
# meta_Electronics.js 100%[===================>] 177.95M   939KB/s    in 2m 2s
#
# 2021-05-17 14:15:05 (1.46 MB/s) - ‘meta_Electronics.json.gz’ saved [186594679/186594679]

# %%
import logging

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(message)s')

# create console handler and set level to info
ch = logging.StreamHandler()
ch.setFormatter(formatter)
ch.setLevel(logging.INFO)

# add ch to logger
logger.addHandler(ch)

# %%
DATA_PATH = './'
MODEL_PATH = './'

# %%
"""
Parses the raw json data into csv file for faster loading into pd.DataFrame.
"""
import argparse
import csv
import gzip
from typing import List

import numpy as np
import pandas as pd
from pandas.api.types import is_object_dtype


def parse(path: str):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)


def parse_json_to_df(path: str) -> pd.DataFrame:
    i = 0
    df_dict = {}
    for d in parse(path):
        df_dict[i] = d
        i += 1
        if i % 10000 == 0:
            logger.info('Rows processed: {:,}'.format(i))

    df = pd.DataFrame.from_dict(df_dict, orient='index')

    # Lowercase
    df['related'] = df['related'].astype(str)
    df['categories'] = df['categories'].astype(str)
    df['salesRank'] = df['salesRank'].astype(str)
    df = lowercase_df(df)

    return df


# Lowercase Functions
def lowercase_df(df: pd.DataFrame) -> pd.DataFrame:
    """
    Lowercase characters from all columns in a dataframe.

    Args:
        df: Pandas dataframe

    Returns:
        Lowercased dataframe
    """
    df = df.copy()
    for col in df.columns:
        if is_object_dtype(df[col]):
            df = lowercase_cols(df, [col])
    return df


def lowercase_cols(df: pd.DataFrame, colnames: List[str]) -> pd.DataFrame:
    """
    Lowercase characters from specified columns in a dataframe

    Args:
        df: Pandas dataframe
        colnames (List): Names of columns to be lowercased

    Returns: Lowercased dataframe

    """
    df = df.copy()
    for col in colnames:
        assert df[col].dtype != np.float64 and df[col].dtype != np.int64, \
            'Trying to lowercase a non-string column: {}'.format(col)
        df[col] = df[col].str.lower()
    return df


def parse_json_to_csv(read_path: str, write_path: str) -> None:
    """
    Note: This assumes that the first json in the path has all the keys, which could be WRONG

    Args:
        read_path:
        write_path:

    Returns:

    """
    csv_writer = csv.writer(open(write_path, 'w'))
    i = 0
    for d in parse(read_path):
        if i == 0:
            header = d.keys()
            csv_writer.writerow(header)

        csv_writer.writerow(d.values().lower())
        i += 1
        if i % 10000 == 0:
            logger.info('Rows processed: {:,}'.format(i))

    logger.info('Csv saved to {}'.format(write_path))

# %%
read_path = 'meta_Electronics.json.gz'
write_path = 'electronics.csv'

df = parse_json_to_df(read_path)
df.to_csv(write_path, index=False)
logger.info('Csv saved to {}'.format(write_path))

# %%
"""
Parses item to item relationships in 'related' field and explodes it such that each relationship is a single row.
"""
import argparse

import numpy as np
import pandas as pd


def get_also_bought_count(related):
    try:
        return len(related['also_bought'])
    except KeyError:
        return -1


def explode_on_related(df: pd.DataFrame, relationship: str) -> pd.DataFrame:
    # Filter on relationship
    df = df[df['related'].apply(lambda x: relationship in x.keys())].copy()

    # Get value (list) from relationship dict
    df['related'] = df['related'].apply(lambda x: x[relationship])

    # Explode efficiently using numpy
    vals = df['related'].values.tolist()
    lens = [len(val_list) for val_list in vals]
    vals_array = np.repeat(df['asin'], lens)
    exploded_df = pd.DataFrame(np.column_stack((vals_array, np.concatenate(vals))), columns=df.columns)

    # Add relationship
    exploded_df['relationship'] = relationship
    logger.info('Exploded for relationship: {}'.format(relationship))

    return exploded_df


def get_node_relationship(df: pd.DataFrame) -> pd.DataFrame:
    """
    Returns a dataframe of products and their relationships (e.g., bought together, also bought, also viewed)
    """
    # Keep only rows with related data
    df = df[~df['related'].isnull()].copy()
    logger.info('DF shape after dropping empty related: {}'.format(df.shape))

    df = df[~df['title'].isnull()].copy()
    logger.info('DF shape after dropping empty title: {}'.format(df.shape))
    df = df[['asin', 'related']].copy()

    # Evaluate related str into dict
    df['related'] = df['related'].apply(eval)
    logger.info('Completed eval on "related" string')

    # Exclude products where also bought relationships less than 2
    df['also_bought_count'] = df['related'].apply(get_also_bought_count)
    df = df[df['also_bought_count'] >= 2].copy()
    logger.info('DF shape after dropping products with <2 edges: {}'.format(df.shape))
    df.drop(columns='also_bought_count', inplace=True)

    # Explode columns
    bought_together_df = explode_on_related(df, relationship='bought_together')
    also_bought_df = explode_on_related(df, relationship='also_bought')
    also_viewed_df = explode_on_related(df, relationship='also_viewed')

    # Concatenate df
    combined_df = pd.concat([bought_together_df, also_bought_df, also_viewed_df], axis=0)
    logger.info('Distribution of relationships: \n{}'.format(combined_df['relationship'].value_counts()))

    return combined_df

# %%
read_path = 'electronics.csv'
write_path = 'electronics_relationships.csv'

df = pd.read_csv(read_path, error_bad_lines=False, warn_bad_lines=True,
                  dtype={'asin': 'str', 'title': 'str', 'brand': 'str'})
logger.info('DF shape: {}'.format(df.shape))

exploded_df = get_node_relationship(df)

exploded_df.to_csv(write_path, index=False)
logger.info('Csv saved to {}'.format(write_path))
# Out:
# 2021-05-17 14:24:25,441 - DF shape: (498196, 9)
# 2021-05-17 14:24:25,646 - DF shape after dropping empty related: (366959, 9)
# 2021-05-17 14:24:25,832 - DF shape after dropping empty title: (362142, 9)
# 2021-05-17 14:24:49,287 - Completed eval on "related" string
# 2021-05-17 14:24:49,795 - DF shape after dropping products with <2 edges: (129415, 3)
# 2021-05-17 14:24:50,261 - Exploded for relationship: bought_together
# 2021-05-17 14:24:52,780 - Exploded for relationship: also_bought
# 2021-05-17 14:24:53,019 - Exploded for relationship: also_viewed
# 2021-05-17 14:24:53,816 - Distribution of relationships:
# also_bought        4398989
# also_viewed         276305
# bought_together     151941
# Name: relationship, dtype: int64
# 2021-05-17 14:25:02,765 - Csv saved to electronics_relationships.csv

# %%
"""
Parses out the metadata from the original csv.
"""
import argparse

import numpy as np
import pandas as pd


def get_category_lvl(category_list: list, lvl=0) -> str:
    try:
        return category_list[lvl]
    except IndexError:
        return 'NA_VALUE'


def get_categories(df: pd.DataFrame) -> pd.DataFrame:
    df['category_lvl_1'] = df['categories'].apply(get_category_lvl, args=(0,))
    df['category_lvl_2'] = df['categories'].apply(get_category_lvl, args=(1,))
    df['category_lvl_3'] = df['categories'].apply(get_category_lvl, args=(2,))
    df['category_lvl_4'] = df['categories'].apply(get_category_lvl, args=(3,))
    logger.info('Categories lvl 1 - 4 prepared')

    return df


def get_meta(df: pd.DataFrame) -> pd.DataFrame:
    # Update to reflect if relationship exist
    df['related'] = np.where(df['related'].isnull(), 0, 1)

    # Prep categories
    df['categories'] = df['categories'].apply(eval)
    df['categories'] = df['categories'].apply(lambda x: x[0])  # Get first category only
    df = get_categories(df)

    # Prep title and description
    # TODO: Add cleaning of title and description

    return df

# %%
read_path = 'electronics.csv'
write_path = 'electronics_meta.csv'

META_COLS = ['asin', 'categories', 'title', 'description', 'price', 'brand', 'related']
df = pd.read_csv(read_path, error_bad_lines=False, warn_bad_lines=True,
                  dtype={'asin': 'str', 'title': 'str', 'brand': 'str'},
                  usecols=META_COLS)
logger.info('DF shape: {}'.format(df.shape))

meta_df = get_meta(df)

meta_df.to_csv(write_path, index=False)
logger.info('Csv saved to {}'.format(write_path))
# Out:
# 2021-05-17 15:22:15,593 - DF shape: (498196, 7)
# 2021-05-17 15:22:24,407 - Categories lvl 1 - 4 prepared
# 2021-05-17 15:22:36,377 - Csv saved to electronics_meta.csv

# %%
"""
Converts edge relationships (e.g., bought together, also bought) to numeric weights between two nodes.
"""
import argparse

import numpy as np
import pandas as pd

relationship_weights = {'bought_together': 1.2,
                        'also_bought': 1.0,
                        'also_viewed': 0.5}


def create_product_pair(df, col_list):
    pairs = df[col_list].values
    pairs.sort(axis=1)
    df['product_pair'] = ['|'.join(arr) for arr in pairs]

    return df


def split_product_pair(product_pair):
    result = product_pair.split('|')
    return result[0], result[1]


def get_relationship_weights(df, relationship_weights):
    df['weight'] = 0
    for relationship, weight in relationship_weights.items():
        df.loc[df['relationship'] == relationship, 'weight'] += weight

    return df


def get_edges(df):
    """
    Returns a dataframe of products and the weights of the edges between them.

    Args:
        df:

    Returns:

    """
    logger.info('Relationship distribution: \n{}'.format(df['relationship'].value_counts()))

    df = create_product_pair(df, col_list=['asin', 'related'])
    logger.info('Product pairs created')

    df = get_relationship_weights(df, relationship_weights)
    logger.info('Relationship weights updated')

    # Aggregate to remove duplicates
    logger.info('Original no. of edges: {:,}'.format(df.shape[0]))
    df = df.groupby('product_pair').agg({'weight': 'sum'}).reset_index()
    logger.info('Deduplicated no. of edges: {:,}'.format(df.shape[0]))

    # Save edge list
    df['product1'], df['product2'] = zip(*df['product_pair'].apply(split_product_pair))

    df = df[['product1', 'product2', 'weight', 'product_pair']]
    return df

# %%
read_path = 'electronics_relationships.csv'
write_path = 'electronics_edges.csv'
sample_size = None

df = pd.read_csv(read_path, error_bad_lines=False, warn_bad_lines=True,
                  dtype={'asin': 'str', 'related': 'str'})
logger.info('DF shape: {}'.format(df.shape))

# Sample for development efficiency
if sample_size:
    sample_idx = np.random.choice(df.shape[0], size=sample_size, replace=False)
    df = df.iloc[sample_idx]

df = get_edges(df)

df.to_csv(write_path, index=False)
logger.info('Csv saved to {}'.format(write_path))
# Out:
# 2021-05-17 15:24:34,095 - DF shape: (4827235, 3)
# 2021-05-17 15:24:34,489 - Relationship distribution:
# also_bought        4398989
# also_viewed         276305
# bought_together     151941
# Name: relationship, dtype: int64
# 2021-05-17 15:24:41,288 - Product pairs created
# 2021-05-17 15:24:43,050 - Relationship weights updated
# 2021-05-17 15:24:43,052 - Original no. of edges: 4,827,235
# 2021-05-17 15:25:00,064 - Deduplicated no. of edges: 4,005,262
# 2021-05-17 15:25:24,635 - Csv saved to electronics_edges.csv

# %%
"""
Splits all ground truth edges into train and validation set, with some constraints
- The validation set should only contain edges where both products are in the train set

For the validation set, negative samples are created by randomly selecting a pair of nodes and creating a negative edge.
- From these samples, we exclude valid edges from either the train or validation set.
"""
import argparse
from pathlib import Path
from typing import Tuple

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split


def train_val_split(df, n_val_samples: int, filter_out_unseen: bool = False) -> Tuple[pd.DataFrame, pd.DataFrame]:
    if filter_out_unseen:
        # First split to get some test samples
        train, val = train_test_split(df, test_size=int(1.1 * n_val_samples), random_state=42)  # Need slightly more
        logger.info('Train shape: {}, val shape: {}'.format(train.shape, val.shape))

        # Get set of products in train
        train_product_set = set(train['product1']).union(set(train['product2']))
        logger.info('No. of unique products in train: {:,}'.format(len(train_product_set)))

        # Only keep val where both products are in train product set
        val = val[(val['product1'].isin(train_product_set)) & (val['product2'].isin(train_product_set))]
        logger.info('Updated val shape: {}'.format(val.shape))

        # Split again to only get n_val_samples
        val = val.iloc[:n_val_samples].copy()
        logger.info('Final val shape: {}'.format(val.shape))

        # Get train set
        train = df[~df.index.isin(set(val.index))].copy()
        logger.info('Final train shape: {}'.format(train.shape))

    else:
        # First split to get some test samples
        train, val = train_test_split(df, test_size=int(n_val_samples), random_state=42)
        logger.info('Train shape: {}, val shape: {}'.format(train.shape, val.shape))

    return train, val


def get_sample(item_array, n_iter=None, sample_size=2):
    np.random.seed(42)
    n = len(item_array)

    # find the index we last sampled from
    start_idx = (n_iter * sample_size) % n
    if (start_idx + sample_size >= n) or (start_idx <= sample_size):
        # shuffle array if we have reached the end and repeat again
        np.random.shuffle(item_array)

    return item_array[start_idx:start_idx + sample_size]


def collect_samples(item_array, sample_size, n_samples):
    samples = []

    for i in range(0, n_samples):
        if i % 1000000 == 0:
            logger.info('Neg sample: {:,}'.format(i))

        sample = get_sample(item_array, n_iter=i, sample_size=sample_size)
        samples.append(sample)

    return samples


def create_negative_edges(df, val, n_val_samples):
    # Get set of valid product edges (across both train and val)
    valid_product_pairs = set(df['product_pair'])
    logger.info('No. of valid product pairs: {:,}'.format(len(valid_product_pairs)))

    # Get set of products in val (to generate edges)
    val_product_arr = np.array(list(set(val['product1']).union(set(val['product2']))))
    logger.info('No. of unique products in val: {:,}'.format(len(val_product_arr)))

    # Create negative samples
    neg_samples = collect_samples(val_product_arr, sample_size=2, n_samples=int(1.1 * n_val_samples))
    neg_samples_df = pd.DataFrame(neg_samples, columns=['product1', 'product2'])
    neg_samples_df.dropna(inplace=True)
    neg_samples_df = create_product_pair(neg_samples_df, col_list=['product1', 'product2'])
    logger.info('No. of negative samples: {:,}'.format(neg_samples_df.shape[0]))

    # Exclude neg samples that are valid pairs
    neg_samples_df = neg_samples_df[~neg_samples_df['product_pair'].isin(valid_product_pairs)].copy()
    logger.info('Updated no. of negative samples: {:,}'.format(neg_samples_df.shape[0]))

    # Only keep no. of val samples required
    neg_samples_df = neg_samples_df.iloc[:n_val_samples].copy()
    logger.info('Final no. of negative samples: {:,}'.format(neg_samples_df.shape[0]))

    return neg_samples_df


def combine_val_and_neg_edges(val, neg_samples):
    neg_samples['edge'] = 0
    val['edge'] = 1

    VAL_COLS = ['product1', 'product2', 'edge']
    neg = neg_samples[VAL_COLS].copy()
    val = val[VAL_COLS].copy()
    logger.info('Val shape: {}, Neg edges shape: {}, Ratio: {}'.format(val.shape, neg.shape,
                                                                       val.shape[0] / (val.shape[0] + neg.shape[0])))

    val = pd.concat([val, neg])
    logger.info('Final val shape: {}'.format(val.shape))

    return val


def get_train_and_val(df, val_prop: float):
    """
    Splits into training and validation set, where validation set has 50% negative edges

    Args:
        df:
        val_prop:

    Returns:

    """
    n_val_samples = int(val_prop * df.shape[0])
    logger.info('Eventual required val samples (proportion: {}): {:,}'.format(val_prop, n_val_samples))

    train, val = train_val_split(df, n_val_samples)
    logger.info('Ratio of train to val: {:,}:{:,} ({:.2f})'.format(train.shape[0], val.shape[0],
                                                                   val.shape[0] / (train.shape[0] + val.shape[0])))

    neg_samples = create_negative_edges(df, val, n_val_samples)

    val = combine_val_and_neg_edges(val, neg_samples)
    train = train[['product1', 'product2', 'weight']].copy()

    return train, val

# %%
read_path = 'electronics_edges.csv'
val_prop = 0.33
DATA_PATH = './'

df = pd.read_csv(read_path, error_bad_lines=False, warn_bad_lines=True,
                  dtype={'product1': 'str', 'product2': 'str'})
logger.info('DF shape: {}'.format(df.shape))

train, val = get_train_and_val(df, val_prop=val_prop)

# Save to train, val, and train edgelist
input_filename = Path(read_path).resolve().stem
train.to_csv('{}/{}_train.csv'.format(DATA_PATH, input_filename), index=False)
logger.info('Train saved as: {}/{}_train.csv'.format(DATA_PATH, input_filename))
val.to_csv('{}/{}_val.csv'.format(DATA_PATH, input_filename), index=False)
logger.info('Val saved as: {}/{}_val.csv'.format(DATA_PATH, input_filename))

train.to_csv('{}/{}_train.edgelist'.format(DATA_PATH, input_filename), sep=' ', index=False, header=False)
logger.info('Train edgelist saved as: {}/{}_train.edgelist'.format(DATA_PATH, input_filename))
# Out:
# 2021-05-17 15:31:14,498 - DF shape: (4005262, 4)
# 2021-05-17 15:31:14,501 - Eventual required val samples (proportion: 0.33): 1,321,736
# 2021-05-17 15:31:17,834 - Train shape: (2683526, 4), val shape: (1321736, 4)
# 2021-05-17 15:31:17,845 - Ratio of train to val: 2,683,526:1,321,736 (0.33)
# 2021-05-17 15:31:19,183 - No. of valid product pairs: 4,005,262
# 2021-05-17 15:31:20,561 - No. of unique products in val: 275,427
# 2021-05-17 15:31:20,563 - Neg sample: 0
# 2021-05-17 15:31:24,337 - Neg sample: 1,000,000
# 2021-05-17 15:31:31,111 - No. of negative samples: 1,453,904
# 2021-05-17 15:31:36,191 - Updated no. of negative samples: 1,453,794
# 2021-05-17 15:31:36,338 - Final no. of negative samples: 1,321,736
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2021-05-17 15:31:37,004 - Val shape: (1321736, 3), Neg edges shape: (1321736, 3), Ratio: 0.5
# 2021-05-17 15:31:37,182 - Final val shape: (2643472, 3)
# 2021-05-17 15:31:45,590 - Train saved as: .//electronics_edges_train.csv
# 2021-05-17 15:31:53,029 - Val saved as: .//electronics_edges_val.csv
# 2021-05-17 15:32:00,604 - Train edgelist saved as: .//electronics_edges_train.edgelist

# %%
import gzip
import pickle
from typing import Any


def save_model(model: Any, model_path: str) -> None:
    """
    Saves model in gzip format

    Args:
        model: Model to be saved
        model_path: Path to save model to

    Returns:
        (None)
    """
    with gzip.open(model_path, "wb") as f:
        pickle.dump(model, f)

    logger.info('Model saved to {}'.format(model_path))


def load_model(model_path: str) -> Any:
    """
    Loads model from gzip format

    Args:
        model_path: Path to load model from

    Returns:

    """
    with gzip.open(model_path, 'rb') as f:
        model = pickle.load(f)

    logger.info('Model loaded from: {}'.format(model_path))
    return model

# %%
"""
Builds a graph from the edges (training set) and performs random walk sampling from the graph
- Currently returns 10 samples of sequence length 10 for each node (this is a parameter in create_random_walk_samples)
"""
import argparse
import random

import networkx
import numpy as np
import scipy as sp


def load_network(edgelist_path):
    graph = networkx.read_weighted_edgelist(edgelist_path)
    logger.info('No of nodes ({:,}) and edges ({:,})'.format(graph.number_of_nodes(), graph.number_of_edges()))

    # Get dictionary mapping of integer to nodes
    node_dict = {i: key for i, key in enumerate(graph.nodes.keys())}

    return graph, node_dict


def create_transition_matrix(graph):
    """
    https://stackoverflow.com/questions/37311651/get-node-list-from-random-walk-in-networkx
    https://stackoverflow.com/questions/15330380/probability-to-visit-nodes-in-a-random-walk-on-graph

    Args:
        graph:

    Returns:

    """
    adjacency_mat = networkx.adj_matrix(graph)
    logger.info('Adjacency matrix shape: {}'.format(adjacency_mat.shape))
    graph = None

    degree_vector = sp.sparse.csr_matrix(1 / np.sum(adjacency_mat, axis=0))

    transition_matrix = adjacency_mat.multiply(degree_vector).T  # Need to transpose so each row probability sum to 1
    logger.info('Transition matrix shape: {}'.format(transition_matrix.shape))

    return transition_matrix


def create_transition_dict(transition_matrix):
    transition_dict = {}
    rows, cols = transition_matrix.nonzero()

    # Create dictionary of transition product and probabilities for each product
    prev_row = -1
    for row, col in zip(rows, cols):
        if row != prev_row:
            transition_dict.setdefault(row, {})
            transition_dict[row].setdefault('product', [])
            transition_dict[row].setdefault('probability', [])

        transition_dict[row]['product'].append(col)
        transition_dict[row]['probability'].append(transition_matrix[row, col])
        prev_row = row

    return transition_dict


def create_random_walk_samples(node_dict, transition_dict, samples_per_node=10, sequence_len=10):
    random.seed(42)
    n_nodes = len(node_dict)

    sample_array = np.zeros((n_nodes * samples_per_node, sequence_len), dtype=int)
    logger.info('Sample array shape: {}'.format(sample_array.shape))

    # For each node
    for node_idx in range(n_nodes):

        if node_idx % 100000 == 0:
            logger.info('Getting samples for node: {:,}/{:,}'.format(node_idx, n_nodes))

        # For each sample
        for sample_idx in range(samples_per_node):
            node = node_idx

            # For each event in sequence
            for seq_idx in range(sequence_len):
                sample_array[node_idx * samples_per_node + sample_idx, seq_idx] = node
                node = random.choices(population=transition_dict[node]['product'],
                                      weights=transition_dict[node]['probability'], k=1)[0]

    return sample_array


def get_samples(edgelist_path):
    graph, node_dict = load_network(edgelist_path)
    logger.info('Network loaded')

    transition_matrix = create_transition_matrix(graph)
    logger.info('Transition matrix created')
    graph = None

    transition_dict = create_transition_dict(transition_matrix)
    logger.info('Transition dict created')
    transition_matrix = None

    sample_array = create_random_walk_samples(node_dict, transition_dict)
    logger.info('Random walk samples created')

    # Convert array of nodeIDs back to product IDs
    sample_array = np.vectorize(node_dict.get)(sample_array)
    logger.info('Converted back to product IDs')

    return sample_array, node_dict, transition_dict

# %%
read_path = 'electronics_edges_train.edgelist'
write_path = 'electronics_sequences.npy'
DATA_PATH = './'
graph_name = 'electronics'

sample_array, node_dict, transition_dict = get_samples(read_path)

np.save(write_path, sample_array)
logger.info('Sample array saved to {}'.format(write_path))
sample_array = None

save_model(node_dict, '{}/{}_node_dict.tar.gz'.format(DATA_PATH, graph_name))
node_dict = None

save_model(transition_dict, '{}/{}_transition_dict.tar.gz'.format(DATA_PATH, graph_name))
transition_dict = None
# Out:
# 2021-05-17 15:35:38,462 - No of nodes (360,456) and edges (2,683,526)
# 2021-05-17 15:35:38,588 - Network loaded
# 2021-05-17 15:36:06,684 - Adjacency matrix shape: (360456, 360456)
# 2021-05-17 15:36:07,178 - Transition matrix shape: (360456, 360456)
# 2021-05-17 15:36:07,186 - Transition matrix created
# 2021-05-17 15:37:58,238 - Transition dict created
# 2021-05-17 15:37:58,354 - Sample array shape: (3604560, 10)
# 2021-05-17 15:37:58,356 - Getting samples for node: 0/360,456
# 2021-05-17 15:41:22,635 - Getting samples for node: 100,000/360,456
# 2021-05-17 15:44:11,941 - Getting samples for node: 200,000/360,456
# 2021-05-17 15:46:45,642 - Getting samples for node: 300,000/360,456
# 2021-05-17 15:48:10,506 - Random walk samples created
# 2021-05-17 15:48:55,386 - Converted back to product IDs
# 2021-05-17 15:49:00,713 - Sample array saved to electronics_sequences.npy
# 2021-05-17 15:49:05,168 - Model saved to .//electronics_node_dict.tar.gz
# 2021-05-17 15:52:37,583 - Model saved to .//electronics_transition_dict.tar.gz

# %%
# import networkx as nx
# from node2vec import Node2Vec


# def train_embeddings(edgelist_path, embedding_path):
#     # Create path
#     graph = nx.read_weighted_edgelist(edgelist_path)
#     logger.info('Graph created!')
#     assert graph.get_edge_data('0000013714', '0005064295')['weight'] == 3.2, 'Expected edge weight of 3.2'

#     # Precomput probabilities and generate walks
#     node2vec = Node2Vec(graph, dimensions=128, walk_length=30, num_walks=10, workers=10, temp_folder=DATA_PATH)
#     logger.info('Computed probabilities and generated walks')
#     graph = None  # We don't need graph anymore since probabilities have been precomputed

#     # Embed nodes
#     model = node2vec.fit(window=5, min_count=1, batch_words=128)
#     logger.info('Nodes embedded')

#     # Save embeddings for later use
#     model.wv.save_word2vec_format(embedding_path)
#     logger.info('Embedding saved')

# %%
# # Slow and requires a lot of ram
# read_path = 'electronics_edges_train.edgelist'
# write_path = 'electronics_embeddings.kv'

# train_embeddings(read_path, write_path)

# %%
import argparse
import datetime

import numpy as np
from gensim.models import Word2Vec


def load_sequences(sequence_path):
    """
    Expects a numpy array at sequence_path

    Args:
        sequence_path:

    Returns:

    """
    sequences = np.load(sequence_path)
    logger.info('Sequences shape: {}'.format(sequences.shape))

    # Convert sequences to string and list of list
    sequences = sequences.astype(str).tolist()

    return sequences


def train_embeddings(sequences, workers, dimension=128, window=5, min_count=1, negative=5, epochs=3, seed=42):
    # Logging specific to gensim training
    import logging
    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

    # Initialize model
    model = Word2Vec(sequences, workers=workers,
                     size=dimension, window=window, min_count=min_count, negative=negative, seed=seed)
    logger.info('Model initialized')

    # Train model (No need to retrain model as initialization includes training)
    # model.train(sequences, total_examples=len(sequences), epochs=epochs)
    # logger.info('Model trained!')

    return model


def save_model(model):
    # Save model and keyedvectors
    current_datetime = datetime.datetime.now().strftime('%Y-%m-%d-%H%M')
    model.save('{}/gensim-w2v-{}.model'.format(MODEL_PATH, current_datetime))
    model.wv.save('{}/gensim-w2v-{}.kv'.format(MODEL_PATH, current_datetime))

# %%
# Works fine with multiprocess
read_path = 'electronics_sequences.npy'
n_workers = 6

sequences = load_sequences(read_path)

start_time = datetime.datetime.now()
model = train_embeddings(sequences, workers=n_workers)
end_time = datetime.datetime.now()
time_diff = round((end_time - start_time).total_seconds() / 60, 2)
logger.info('Total time taken: {:,} minutes'.format(time_diff))
save_model(model)
# Out:
# 2021-05-17 16:00:35,832 - Sequences shape: (3604560, 10)
# 2021-05-17 16:00:57,494 : INFO : collecting all words and their counts
# 2021-05-17 16:00:57,496 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-05-17 16:00:57,540 : INFO : PROGRESS: at sentence #10000, processed 100000 words, keeping 47795 word types
# 2021-05-17 16:00:57,587 : INFO : PROGRESS: at sentence #20000, processed 200000 words, keeping 73561 word types
# 2021-05-17 16:00:57,632 : INFO : PROGRESS: at sentence #30000, processed 300000 words, keeping 91774 word types
# 2021-05-17 16:00:57,677 : INFO : PROGRESS: at sentence #40000, processed 400000 words, keeping 106323 word types
# 2021-05-17 16:00:57,723 : INFO : PROGRESS: at sentence #50000, processed 500000 words, keeping 118032 word types
# 2021-05-17 16:00:57,768 : INFO : PROGRESS: at sentence #60000, processed 600000 words, keeping 127863 word types
# 2021-05-17 16:00:57,818 : INFO : PROGRESS: at sentence #70000, processed 700000 words, keeping 136588 word types
# 2021-05-17 16:00:57,867 : INFO : PROGRESS: at sentence #80000, processed 800000 words, keeping 144471 word types
# 2021-05-17 16:00:57,916 : INFO : PROGRESS: at sentence #90000, processed 900000 words, keeping 151521 word types
# 2021-05-17 16:00:57,966 : INFO : PROGRESS: at sentence #100000, processed 1000000 words, keeping 158063 word types
# 2021-05-17 16:00:58,012 : INFO : PROGRESS: at sentence #110000, processed 1100000 words, keeping 163719 word types
# 2021-05-17 16:00:58,059 : INFO : PROGRESS: at sentence #120000, processed 1200000 words, keeping 169295 word types
# 2021-05-17 16:00:58,106 : INFO : PROGRESS: at sentence #130000, processed 1300000 words, keeping 174493 word types
# 2021-05-17 16:00:58,166 : INFO : PROGRESS: at sentence #140000, processed 1400000 words, keeping 179661 word types
# 2021-05-17 16:00:58,219 : INFO : PROGRESS: at sentence #150000, processed 1500000 words, keeping 184393 word types
# 2021-05-17 16:00:58,269 : INFO : PROGRESS: at sentence #160000, processed 1600000 words, keeping 188923 word types
# 2021-05-17 16:00:58,319 : INFO : PROGRESS: at sentence #170000, processed 1700000 words, keeping 193021 word types
# 2021-05-17 16:00:58,371 : INFO : PROGRESS: at sentence #180000, processed 1800000 words, keeping 196960 word types
# 2021-05-17 16:00:58,424 : INFO : PROGRESS: at sentence #190000, processed 1900000 words, keeping 200862 word types
# 2021-05-17 16:00:58,474 : INFO : PROGRESS: at sentence #200000, processed 2000000 words, keeping 204243 word types
# 2021-05-17 16:00:58,526 : INFO : PROGRESS: at sentence #210000, processed 2100000 words, keeping 207802 word types
# 2021-05-17 16:00:58,583 : INFO : PROGRESS: at sentence #220000, processed 2200000 words, keeping 210925 word types
# 2021-05-17 16:00:58,634 : INFO : PROGRESS: at sentence #230000, processed 2300000 words, keeping 214082 word types
# 2021-05-17 16:00:58,688 : INFO : PROGRESS: at sentence #240000, processed 2400000 words, keeping 217372 word types
# 2021-05-17 16:00:58,741 : INFO : PROGRESS: at sentence #250000, processed 2500000 words, keeping 220517 word types
# 2021-05-17 16:00:58,791 : INFO : PROGRESS: at sentence #260000, processed 2600000 words, keeping 223460 word types
# 2021-05-17 16:00:58,843 : INFO : PROGRESS: at sentence #270000, processed 2700000 words, keeping 226479 word types
# 2021-05-17 16:00:58,900 : INFO : PROGRESS: at sentence #280000, processed 2800000 words, keeping 228960 word types
# 2021-05-17 16:00:58,956 : INFO : PROGRESS: at sentence #290000, processed 2900000 words, keeping 231567 word types
# 2021-05-17 16:00:59,009 : INFO : PROGRESS: at sentence #300000, processed 3000000 words, keeping 234085 word types
# 2021-05-17 16:00:59,065 : INFO : PROGRESS: at sentence #310000, processed 3100000 words, keeping 236700 word types
# 2021-05-17 16:00:59,116 : INFO : PROGRESS: at sentence #320000, processed 3200000 words, keeping 239019 word types
# 2021-05-17 16:00:59,167 : INFO : PROGRESS: at sentence #330000, processed 3300000 words, keeping 241158 word types
# 2021-05-17 16:00:59,218 : INFO : PROGRESS: at sentence #340000, processed 3400000 words, keeping 243397 word types
# 2021-05-17 16:00:59,267 : INFO : PROGRESS: at sentence #350000, processed 3500000 words, keeping 245819 word types
# 2021-05-17 16:00:59,319 : INFO : PROGRESS: at sentence #360000, processed 3600000 words, keeping 247983 word types
# 2021-05-17 16:00:59,372 : INFO : PROGRESS: at sentence #370000, processed 3700000 words, keeping 249999 word types
# 2021-05-17 16:00:59,422 : INFO : PROGRESS: at sentence #380000, processed 3800000 words, keeping 251884 word types
# 2021-05-17 16:00:59,472 : INFO : PROGRESS: at sentence #390000, processed 3900000 words, keeping 253781 word types
# 2021-05-17 16:00:59,521 : INFO : PROGRESS: at sentence #400000, processed 4000000 words, keeping 255794 word types
# 2021-05-17 16:00:59,574 : INFO : PROGRESS: at sentence #410000, processed 4100000 words, keeping 257802 word types
# 2021-05-17 16:00:59,628 : INFO : PROGRESS: at sentence #420000, processed 4200000 words, keeping 259808 word types
# 2021-05-17 16:00:59,680 : INFO : PROGRESS: at sentence #430000, processed 4300000 words, keeping 261782 word types
# 2021-05-17 16:00:59,732 : INFO : PROGRESS: at sentence #440000, processed 4400000 words, keeping 263521 word types
# 2021-05-17 16:00:59,786 : INFO : PROGRESS: at sentence #450000, processed 4500000 words, keeping 265323 word types
# 2021-05-17 16:00:59,838 : INFO : PROGRESS: at sentence #460000, processed 4600000 words, keeping 267031 word types
# 2021-05-17 16:00:59,890 : INFO : PROGRESS: at sentence #470000, processed 4700000 words, keeping 268760 word types
# 2021-05-17 16:00:59,941 : INFO : PROGRESS: at sentence #480000, processed 4800000 words, keeping 270462 word types
# 2021-05-17 16:00:59,994 : INFO : PROGRESS: at sentence #490000, processed 4900000 words, keeping 272106 word types
# 2021-05-17 16:01:00,044 : INFO : PROGRESS: at sentence #500000, processed 5000000 words, keeping 273677 word types
# 2021-05-17 16:01:00,094 : INFO : PROGRESS: at sentence #510000, processed 5100000 words, keeping 275238 word types
# 2021-05-17 16:01:00,144 : INFO : PROGRESS: at sentence #520000, processed 5200000 words, keeping 276969 word types
# 2021-05-17 16:01:00,197 : INFO : PROGRESS: at sentence #530000, processed 5300000 words, keeping 278417 word types
# 2021-05-17 16:01:00,248 : INFO : PROGRESS: at sentence #540000, processed 5400000 words, keeping 279916 word types
# 2021-05-17 16:01:00,299 : INFO : PROGRESS: at sentence #550000, processed 5500000 words, keeping 281331 word types
# 2021-05-17 16:01:00,355 : INFO : PROGRESS: at sentence #560000, processed 5600000 words, keeping 282719 word types
# 2021-05-17 16:01:00,404 : INFO : PROGRESS: at sentence #570000, processed 5700000 words, keeping 284115 word types
# 2021-05-17 16:01:00,461 : INFO : PROGRESS: at sentence #580000, processed 5800000 words, keeping 285551 word types
# 2021-05-17 16:01:00,513 : INFO : PROGRESS: at sentence #590000, processed 5900000 words, keeping 286998 word types
# 2021-05-17 16:01:00,564 : INFO : PROGRESS: at sentence #600000, processed 6000000 words, keeping 288294 word types
# 2021-05-17 16:01:00,620 : INFO : PROGRESS: at sentence #610000, processed 6100000 words, keeping 289538 word types
# 2021-05-17 16:01:00,670 : INFO : PROGRESS: at sentence #620000, processed 6200000 words, keeping 290736 word types
# 2021-05-17 16:01:00,718 : INFO : PROGRESS: at sentence #630000, processed 6300000 words, keeping 291969 word types
# 2021-05-17 16:01:00,768 : INFO : PROGRESS: at sentence #640000, processed 6400000 words, keeping 293167 word types
# 2021-05-17 16:01:00,817 : INFO : PROGRESS: at sentence #650000, processed 6500000 words, keeping 294223 word types
# 2021-05-17 16:01:00,871 : INFO : PROGRESS: at sentence #660000, processed 6600000 words, keeping 295388 word types
# 2021-05-17 16:01:00,925 : INFO : PROGRESS: at sentence #670000, processed 6700000 words, keeping 296679 word types
# 2021-05-17 16:01:00,982 : INFO : PROGRESS: at sentence #680000, processed 6800000 words, keeping 297824 word types
# 2021-05-17 16:01:01,033 : INFO : PROGRESS: at sentence #690000, processed 6900000 words, keeping 299036 word types
# 2021-05-17 16:01:01,084 : INFO : PROGRESS: at sentence #700000, processed 7000000 words, keeping 300093 word types
# 2021-05-17 16:01:01,135 : INFO : PROGRESS: at sentence #710000, processed 7100000 words, keeping 301026 word types
# 2021-05-17 16:01:01,185 : INFO : PROGRESS: at sentence #720000, processed 7200000 words, keeping 302135 word types
# 2021-05-17 16:01:01,236 : INFO : PROGRESS: at sentence #730000, processed 7300000 words, keeping 303221 word types
# 2021-05-17 16:01:01,287 : INFO : PROGRESS: at sentence #740000, processed 7400000 words, keeping 304182 word types
# 2021-05-17 16:01:01,338 : INFO : PROGRESS: at sentence #750000, processed 7500000 words, keeping 305336 word types
# 2021-05-17 16:01:01,389 : INFO : PROGRESS: at sentence #760000, processed 7600000 words, keeping 306263 word types
# 2021-05-17 16:01:01,439 : INFO : PROGRESS: at sentence #770000, processed 7700000 words, keeping 307212 word types
# 2021-05-17 16:01:01,489 : INFO : PROGRESS: at sentence #780000, processed 7800000 words, keeping 308188 word types
# 2021-05-17 16:01:01,543 : INFO : PROGRESS: at sentence #790000, processed 7900000 words, keeping 309069 word types
# 2021-05-17 16:01:01,592 : INFO : PROGRESS: at sentence #800000, processed 8000000 words, keeping 310018 word types
# 2021-05-17 16:01:01,647 : INFO : PROGRESS: at sentence #810000, processed 8100000 words, keeping 310840 word types
# 2021-05-17 16:01:01,698 : INFO : PROGRESS: at sentence #820000, processed 8200000 words, keeping 311673 word types
# 2021-05-17 16:01:01,749 : INFO : PROGRESS: at sentence #830000, processed 8300000 words, keeping 312448 word types
# 2021-05-17 16:01:01,798 : INFO : PROGRESS: at sentence #840000, processed 8400000 words, keeping 313297 word types
# 2021-05-17 16:01:01,847 : INFO : PROGRESS: at sentence #850000, processed 8500000 words, keeping 314081 word types
# 2021-05-17 16:01:01,903 : INFO : PROGRESS: at sentence #860000, processed 8600000 words, keeping 314807 word types
# 2021-05-17 16:01:01,953 : INFO : PROGRESS: at sentence #870000, processed 8700000 words, keeping 315637 word types
# 2021-05-17 16:01:02,003 : INFO : PROGRESS: at sentence #880000, processed 8800000 words, keeping 316394 word types
# 2021-05-17 16:01:02,053 : INFO : PROGRESS: at sentence #890000, processed 8900000 words, keeping 317223 word types
# 2021-05-17 16:01:02,102 : INFO : PROGRESS: at sentence #900000, processed 9000000 words, keeping 317992 word types
# 2021-05-17 16:01:02,152 : INFO : PROGRESS: at sentence #910000, processed 9100000 words, keeping 318792 word types
# 2021-05-17 16:01:02,203 : INFO : PROGRESS: at sentence #920000, processed 9200000 words, keeping 319508 word types
# 2021-05-17 16:01:02,252 : INFO : PROGRESS: at sentence #930000, processed 9300000 words, keeping 320161 word types
# 2021-05-17 16:01:02,302 : INFO : PROGRESS: at sentence #940000, processed 9400000 words, keeping 320926 word types
# 2021-05-17 16:01:02,354 : INFO : PROGRESS: at sentence #950000, processed 9500000 words, keeping 321601 word types
# 2021-05-17 16:01:02,410 : INFO : PROGRESS: at sentence #960000, processed 9600000 words, keeping 322239 word types
# 2021-05-17 16:01:02,461 : INFO : PROGRESS: at sentence #970000, processed 9700000 words, keeping 322936 word types
# 2021-05-17 16:01:02,514 : INFO : PROGRESS: at sentence #980000, processed 9800000 words, keeping 323536 word types
# 2021-05-17 16:01:02,572 : INFO : PROGRESS: at sentence #990000, processed 9900000 words, keeping 324161 word types
# 2021-05-17 16:01:02,629 : INFO : PROGRESS: at sentence #1000000, processed 10000000 words, keeping 324823 word types
# 2021-05-17 16:01:02,681 : INFO : PROGRESS: at sentence #1010000, processed 10100000 words, keeping 325448 word types
# 2021-05-17 16:01:02,731 : INFO : PROGRESS: at sentence #1020000, processed 10200000 words, keeping 326155 word types
# 2021-05-17 16:01:02,782 : INFO : PROGRESS: at sentence #1030000, processed 10300000 words, keeping 326764 word types
# 2021-05-17 16:01:02,832 : INFO : PROGRESS: at sentence #1040000, processed 10400000 words, keeping 327351 word types
# 2021-05-17 16:01:02,881 : INFO : PROGRESS: at sentence #1050000, processed 10500000 words, keeping 327875 word types
# 2021-05-17 16:01:02,929 : INFO : PROGRESS: at sentence #1060000, processed 10600000 words, keeping 328394 word types
# 2021-05-17 16:01:02,983 : INFO : PROGRESS: at sentence #1070000, processed 10700000 words, keeping 328909 word types
# 2021-05-17 16:01:03,035 : INFO : PROGRESS: at sentence #1080000, processed 10800000 words, keeping 329444 word types
# 2021-05-17 16:01:03,089 : INFO : PROGRESS: at sentence #1090000, processed 10900000 words, keeping 329989 word types
# 2021-05-17 16:01:03,143 : INFO : PROGRESS: at sentence #1100000, processed 11000000 words, keeping 330479 word types
# 2021-05-17 16:01:03,194 : INFO : PROGRESS: at sentence #1110000, processed 11100000 words, keeping 331028 word types
# 2021-05-17 16:01:03,247 : INFO : PROGRESS: at sentence #1120000, processed 11200000 words, keeping 331585 word types
# 2021-05-17 16:01:03,302 : INFO : PROGRESS: at sentence #1130000, processed 11300000 words, keeping 332080 word types
# 2021-05-17 16:01:03,359 : INFO : PROGRESS: at sentence #1140000, processed 11400000 words, keeping 332525 word types
# 2021-05-17 16:01:03,410 : INFO : PROGRESS: at sentence #1150000, processed 11500000 words, keeping 333066 word types
# 2021-05-17 16:01:03,474 : INFO : PROGRESS: at sentence #1160000, processed 11600000 words, keeping 333528 word types
# 2021-05-17 16:01:03,543 : INFO : PROGRESS: at sentence #1170000, processed 11700000 words, keeping 333935 word types
# 2021-05-17 16:01:03,604 : INFO : PROGRESS: at sentence #1180000, processed 11800000 words, keeping 334360 word types
# 2021-05-17 16:01:03,670 : INFO : PROGRESS: at sentence #1190000, processed 11900000 words, keeping 334856 word types
# 2021-05-17 16:01:03,737 : INFO : PROGRESS: at sentence #1200000, processed 12000000 words, keeping 335244 word types
# 2021-05-17 16:01:03,798 : INFO : PROGRESS: at sentence #1210000, processed 12100000 words, keeping 335716 word types
# 2021-05-17 16:01:03,863 : INFO : PROGRESS: at sentence #1220000, processed 12200000 words, keeping 336126 word types
# 2021-05-17 16:01:03,937 : INFO : PROGRESS: at sentence #1230000, processed 12300000 words, keeping 336520 word types
# 2021-05-17 16:01:04,007 : INFO : PROGRESS: at sentence #1240000, processed 12400000 words, keeping 336917 word types
# 2021-05-17 16:01:04,076 : INFO : PROGRESS: at sentence #1250000, processed 12500000 words, keeping 337299 word types
# 2021-05-17 16:01:04,144 : INFO : PROGRESS: at sentence #1260000, processed 12600000 words, keeping 337738 word types
# 2021-05-17 16:01:04,206 : INFO : PROGRESS: at sentence #1270000, processed 12700000 words, keeping 338163 word types
# 2021-05-17 16:01:04,257 : INFO : PROGRESS: at sentence #1280000, processed 12800000 words, keeping 338571 word types
# 2021-05-17 16:01:04,320 : INFO : PROGRESS: at sentence #1290000, processed 12900000 words, keeping 338928 word types
# 2021-05-17 16:01:04,376 : INFO : PROGRESS: at sentence #1300000, processed 13000000 words, keeping 339239 word types
# 2021-05-17 16:01:04,428 : INFO : PROGRESS: at sentence #1310000, processed 13100000 words, keeping 339601 word types
# 2021-05-17 16:01:04,479 : INFO : PROGRESS: at sentence #1320000, processed 13200000 words, keeping 339905 word types
# 2021-05-17 16:01:04,531 : INFO : PROGRESS: at sentence #1330000, processed 13300000 words, keeping 340241 word types
# 2021-05-17 16:01:04,581 : INFO : PROGRESS: at sentence #1340000, processed 13400000 words, keeping 340591 word types
# 2021-05-17 16:01:04,632 : INFO : PROGRESS: at sentence #1350000, processed 13500000 words, keeping 340906 word types
# 2021-05-17 16:01:04,690 : INFO : PROGRESS: at sentence #1360000, processed 13600000 words, keeping 341251 word types
# 2021-05-17 16:01:04,743 : INFO : PROGRESS: at sentence #1370000, processed 13700000 words, keeping 341618 word types
# 2021-05-17 16:01:04,794 : INFO : PROGRESS: at sentence #1380000, processed 13800000 words, keeping 341930 word types
# 2021-05-17 16:01:04,846 : INFO : PROGRESS: at sentence #1390000, processed 13900000 words, keeping 342236 word types
# 2021-05-17 16:01:04,898 : INFO : PROGRESS: at sentence #1400000, processed 14000000 words, keeping 342534 word types
# 2021-05-17 16:01:04,952 : INFO : PROGRESS: at sentence #1410000, processed 14100000 words, keeping 342835 word types
# 2021-05-17 16:01:05,008 : INFO : PROGRESS: at sentence #1420000, processed 14200000 words, keeping 343109 word types
# 2021-05-17 16:01:05,059 : INFO : PROGRESS: at sentence #1430000, processed 14300000 words, keeping 343410 word types
# 2021-05-17 16:01:05,112 : INFO : PROGRESS: at sentence #1440000, processed 14400000 words, keeping 343669 word types
# 2021-05-17 16:01:05,163 : INFO : PROGRESS: at sentence #1450000, processed 14500000 words, keeping 343955 word types
# 2021-05-17 16:01:05,214 : INFO : PROGRESS: at sentence #1460000, processed 14600000 words, keeping 344288 word types
# 2021-05-17 16:01:05,264 : INFO : PROGRESS: at sentence #1470000, processed 14700000 words, keeping 344515 word types
# 2021-05-17 16:01:05,316 : INFO : PROGRESS: at sentence #1480000, processed 14800000 words, keeping 344767 word types
# 2021-05-17 16:01:05,372 : INFO : PROGRESS: at sentence #1490000, processed 14900000 words, keeping 345035 word types
# 2021-05-17 16:01:05,427 : INFO : PROGRESS: at sentence #1500000, processed 15000000 words, keeping 345260 word types
# 2021-05-17 16:01:05,479 : INFO : PROGRESS: at sentence #1510000, processed 15100000 words, keeping 345486 word types
# 2021-05-17 16:01:05,530 : INFO : PROGRESS: at sentence #1520000, processed 15200000 words, keeping 345763 word types
# 2021-05-17 16:01:05,581 : INFO : PROGRESS: at sentence #1530000, processed 15300000 words, keeping 345983 word types
# 2021-05-17 16:01:05,634 : INFO : PROGRESS: at sentence #1540000, processed 15400000 words, keeping 346271 word types
# 2021-05-17 16:01:05,690 : INFO : PROGRESS: at sentence #1550000, processed 15500000 words, keeping 346495 word types
# 2021-05-17 16:01:05,740 : INFO : PROGRESS: at sentence #1560000, processed 15600000 words, keeping 346705 word types
# 2021-05-17 16:01:05,790 : INFO : PROGRESS: at sentence #1570000, processed 15700000 words, keeping 346907 word types
# 2021-05-17 16:01:05,840 : INFO : PROGRESS: at sentence #1580000, processed 15800000 words, keeping 347126 word types
# 2021-05-17 16:01:05,892 : INFO : PROGRESS: at sentence #1590000, processed 15900000 words, keeping 347317 word types
# 2021-05-17 16:01:05,952 : INFO : PROGRESS: at sentence #1600000, processed 16000000 words, keeping 347491 word types
# 2021-05-17 16:01:06,004 : INFO : PROGRESS: at sentence #1610000, processed 16100000 words, keeping 347677 word types
# 2021-05-17 16:01:06,058 : INFO : PROGRESS: at sentence #1620000, processed 16200000 words, keeping 347865 word types
# 2021-05-17 16:01:06,111 : INFO : PROGRESS: at sentence #1630000, processed 16300000 words, keeping 348048 word types
# 2021-05-17 16:01:06,160 : INFO : PROGRESS: at sentence #1640000, processed 16400000 words, keeping 348246 word types
# 2021-05-17 16:01:06,210 : INFO : PROGRESS: at sentence #1650000, processed 16500000 words, keeping 348401 word types
# 2021-05-17 16:01:06,261 : INFO : PROGRESS: at sentence #1660000, processed 16600000 words, keeping 348592 word types
# 2021-05-17 16:01:06,313 : INFO : PROGRESS: at sentence #1670000, processed 16700000 words, keeping 348767 word types
# 2021-05-17 16:01:06,368 : INFO : PROGRESS: at sentence #1680000, processed 16800000 words, keeping 348956 word types
# 2021-05-17 16:01:06,420 : INFO : PROGRESS: at sentence #1690000, processed 16900000 words, keeping 349121 word types
# 2021-05-17 16:01:06,472 : INFO : PROGRESS: at sentence #1700000, processed 17000000 words, keeping 349311 word types
# 2021-05-17 16:01:06,524 : INFO : PROGRESS: at sentence #1710000, processed 17100000 words, keeping 349449 word types
# 2021-05-17 16:01:06,590 : INFO : PROGRESS: at sentence #1720000, processed 17200000 words, keeping 349596 word types
# 2021-05-17 16:01:06,637 : INFO : PROGRESS: at sentence #1730000, processed 17300000 words, keeping 349782 word types
# 2021-05-17 16:01:06,691 : INFO : PROGRESS: at sentence #1740000, processed 17400000 words, keeping 349940 word types
# 2021-05-17 16:01:06,736 : INFO : PROGRESS: at sentence #1750000, processed 17500000 words, keeping 350082 word types
# 2021-05-17 16:01:06,783 : INFO : PROGRESS: at sentence #1760000, processed 17600000 words, keeping 350223 word types
# 2021-05-17 16:01:06,833 : INFO : PROGRESS: at sentence #1770000, processed 17700000 words, keeping 350379 word types
# 2021-05-17 16:01:06,883 : INFO : PROGRESS: at sentence #1780000, processed 17800000 words, keeping 350540 word types
# 2021-05-17 16:01:06,933 : INFO : PROGRESS: at sentence #1790000, processed 17900000 words, keeping 350711 word types
# 2021-05-17 16:01:06,982 : INFO : PROGRESS: at sentence #1800000, processed 18000000 words, keeping 350888 word types
# 2021-05-17 16:01:07,030 : INFO : PROGRESS: at sentence #1810000, processed 18100000 words, keeping 351000 word types
# 2021-05-17 16:01:07,076 : INFO : PROGRESS: at sentence #1820000, processed 18200000 words, keeping 351134 word types
# 2021-05-17 16:01:07,123 : INFO : PROGRESS: at sentence #1830000, processed 18300000 words, keeping 351271 word types
# 2021-05-17 16:01:07,172 : INFO : PROGRESS: at sentence #1840000, processed 18400000 words, keeping 351404 word types
# 2021-05-17 16:01:07,220 : INFO : PROGRESS: at sentence #1850000, processed 18500000 words, keeping 351550 word types
# 2021-05-17 16:01:07,266 : INFO : PROGRESS: at sentence #1860000, processed 18600000 words, keeping 351682 word types
# 2021-05-17 16:01:07,311 : INFO : PROGRESS: at sentence #1870000, processed 18700000 words, keeping 351827 word types
# 2021-05-17 16:01:07,360 : INFO : PROGRESS: at sentence #1880000, processed 18800000 words, keeping 351946 word types
# 2021-05-17 16:01:07,406 : INFO : PROGRESS: at sentence #1890000, processed 18900000 words, keeping 352045 word types
# 2021-05-17 16:01:07,452 : INFO : PROGRESS: at sentence #1900000, processed 19000000 words, keeping 352166 word types
# 2021-05-17 16:01:07,498 : INFO : PROGRESS: at sentence #1910000, processed 19100000 words, keeping 352299 word types
# 2021-05-17 16:01:07,545 : INFO : PROGRESS: at sentence #1920000, processed 19200000 words, keeping 352432 word types
# 2021-05-17 16:01:07,591 : INFO : PROGRESS: at sentence #1930000, processed 19300000 words, keeping 352528 word types
# 2021-05-17 16:01:07,637 : INFO : PROGRESS: at sentence #1940000, processed 19400000 words, keeping 352628 word types
# 2021-05-17 16:01:07,685 : INFO : PROGRESS: at sentence #1950000, processed 19500000 words, keeping 352753 word types
# 2021-05-17 16:01:07,735 : INFO : PROGRESS: at sentence #1960000, processed 19600000 words, keeping 352861 word types
# 2021-05-17 16:01:07,780 : INFO : PROGRESS: at sentence #1970000, processed 19700000 words, keeping 352973 word types
# 2021-05-17 16:01:07,825 : INFO : PROGRESS: at sentence #1980000, processed 19800000 words, keeping 353072 word types
# 2021-05-17 16:01:07,870 : INFO : PROGRESS: at sentence #1990000, processed 19900000 words, keeping 353173 word types
# 2021-05-17 16:01:07,915 : INFO : PROGRESS: at sentence #2000000, processed 20000000 words, keeping 353295 word types
# 2021-05-17 16:01:07,963 : INFO : PROGRESS: at sentence #2010000, processed 20100000 words, keeping 353419 word types
# 2021-05-17 16:01:08,010 : INFO : PROGRESS: at sentence #2020000, processed 20200000 words, keeping 353518 word types
# 2021-05-17 16:01:08,060 : INFO : PROGRESS: at sentence #2030000, processed 20300000 words, keeping 353609 word types
# 2021-05-17 16:01:08,111 : INFO : PROGRESS: at sentence #2040000, processed 20400000 words, keeping 353702 word types
# 2021-05-17 16:01:08,162 : INFO : PROGRESS: at sentence #2050000, processed 20500000 words, keeping 353804 word types
# 2021-05-17 16:01:08,213 : INFO : PROGRESS: at sentence #2060000, processed 20600000 words, keeping 353914 word types
# 2021-05-17 16:01:08,262 : INFO : PROGRESS: at sentence #2070000, processed 20700000 words, keeping 354012 word types
# 2021-05-17 16:01:08,310 : INFO : PROGRESS: at sentence #2080000, processed 20800000 words, keeping 354109 word types
# 2021-05-17 16:01:08,360 : INFO : PROGRESS: at sentence #2090000, processed 20900000 words, keeping 354214 word types
# 2021-05-17 16:01:08,410 : INFO : PROGRESS: at sentence #2100000, processed 21000000 words, keeping 354298 word types
# 2021-05-17 16:01:08,458 : INFO : PROGRESS: at sentence #2110000, processed 21100000 words, keeping 354394 word types
# 2021-05-17 16:01:08,505 : INFO : PROGRESS: at sentence #2120000, processed 21200000 words, keeping 354497 word types
# 2021-05-17 16:01:08,551 : INFO : PROGRESS: at sentence #2130000, processed 21300000 words, keeping 354564 word types
# 2021-05-17 16:01:08,600 : INFO : PROGRESS: at sentence #2140000, processed 21400000 words, keeping 354661 word types
# 2021-05-17 16:01:08,647 : INFO : PROGRESS: at sentence #2150000, processed 21500000 words, keeping 354755 word types
# 2021-05-17 16:01:08,694 : INFO : PROGRESS: at sentence #2160000, processed 21600000 words, keeping 354823 word types
# 2021-05-17 16:01:08,746 : INFO : PROGRESS: at sentence #2170000, processed 21700000 words, keeping 354903 word types
# 2021-05-17 16:01:08,792 : INFO : PROGRESS: at sentence #2180000, processed 21800000 words, keeping 354981 word types
# 2021-05-17 16:01:08,845 : INFO : PROGRESS: at sentence #2190000, processed 21900000 words, keeping 355053 word types
# 2021-05-17 16:01:08,894 : INFO : PROGRESS: at sentence #2200000, processed 22000000 words, keeping 355126 word types
# 2021-05-17 16:01:08,942 : INFO : PROGRESS: at sentence #2210000, processed 22100000 words, keeping 355216 word types
# 2021-05-17 16:01:08,990 : INFO : PROGRESS: at sentence #2220000, processed 22200000 words, keeping 355309 word types
# 2021-05-17 16:01:09,040 : INFO : PROGRESS: at sentence #2230000, processed 22300000 words, keeping 355396 word types
# 2021-05-17 16:01:09,085 : INFO : PROGRESS: at sentence #2240000, processed 22400000 words, keeping 355472 word types
# 2021-05-17 16:01:09,131 : INFO : PROGRESS: at sentence #2250000, processed 22500000 words, keeping 355542 word types
# 2021-05-17 16:01:09,177 : INFO : PROGRESS: at sentence #2260000, processed 22600000 words, keeping 355604 word types
# 2021-05-17 16:01:09,224 : INFO : PROGRESS: at sentence #2270000, processed 22700000 words, keeping 355671 word types
# 2021-05-17 16:01:09,270 : INFO : PROGRESS: at sentence #2280000, processed 22800000 words, keeping 355746 word types
# 2021-05-17 16:01:09,316 : INFO : PROGRESS: at sentence #2290000, processed 22900000 words, keeping 355802 word types
# 2021-05-17 16:01:09,368 : INFO : PROGRESS: at sentence #2300000, processed 23000000 words, keeping 355872 word types
# 2021-05-17 16:01:09,413 : INFO : PROGRESS: at sentence #2310000, processed 23100000 words, keeping 355936 word types
# 2021-05-17 16:01:09,458 : INFO : PROGRESS: at sentence #2320000, processed 23200000 words, keeping 356003 word types
# 2021-05-17 16:01:09,502 : INFO : PROGRESS: at sentence #2330000, processed 23300000 words, keeping 356065 word types
# 2021-05-17 16:01:09,547 : INFO : PROGRESS: at sentence #2340000, processed 23400000 words, keeping 356139 word types
# 2021-05-17 16:01:09,593 : INFO : PROGRESS: at sentence #2350000, processed 23500000 words, keeping 356205 word types
# 2021-05-17 16:01:09,639 : INFO : PROGRESS: at sentence #2360000, processed 23600000 words, keeping 356287 word types
# 2021-05-17 16:01:09,684 : INFO : PROGRESS: at sentence #2370000, processed 23700000 words, keeping 356352 word types
# 2021-05-17 16:01:09,734 : INFO : PROGRESS: at sentence #2380000, processed 23800000 words, keeping 356402 word types
# 2021-05-17 16:01:09,779 : INFO : PROGRESS: at sentence #2390000, processed 23900000 words, keeping 356481 word types
# 2021-05-17 16:01:09,823 : INFO : PROGRESS: at sentence #2400000, processed 24000000 words, keeping 356540 word types
# 2021-05-17 16:01:09,868 : INFO : PROGRESS: at sentence #2410000, processed 24100000 words, keeping 356600 word types
# 2021-05-17 16:01:09,918 : INFO : PROGRESS: at sentence #2420000, processed 24200000 words, keeping 356658 word types
# 2021-05-17 16:01:09,966 : INFO : PROGRESS: at sentence #2430000, processed 24300000 words, keeping 356710 word types
# 2021-05-17 16:01:10,014 : INFO : PROGRESS: at sentence #2440000, processed 24400000 words, keeping 356763 word types
# 2021-05-17 16:01:10,060 : INFO : PROGRESS: at sentence #2450000, processed 24500000 words, keeping 356815 word types
# 2021-05-17 16:01:10,108 : INFO : PROGRESS: at sentence #2460000, processed 24600000 words, keeping 356867 word types
# 2021-05-17 16:01:10,154 : INFO : PROGRESS: at sentence #2470000, processed 24700000 words, keeping 356918 word types
# 2021-05-17 16:01:10,199 : INFO : PROGRESS: at sentence #2480000, processed 24800000 words, keeping 356962 word types
# 2021-05-17 16:01:10,248 : INFO : PROGRESS: at sentence #2490000, processed 24900000 words, keeping 357015 word types
# 2021-05-17 16:01:10,298 : INFO : PROGRESS: at sentence #2500000, processed 25000000 words, keeping 357062 word types
# 2021-05-17 16:01:10,347 : INFO : PROGRESS: at sentence #2510000, processed 25100000 words, keeping 357106 word types
# 2021-05-17 16:01:10,393 : INFO : PROGRESS: at sentence #2520000, processed 25200000 words, keeping 357157 word types
# 2021-05-17 16:01:10,439 : INFO : PROGRESS: at sentence #2530000, processed 25300000 words, keeping 357195 word types
# 2021-05-17 16:01:10,484 : INFO : PROGRESS: at sentence #2540000, processed 25400000 words, keeping 357230 word types
# 2021-05-17 16:01:10,531 : INFO : PROGRESS: at sentence #2550000, processed 25500000 words, keeping 357274 word types
# 2021-05-17 16:01:10,581 : INFO : PROGRESS: at sentence #2560000, processed 25600000 words, keeping 357330 word types
# 2021-05-17 16:01:10,626 : INFO : PROGRESS: at sentence #2570000, processed 25700000 words, keeping 357386 word types
# 2021-05-17 16:01:10,672 : INFO : PROGRESS: at sentence #2580000, processed 25800000 words, keeping 357438 word types
# 2021-05-17 16:01:10,718 : INFO : PROGRESS: at sentence #2590000, processed 25900000 words, keeping 357502 word types
# 2021-05-17 16:01:10,773 : INFO : PROGRESS: at sentence #2600000, processed 26000000 words, keeping 357545 word types
# 2021-05-17 16:01:10,818 : INFO : PROGRESS: at sentence #2610000, processed 26100000 words, keeping 357604 word types
# 2021-05-17 16:01:10,863 : INFO : PROGRESS: at sentence #2620000, processed 26200000 words, keeping 357660 word types
# 2021-05-17 16:01:10,909 : INFO : PROGRESS: at sentence #2630000, processed 26300000 words, keeping 357702 word types
# 2021-05-17 16:01:10,953 : INFO : PROGRESS: at sentence #2640000, processed 26400000 words, keeping 357745 word types
# 2021-05-17 16:01:10,999 : INFO : PROGRESS: at sentence #2650000, processed 26500000 words, keeping 357788 word types
# 2021-05-17 16:01:11,045 : INFO : PROGRESS: at sentence #2660000, processed 26600000 words, keeping 357822 word types
# 2021-05-17 16:01:11,091 : INFO : PROGRESS: at sentence #2670000, processed 26700000 words, keeping 357881 word types
# 2021-05-17 16:01:11,143 : INFO : PROGRESS: at sentence #2680000, processed 26800000 words, keeping 357929 word types
# 2021-05-17 16:01:11,195 : INFO : PROGRESS: at sentence #2690000, processed 26900000 words, keeping 357969 word types
# 2021-05-17 16:01:11,242 : INFO : PROGRESS: at sentence #2700000, processed 27000000 words, keeping 358017 word types
# 2021-05-17 16:01:11,289 : INFO : PROGRESS: at sentence #2710000, processed 27100000 words, keeping 358065 word types
# 2021-05-17 16:01:11,333 : INFO : PROGRESS: at sentence #2720000, processed 27200000 words, keeping 358102 word types
# 2021-05-17 16:01:11,379 : INFO : PROGRESS: at sentence #2730000, processed 27300000 words, keeping 358140 word types
# 2021-05-17 16:01:11,422 : INFO : PROGRESS: at sentence #2740000, processed 27400000 words, keeping 358185 word types
# 2021-05-17 16:01:11,466 : INFO : PROGRESS: at sentence #2750000, processed 27500000 words, keeping 358224 word types
# 2021-05-17 16:01:11,510 : INFO : PROGRESS: at sentence #2760000, processed 27600000 words, keeping 358267 word types
# 2021-05-17 16:01:11,553 : INFO : PROGRESS: at sentence #2770000, processed 27700000 words, keeping 358302 word types
# 2021-05-17 16:01:11,597 : INFO : PROGRESS: at sentence #2780000, processed 27800000 words, keeping 358345 word types
# 2021-05-17 16:01:11,641 : INFO : PROGRESS: at sentence #2790000, processed 27900000 words, keeping 358390 word types
# 2021-05-17 16:01:11,685 : INFO : PROGRESS: at sentence #2800000, processed 28000000 words, keeping 358425 word types
# 2021-05-17 16:01:11,729 : INFO : PROGRESS: at sentence #2810000, processed 28100000 words, keeping 358458 word types
# 2021-05-17 16:01:11,778 : INFO : PROGRESS: at sentence #2820000, processed 28200000 words, keeping 358514 word types
# 2021-05-17 16:01:11,822 : INFO : PROGRESS: at sentence #2830000, processed 28300000 words, keeping 358541 word types
# 2021-05-17 16:01:11,867 : INFO : PROGRESS: at sentence #2840000, processed 28400000 words, keeping 358568 word types
# 2021-05-17 16:01:11,916 : INFO : PROGRESS: at sentence #2850000, processed 28500000 words, keeping 358592 word types
# 2021-05-17 16:01:11,963 : INFO : PROGRESS: at sentence #2860000, processed 28600000 words, keeping 358628 word types
# 2021-05-17 16:01:12,010 : INFO : PROGRESS: at sentence #2870000, processed 28700000 words, keeping 358668 word types
# 2021-05-17 16:01:12,057 : INFO : PROGRESS: at sentence #2880000, processed 28800000 words, keeping 358705 word types
# 2021-05-17 16:01:12,109 : INFO : PROGRESS: at sentence #2890000, processed 28900000 words, keeping 358741 word types
# 2021-05-17 16:01:12,155 : INFO : PROGRESS: at sentence #2900000, processed 29000000 words, keeping 358775 word types
# 2021-05-17 16:01:12,202 : INFO : PROGRESS: at sentence #2910000, processed 29100000 words, keeping 358809 word types
# 2021-05-17 16:01:12,250 : INFO : PROGRESS: at sentence #2920000, processed 29200000 words, keeping 358842 word types
# 2021-05-17 16:01:12,297 : INFO : PROGRESS: at sentence #2930000, processed 29300000 words, keeping 358887 word types
# 2021-05-17 16:01:12,342 : INFO : PROGRESS: at sentence #2940000, processed 29400000 words, keeping 358924 word types
# 2021-05-17 16:01:12,391 : INFO : PROGRESS: at sentence #2950000, processed 29500000 words, keeping 358951 word types
# 2021-05-17 16:01:12,435 : INFO : PROGRESS: at sentence #2960000, processed 29600000 words, keeping 358980 word types
# 2021-05-17 16:01:12,479 : INFO : PROGRESS: at sentence #2970000, processed 29700000 words, keeping 359010 word types
# 2021-05-17 16:01:12,523 : INFO : PROGRESS: at sentence #2980000, processed 29800000 words, keeping 359029 word types
# 2021-05-17 16:01:12,567 : INFO : PROGRESS: at sentence #2990000, processed 29900000 words, keeping 359049 word types
# 2021-05-17 16:01:12,614 : INFO : PROGRESS: at sentence #3000000, processed 30000000 words, keeping 359091 word types
# 2021-05-17 16:01:12,663 : INFO : PROGRESS: at sentence #3010000, processed 30100000 words, keeping 359104 word types
# 2021-05-17 16:01:12,709 : INFO : PROGRESS: at sentence #3020000, processed 30200000 words, keeping 359131 word types
# 2021-05-17 16:01:12,754 : INFO : PROGRESS: at sentence #3030000, processed 30300000 words, keeping 359169 word types
# 2021-05-17 16:01:12,802 : INFO : PROGRESS: at sentence #3040000, processed 30400000 words, keeping 359202 word types
# 2021-05-17 16:01:12,852 : INFO : PROGRESS: at sentence #3050000, processed 30500000 words, keeping 359232 word types
# 2021-05-17 16:01:12,898 : INFO : PROGRESS: at sentence #3060000, processed 30600000 words, keeping 359263 word types
# 2021-05-17 16:01:12,945 : INFO : PROGRESS: at sentence #3070000, processed 30700000 words, keeping 359287 word types
# 2021-05-17 16:01:12,989 : INFO : PROGRESS: at sentence #3080000, processed 30800000 words, keeping 359313 word types
# 2021-05-17 16:01:13,035 : INFO : PROGRESS: at sentence #3090000, processed 30900000 words, keeping 359355 word types
# 2021-05-17 16:01:13,082 : INFO : PROGRESS: at sentence #3100000, processed 31000000 words, keeping 359387 word types
# 2021-05-17 16:01:13,126 : INFO : PROGRESS: at sentence #3110000, processed 31100000 words, keeping 359411 word types
# 2021-05-17 16:01:13,170 : INFO : PROGRESS: at sentence #3120000, processed 31200000 words, keeping 359439 word types
# 2021-05-17 16:01:13,214 : INFO : PROGRESS: at sentence #3130000, processed 31300000 words, keeping 359467 word types
# 2021-05-17 16:01:13,260 : INFO : PROGRESS: at sentence #3140000, processed 31400000 words, keeping 359495 word types
# 2021-05-17 16:01:13,305 : INFO : PROGRESS: at sentence #3150000, processed 31500000 words, keeping 359526 word types
# 2021-05-17 16:01:13,353 : INFO : PROGRESS: at sentence #3160000, processed 31600000 words, keeping 359558 word types
# 2021-05-17 16:01:13,399 : INFO : PROGRESS: at sentence #3170000, processed 31700000 words, keeping 359580 word types
# 2021-05-17 16:01:13,445 : INFO : PROGRESS: at sentence #3180000, processed 31800000 words, keeping 359601 word types
# 2021-05-17 16:01:13,490 : INFO : PROGRESS: at sentence #3190000, processed 31900000 words, keeping 359622 word types
# 2021-05-17 16:01:13,534 : INFO : PROGRESS: at sentence #3200000, processed 32000000 words, keeping 359636 word types
# 2021-05-17 16:01:13,580 : INFO : PROGRESS: at sentence #3210000, processed 32100000 words, keeping 359651 word types
# 2021-05-17 16:01:13,624 : INFO : PROGRESS: at sentence #3220000, processed 32200000 words, keeping 359672 word types
# 2021-05-17 16:01:13,670 : INFO : PROGRESS: at sentence #3230000, processed 32300000 words, keeping 359701 word types
# 2021-05-17 16:01:13,713 : INFO : PROGRESS: at sentence #3240000, processed 32400000 words, keeping 359715 word types
# 2021-05-17 16:01:13,760 : INFO : PROGRESS: at sentence #3250000, processed 32500000 words, keeping 359726 word types
# 2021-05-17 16:01:13,810 : INFO : PROGRESS: at sentence #3260000, processed 32600000 words, keeping 359751 word types
# 2021-05-17 16:01:13,854 : INFO : PROGRESS: at sentence #3270000, processed 32700000 words, keeping 359767 word types
# 2021-05-17 16:01:13,898 : INFO : PROGRESS: at sentence #3280000, processed 32800000 words, keeping 359786 word types
# 2021-05-17 16:01:13,943 : INFO : PROGRESS: at sentence #3290000, processed 32900000 words, keeping 359826 word types
# 2021-05-17 16:01:13,989 : INFO : PROGRESS: at sentence #3300000, processed 33000000 words, keeping 359850 word types
# 2021-05-17 16:01:14,037 : INFO : PROGRESS: at sentence #3310000, processed 33100000 words, keeping 359866 word types
# 2021-05-17 16:01:14,082 : INFO : PROGRESS: at sentence #3320000, processed 33200000 words, keeping 359887 word types
# 2021-05-17 16:01:14,128 : INFO : PROGRESS: at sentence #3330000, processed 33300000 words, keeping 359906 word types
# 2021-05-17 16:01:14,176 : INFO : PROGRESS: at sentence #3340000, processed 33400000 words, keeping 359929 word types
# 2021-05-17 16:01:14,221 : INFO : PROGRESS: at sentence #3350000, processed 33500000 words, keeping 359951 word types
# 2021-05-17 16:01:14,265 : INFO : PROGRESS: at sentence #3360000, processed 33600000 words, keeping 359977 word types
# 2021-05-17 16:01:14,310 : INFO : PROGRESS: at sentence #3370000, processed 33700000 words, keeping 359995 word types
# 2021-05-17 16:01:14,356 : INFO : PROGRESS: at sentence #3380000, processed 33800000 words, keeping 360021 word types
# 2021-05-17 16:01:14,401 : INFO : PROGRESS: at sentence #3390000, processed 33900000 words, keeping 360047 word types
# 2021-05-17 16:01:14,446 : INFO : PROGRESS: at sentence #3400000, processed 34000000 words, keeping 360068 word types
# 2021-05-17 16:01:14,491 : INFO : PROGRESS: at sentence #3410000, processed 34100000 words, keeping 360084 word types
# 2021-05-17 16:01:14,534 : INFO : PROGRESS: at sentence #3420000, processed 34200000 words, keeping 360112 word types
# 2021-05-17 16:01:14,591 : INFO : PROGRESS: at sentence #3430000, processed 34300000 words, keeping 360131 word types
# 2021-05-17 16:01:14,635 : INFO : PROGRESS: at sentence #3440000, processed 34400000 words, keeping 360151 word types
# 2021-05-17 16:01:14,679 : INFO : PROGRESS: at sentence #3450000, processed 34500000 words, keeping 360167 word types
# 2021-05-17 16:01:14,725 : INFO : PROGRESS: at sentence #3460000, processed 34600000 words, keeping 360183 word types
# 2021-05-17 16:01:14,771 : INFO : PROGRESS: at sentence #3470000, processed 34700000 words, keeping 360209 word types
# 2021-05-17 16:01:14,823 : INFO : PROGRESS: at sentence #3480000, processed 34800000 words, keeping 360232 word types
# 2021-05-17 16:01:14,872 : INFO : PROGRESS: at sentence #3490000, processed 34900000 words, keeping 360249 word types
# 2021-05-17 16:01:14,917 : INFO : PROGRESS: at sentence #3500000, processed 35000000 words, keeping 360277 word types
# 2021-05-17 16:01:14,967 : INFO : PROGRESS: at sentence #3510000, processed 35100000 words, keeping 360297 word types
# 2021-05-17 16:01:15,011 : INFO : PROGRESS: at sentence #3520000, processed 35200000 words, keeping 360315 word types
# 2021-05-17 16:01:15,056 : INFO : PROGRESS: at sentence #3530000, processed 35300000 words, keeping 360335 word types
# 2021-05-17 16:01:15,103 : INFO : PROGRESS: at sentence #3540000, processed 35400000 words, keeping 360356 word types
# 2021-05-17 16:01:15,147 : INFO : PROGRESS: at sentence #3550000, processed 35500000 words, keeping 360367 word types
# 2021-05-17 16:01:15,191 : INFO : PROGRESS: at sentence #3560000, processed 35600000 words, keeping 360383 word types
# 2021-05-17 16:01:15,236 : INFO : PROGRESS: at sentence #3570000, processed 35700000 words, keeping 360398 word types
# 2021-05-17 16:01:15,280 : INFO : PROGRESS: at sentence #3580000, processed 35800000 words, keeping 360414 word types
# 2021-05-17 16:01:15,325 : INFO : PROGRESS: at sentence #3590000, processed 35900000 words, keeping 360435 word types
# 2021-05-17 16:01:15,373 : INFO : PROGRESS: at sentence #3600000, processed 36000000 words, keeping 360448 word types
# 2021-05-17 16:01:15,393 : INFO : collected 360456 word types from a corpus of 36045600 raw words and 3604560 sentences
# 2021-05-17 16:01:15,400 : INFO : Loading a fresh vocabulary
# 2021-05-17 16:01:16,228 : INFO : effective_min_count=1 retains 360456 unique words (100% of original 360456, drops 0)
# 2021-05-17 16:01:16,229 : INFO : effective_min_count=1 leaves 36045600 word corpus (100% of original 36045600, drops 0)
# 2021-05-17 16:01:17,416 : INFO : deleting the raw counts dictionary of 360456 items
# 2021-05-17 16:01:17,428 : INFO : sample=0.001 downsamples 0 most-common words
# 2021-05-17 16:01:17,438 : INFO : downsampling leaves estimated 36045600 word corpus (100.0% of prior 36045600)
# 2021-05-17 16:01:19,178 : INFO : estimated required memory for 360456 words and 128 dimensions: 549334944 bytes
# 2021-05-17 16:01:19,180 : INFO : resetting layer weights
# 2021-05-17 16:02:28,593 : INFO : training model with 6 workers on 360456 vocabulary and 128 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2021-05-17 16:02:29,612 : INFO : EPOCH 1 - PROGRESS: at 0.92% examples, 328359 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:30,636 : INFO : EPOCH 1 - PROGRESS: at 1.83% examples, 325261 words/s, in_qsize 12, out_qsize 3
# 2021-05-17 16:02:31,677 : INFO : EPOCH 1 - PROGRESS: at 2.86% examples, 335537 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:32,682 : INFO : EPOCH 1 - PROGRESS: at 3.88% examples, 343536 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:33,717 : INFO : EPOCH 1 - PROGRESS: at 4.85% examples, 342430 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:02:34,792 : INFO : EPOCH 1 - PROGRESS: at 5.83% examples, 339493 words/s, in_qsize 9, out_qsize 4
# 2021-05-17 16:02:35,811 : INFO : EPOCH 1 - PROGRESS: at 6.85% examples, 342838 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:36,864 : INFO : EPOCH 1 - PROGRESS: at 7.85% examples, 342733 words/s, in_qsize 11, out_qsize 2
# 2021-05-17 16:02:37,896 : INFO : EPOCH 1 - PROGRESS: at 8.85% examples, 343406 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:38,905 : INFO : EPOCH 1 - PROGRESS: at 9.82% examples, 343756 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:02:39,906 : INFO : EPOCH 1 - PROGRESS: at 10.71% examples, 341624 words/s, in_qsize 8, out_qsize 3
# 2021-05-17 16:02:40,919 : INFO : EPOCH 1 - PROGRESS: at 11.71% examples, 342763 words/s, in_qsize 12, out_qsize 1
# 2021-05-17 16:02:41,927 : INFO : EPOCH 1 - PROGRESS: at 12.73% examples, 344581 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:02:42,962 : INFO : EPOCH 1 - PROGRESS: at 13.70% examples, 344126 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:02:44,013 : INFO : EPOCH 1 - PROGRESS: at 14.76% examples, 345316 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:45,062 : INFO : EPOCH 1 - PROGRESS: at 15.70% examples, 344406 words/s, in_qsize 11, out_qsize 1
# 2021-05-17 16:02:46,093 : INFO : EPOCH 1 - PROGRESS: at 16.73% examples, 344850 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:47,110 : INFO : EPOCH 1 - PROGRESS: at 17.70% examples, 344804 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:02:48,128 : INFO : EPOCH 1 - PROGRESS: at 18.70% examples, 345260 words/s, in_qsize 11, out_qsize 1
# 2021-05-17 16:02:49,144 : INFO : EPOCH 1 - PROGRESS: at 19.64% examples, 344733 words/s, in_qsize 10, out_qsize 2
# 2021-05-17 16:02:50,264 : INFO : EPOCH 1 - PROGRESS: at 20.70% examples, 344454 words/s, in_qsize 11, out_qsize 3
# 2021-05-17 16:02:51,321 : INFO : EPOCH 1 - PROGRESS: at 21.81% examples, 346036 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:52,353 : INFO : EPOCH 1 - PROGRESS: at 22.75% examples, 345323 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:53,475 : INFO : EPOCH 1 - PROGRESS: at 23.80% examples, 345017 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:02:54,514 : INFO : EPOCH 1 - PROGRESS: at 24.86% examples, 346282 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:55,515 : INFO : EPOCH 1 - PROGRESS: at 25.83% examples, 345992 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:02:56,545 : INFO : EPOCH 1 - PROGRESS: at 26.74% examples, 345053 words/s, in_qsize 10, out_qsize 5
# 2021-05-17 16:02:57,681 : INFO : EPOCH 1 - PROGRESS: at 27.85% examples, 345317 words/s, in_qsize 10, out_qsize 3
# 2021-05-17 16:02:58,707 : INFO : EPOCH 1 - PROGRESS: at 28.99% examples, 347170 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:02:59,710 : INFO : EPOCH 1 - PROGRESS: at 29.91% examples, 346594 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:03:00,749 : INFO : EPOCH 1 - PROGRESS: at 30.88% examples, 346278 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:03:01,814 : INFO : EPOCH 1 - PROGRESS: at 31.85% examples, 346344 words/s, in_qsize 12, out_qsize 3
# 2021-05-17 16:03:02,780 : INFO : EPOCH 1 - PROGRESS: at 32.85% examples, 346470 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:03:03,814 : INFO : EPOCH 1 - PROGRESS: at 33.71% examples, 345100 words/s, in_qsize 12, out_qsize 6
# 2021-05-17 16:03:04,829 : INFO : EPOCH 1 - PROGRESS: at 34.79% examples, 346193 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:03:05,862 : INFO : EPOCH 1 - PROGRESS: at 35.82% examples, 346531 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:03:06,920 : INFO : EPOCH 1 - PROGRESS: at 36.81% examples, 346352 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:03:07,932 : INFO : EPOCH 1 - PROGRESS: at 37.87% examples, 347108 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:03:08,978 : INFO : EPOCH 1 - PROGRESS: at 38.84% examples, 346785 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:03:10,010 : INFO : EPOCH 1 - PROGRESS: at 39.95% examples, 347795 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:03:11,012 : INFO : EPOCH 1 - PROGRESS: at 40.98% examples, 348308 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:03:12,053 : INFO : EPOCH 1 - PROGRESS: at 41.92% examples, 347785 words/s, in_qsize 11, out_qsize 0
# ...
# 2021-05-17 16:08:48,941 : INFO : EPOCH 4 - PROGRESS: at 75.63% examples, 361354 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:08:49,952 : INFO : EPOCH 4 - PROGRESS: at 76.71% examples, 361677 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:08:50,967 : INFO : EPOCH 4 - PROGRESS: at 77.76% examples, 361843 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:08:52,091 : INFO : EPOCH 4 - PROGRESS: at 78.87% examples, 361760 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:08:53,098 : INFO : EPOCH 4 - PROGRESS: at 80.01% examples, 362332 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:08:54,191 : INFO : EPOCH 4 - PROGRESS: at 81.06% examples, 362136 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:08:55,244 : INFO : EPOCH 4 - PROGRESS: at 82.20% examples, 362484 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:08:56,247 : INFO : EPOCH 4 - PROGRESS: at 83.20% examples, 362441 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:08:57,284 : INFO : EPOCH 4 - PROGRESS: at 84.31% examples, 362731 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:08:58,359 : INFO : EPOCH 4 - PROGRESS: at 85.36% examples, 362613 words/s, in_qsize 10, out_qsize 4
# 2021-05-17 16:08:59,390 : INFO : EPOCH 4 - PROGRESS: at 86.53% examples, 363153 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:00,442 : INFO : EPOCH 4 - PROGRESS: at 87.56% examples, 363012 words/s, in_qsize 12, out_qsize 3
# 2021-05-17 16:09:01,516 : INFO : EPOCH 4 - PROGRESS: at 88.67% examples, 363126 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:02,561 : INFO : EPOCH 4 - PROGRESS: at 89.72% examples, 363135 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:09:03,720 : INFO : EPOCH 4 - PROGRESS: at 90.86% examples, 363012 words/s, in_qsize 11, out_qsize 4
# 2021-05-17 16:09:04,722 : INFO : EPOCH 4 - PROGRESS: at 92.02% examples, 363630 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:05,793 : INFO : EPOCH 4 - PROGRESS: at 93.02% examples, 363310 words/s, in_qsize 7, out_qsize 4
# 2021-05-17 16:09:06,900 : INFO : EPOCH 4 - PROGRESS: at 94.19% examples, 363501 words/s, in_qsize 12, out_qsize 3
# 2021-05-17 16:09:07,936 : INFO : EPOCH 4 - PROGRESS: at 95.38% examples, 364069 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:08,948 : INFO : EPOCH 4 - PROGRESS: at 96.35% examples, 363873 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:10,028 : INFO : EPOCH 4 - PROGRESS: at 97.52% examples, 364380 words/s, in_qsize 10, out_qsize 0
# 2021-05-17 16:09:10,981 : INFO : EPOCH 4 - PROGRESS: at 98.57% examples, 364491 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:12,010 : INFO : EPOCH 4 - PROGRESS: at 99.60% examples, 364440 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:09:12,218 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-05-17 16:09:12,230 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-05-17 16:09:12,245 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-05-17 16:09:12,259 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-05-17 16:09:12,264 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-05-17 16:09:12,278 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-05-17 16:09:12,279 : INFO : EPOCH - 4 : training on 36045600 raw words (36045600 effective words) took 98.8s, 364921 effective words/s
# 2021-05-17 16:09:13,314 : INFO : EPOCH 5 - PROGRESS: at 0.94% examples, 334482 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:14,322 : INFO : EPOCH 5 - PROGRESS: at 1.94% examples, 345814 words/s, in_qsize 11, out_qsize 1
# 2021-05-17 16:09:15,366 : INFO : EPOCH 5 - PROGRESS: at 3.02% examples, 355206 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:16,393 : INFO : EPOCH 5 - PROGRESS: at 3.97% examples, 349159 words/s, in_qsize 8, out_qsize 3
# 2021-05-17 16:09:17,421 : INFO : EPOCH 5 - PROGRESS: at 5.10% examples, 360989 words/s, in_qsize 9, out_qsize 1
# 2021-05-17 16:09:18,400 : INFO : EPOCH 5 - PROGRESS: at 5.99% examples, 353962 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:09:19,435 : INFO : EPOCH 5 - PROGRESS: at 7.05% examples, 355889 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:20,518 : INFO : EPOCH 5 - PROGRESS: at 8.07% examples, 354007 words/s, in_qsize 12, out_qsize 5
# 2021-05-17 16:09:21,535 : INFO : EPOCH 5 - PROGRESS: at 9.16% examples, 357273 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:09:22,535 : INFO : EPOCH 5 - PROGRESS: at 10.07% examples, 354597 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:23,576 : INFO : EPOCH 5 - PROGRESS: at 11.01% examples, 351997 words/s, in_qsize 11, out_qsize 5
# 2021-05-17 16:09:24,651 : INFO : EPOCH 5 - PROGRESS: at 12.12% examples, 353763 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:25,659 : INFO : EPOCH 5 - PROGRESS: at 13.09% examples, 353271 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:09:26,667 : INFO : EPOCH 5 - PROGRESS: at 14.12% examples, 354222 words/s, in_qsize 10, out_qsize 2
# 2021-05-17 16:09:27,740 : INFO : EPOCH 5 - PROGRESS: at 15.20% examples, 354880 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:28,788 : INFO : EPOCH 5 - PROGRESS: at 16.26% examples, 355798 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:29,885 : INFO : EPOCH 5 - PROGRESS: at 17.28% examples, 354226 words/s, in_qsize 11, out_qsize 2
# 2021-05-17 16:09:30,960 : INFO : EPOCH 5 - PROGRESS: at 18.34% examples, 354190 words/s, in_qsize 12, out_qsize 5
# 2021-05-17 16:09:31,966 : INFO : EPOCH 5 - PROGRESS: at 19.48% examples, 356930 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:33,002 : INFO : EPOCH 5 - PROGRESS: at 20.47% examples, 356451 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:34,037 : INFO : EPOCH 5 - PROGRESS: at 21.47% examples, 356031 words/s, in_qsize 10, out_qsize 3
# 2021-05-17 16:09:35,065 : INFO : EPOCH 5 - PROGRESS: at 22.58% examples, 357531 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:36,078 : INFO : EPOCH 5 - PROGRESS: at 23.61% examples, 357861 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:37,080 : INFO : EPOCH 5 - PROGRESS: at 24.58% examples, 357511 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:38,173 : INFO : EPOCH 5 - PROGRESS: at 25.66% examples, 357490 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:39,253 : INFO : EPOCH 5 - PROGRESS: at 26.74% examples, 357629 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:09:40,256 : INFO : EPOCH 5 - PROGRESS: at 27.83% examples, 358755 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:41,294 : INFO : EPOCH 5 - PROGRESS: at 28.82% examples, 358325 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:09:42,331 : INFO : EPOCH 5 - PROGRESS: at 29.91% examples, 358932 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:43,351 : INFO : EPOCH 5 - PROGRESS: at 30.88% examples, 358417 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:09:44,363 : INFO : EPOCH 5 - PROGRESS: at 31.93% examples, 358959 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:45,384 : INFO : EPOCH 5 - PROGRESS: at 32.93% examples, 358756 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:46,436 : INFO : EPOCH 5 - PROGRESS: at 33.93% examples, 358255 words/s, in_qsize 12, out_qsize 1
# 2021-05-17 16:09:47,508 : INFO : EPOCH 5 - PROGRESS: at 35.04% examples, 358708 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:48,628 : INFO : EPOCH 5 - PROGRESS: at 36.12% examples, 358383 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:09:49,631 : INFO : EPOCH 5 - PROGRESS: at 37.23% examples, 359462 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:50,638 : INFO : EPOCH 5 - PROGRESS: at 38.20% examples, 359150 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:51,692 : INFO : EPOCH 5 - PROGRESS: at 39.26% examples, 359188 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:52,713 : INFO : EPOCH 5 - PROGRESS: at 40.25% examples, 359021 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:53,716 : INFO : EPOCH 5 - PROGRESS: at 41.31% examples, 359508 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:54,718 : INFO : EPOCH 5 - PROGRESS: at 42.34% examples, 359739 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:09:55,728 : INFO : EPOCH 5 - PROGRESS: at 43.33% examples, 359658 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:09:56,772 : INFO : EPOCH 5 - PROGRESS: at 44.39% examples, 359758 words/s, in_qsize 8, out_qsize 4
# 2021-05-17 16:09:57,777 : INFO : EPOCH 5 - PROGRESS: at 45.41% examples, 359945 words/s, in_qsize 12, out_qsize 1
# 2021-05-17 16:09:58,803 : INFO : EPOCH 5 - PROGRESS: at 46.44% examples, 359962 words/s, in_qsize 6, out_qsize 5
# 2021-05-17 16:09:59,923 : INFO : EPOCH 5 - PROGRESS: at 47.61% examples, 360318 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:10:00,936 : INFO : EPOCH 5 - PROGRESS: at 48.69% examples, 360826 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:10:01,996 : INFO : EPOCH 5 - PROGRESS: at 49.69% examples, 360377 words/s, in_qsize 11, out_qsize 1
# 2021-05-17 16:10:02,997 : INFO : EPOCH 5 - PROGRESS: at 50.71% examples, 360556 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:10:04,077 : INFO : EPOCH 5 - PROGRESS: at 51.88% examples, 361368 words/s, in_qsize 10, out_qsize 2
# 2021-05-17 16:10:05,137 : INFO : EPOCH 5 - PROGRESS: at 52.96% examples, 361285 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:06,138 : INFO : EPOCH 5 - PROGRESS: at 53.99% examples, 361438 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:10:07,141 : INFO : EPOCH 5 - PROGRESS: at 55.01% examples, 361577 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:10:08,182 : INFO : EPOCH 5 - PROGRESS: at 56.07% examples, 361747 words/s, in_qsize 11, out_qsize 1
# 2021-05-17 16:10:09,287 : INFO : EPOCH 5 - PROGRESS: at 57.18% examples, 361651 words/s, in_qsize 8, out_qsize 4
# 2021-05-17 16:10:10,342 : INFO : EPOCH 5 - PROGRESS: at 58.29% examples, 361968 words/s, in_qsize 11, out_qsize 1
# 2021-05-17 16:10:11,346 : INFO : EPOCH 5 - PROGRESS: at 59.37% examples, 362415 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:10:12,421 : INFO : EPOCH 5 - PROGRESS: at 60.40% examples, 362088 words/s, in_qsize 7, out_qsize 4
# 2021-05-17 16:10:13,476 : INFO : EPOCH 5 - PROGRESS: at 61.56% examples, 362712 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:14,478 : INFO : EPOCH 5 - PROGRESS: at 62.53% examples, 362493 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:10:15,498 : INFO : EPOCH 5 - PROGRESS: at 63.59% examples, 362657 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:16,557 : INFO : EPOCH 5 - PROGRESS: at 64.67% examples, 362749 words/s, in_qsize 8, out_qsize 3
# 2021-05-17 16:10:17,574 : INFO : EPOCH 5 - PROGRESS: at 65.75% examples, 363075 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:18,620 : INFO : EPOCH 5 - PROGRESS: at 66.75% examples, 362775 words/s, in_qsize 10, out_qsize 3
# 2021-05-17 16:10:19,640 : INFO : EPOCH 5 - PROGRESS: at 67.86% examples, 363220 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:20,643 : INFO : EPOCH 5 - PROGRESS: at 68.91% examples, 363449 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:21,656 : INFO : EPOCH 5 - PROGRESS: at 70.05% examples, 364054 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:22,661 : INFO : EPOCH 5 - PROGRESS: at 71.08% examples, 364109 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:10:23,685 : INFO : EPOCH 5 - PROGRESS: at 72.08% examples, 363933 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:10:24,725 : INFO : EPOCH 5 - PROGRESS: at 73.21% examples, 364364 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:25,805 : INFO : EPOCH 5 - PROGRESS: at 74.29% examples, 364317 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:26,865 : INFO : EPOCH 5 - PROGRESS: at 75.49% examples, 364906 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:10:27,986 : INFO : EPOCH 5 - PROGRESS: at 76.60% examples, 364788 words/s, in_qsize 8, out_qsize 3
# 2021-05-17 16:10:29,054 : INFO : EPOCH 5 - PROGRESS: at 77.71% examples, 364922 words/s, in_qsize 7, out_qsize 4
# 2021-05-17 16:10:30,093 : INFO : EPOCH 5 - PROGRESS: at 78.79% examples, 365061 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:10:31,106 : INFO : EPOCH 5 - PROGRESS: at 79.95% examples, 365697 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:32,168 : INFO : EPOCH 5 - PROGRESS: at 81.04% examples, 365717 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:33,210 : INFO : EPOCH 5 - PROGRESS: at 82.12% examples, 365827 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:34,249 : INFO : EPOCH 5 - PROGRESS: at 83.17% examples, 365827 words/s, in_qsize 6, out_qsize 5
# 2021-05-17 16:10:35,263 : INFO : EPOCH 5 - PROGRESS: at 84.31% examples, 366300 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:36,291 : INFO : EPOCH 5 - PROGRESS: at 85.45% examples, 366695 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:10:37,303 : INFO : EPOCH 5 - PROGRESS: at 86.50% examples, 366801 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:38,345 : INFO : EPOCH 5 - PROGRESS: at 87.50% examples, 366545 words/s, in_qsize 10, out_qsize 3
# 2021-05-17 16:10:39,375 : INFO : EPOCH 5 - PROGRESS: at 88.55% examples, 366573 words/s, in_qsize 12, out_qsize 4
# 2021-05-17 16:10:40,402 : INFO : EPOCH 5 - PROGRESS: at 89.64% examples, 366723 words/s, in_qsize 12, out_qsize 1
# 2021-05-17 16:10:41,414 : INFO : EPOCH 5 - PROGRESS: at 90.69% examples, 366824 words/s, in_qsize 8, out_qsize 5
# 2021-05-17 16:10:42,435 : INFO : EPOCH 5 - PROGRESS: at 91.77% examples, 366998 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:10:43,446 : INFO : EPOCH 5 - PROGRESS: at 92.91% examples, 367424 words/s, in_qsize 12, out_qsize 0
# 2021-05-17 16:10:44,460 : INFO : EPOCH 5 - PROGRESS: at 93.99% examples, 367613 words/s, in_qsize 12, out_qsize 1
# 2021-05-17 16:10:45,528 : INFO : EPOCH 5 - PROGRESS: at 95.05% examples, 367478 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:10:46,575 : INFO : EPOCH 5 - PROGRESS: at 96.16% examples, 367638 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:47,644 : INFO : EPOCH 5 - PROGRESS: at 97.29% examples, 367817 words/s, in_qsize 11, out_qsize 0
# 2021-05-17 16:10:48,720 : INFO : EPOCH 5 - PROGRESS: at 98.38% examples, 367759 words/s, in_qsize 10, out_qsize 1
# 2021-05-17 16:10:49,780 : INFO : EPOCH 5 - PROGRESS: at 99.49% examples, 367864 words/s, in_qsize 9, out_qsize 2
# 2021-05-17 16:10:50,007 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-05-17 16:10:50,056 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-05-17 16:10:50,100 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-05-17 16:10:50,123 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-05-17 16:10:50,129 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-05-17 16:10:50,144 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-05-17 16:10:50,146 : INFO : EPOCH - 5 : training on 36045600 raw words (36045600 effective words) took 97.8s, 368384 effective words/s
# 2021-05-17 16:10:50,148 : INFO : training on a 180228000 raw words (180228000 effective words) took 501.6s, 359341 effective words/s
# 2021-05-17 16:10:50,149 - Model initialized
# 2021-05-17 16:10:50,149 : INFO : Model initialized
# 2021-05-17 16:10:50,154 - Total time taken: 9.88 minutes
# 2021-05-17 16:10:50,154 : INFO : Total time taken: 9.88 minutes
# 2021-05-17 16:10:50,157 : INFO : saving Word2Vec object under .//gensim-w2v-2021-05-17-1610.model, separately None
# 2021-05-17 16:10:50,160 : INFO : storing np array 'vectors' to .//gensim-w2v-2021-05-17-1610.model.wv.vectors.npy
# 2021-05-17 16:10:50,709 : INFO : not storing attribute vectors_norm
# 2021-05-17 16:10:50,712 : INFO : storing np array 'syn1neg' to .//gensim-w2v-2021-05-17-1610.model.trainables.syn1neg.npy
# 2021-05-17 16:10:51,225 : INFO : not storing attribute cum_table
# 2021-05-17 16:10:52,245 : INFO : saved .//gensim-w2v-2021-05-17-1610.model
# 2021-05-17 16:10:52,247 : INFO : saving Word2VecKeyedVectors object under .//gensim-w2v-2021-05-17-1610.kv, separately None
# 2021-05-17 16:10:52,250 : INFO : storing np array 'vectors' to .//gensim-w2v-2021-05-17-1610.kv.vectors.npy
# 2021-05-17 16:10:52,804 : INFO : not storing attribute vectors_norm
# 2021-05-17 16:10:53,706 : INFO : saved .//gensim-w2v-2021-05-17-1610.kv

# %%
def get_product_id(mapping):
    def func(x):
        return mapping.get(x, -1)
    return func

# %%
from collections import OrderedDict

import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, roc_curve


def plot_auc(label, score, title):
    precision, recall, thresholds = precision_recall_curve(label, score)
    plt.figure(figsize=(15, 5))
    plt.grid()
    plt.plot(thresholds, precision[1:], color='r', label='Precision')
    plt.plot(thresholds, recall[1:], color='b', label='Recall')
    plt.gca().invert_xaxis()
    plt.legend(loc='lower right')

    plt.xlabel('Threshold (0.00 - 1.00)')
    plt.ylabel('Precision / Recall')
    _ = plt.title(title)


def plot_roc(label, score, title):
    fpr, tpr, roc_thresholds = roc_curve(label, score)
    plt.figure(figsize=(5, 5))
    plt.grid()
    plt.plot(fpr, tpr, color='b')

    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    _ = plt.title(title)


def plot_tradeoff(label, score, title):
    precision, recall, thresholds = precision_recall_curve(label, score)
    plt.figure(figsize=(5, 5))
    plt.grid()
    plt.step(recall, precision, color='b', label='Precision-Recall Trade-off')
    plt.fill_between(recall, precision, alpha=0.1, color='b')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    _ = plt.title(title)


def plot_metrics(df, ylim=None):
    plt.figure(figsize=(15, 5))
    plt.grid()
    plt.plot(df.index, df['auc'], label='AUC-ROC', color='black')

    # Plot learning rate resets
    lr_reset_batch = df[df['batches'] == df['batches'].max()]
    for idx in lr_reset_batch.index:
        plt.vlines(idx, df['auc'].min(), 1, label='LR reset (per epoch)',
                   linestyles='--', colors='grey')

    # PLot legend
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = OrderedDict(zip(labels, handles))
    _ = plt.legend(by_label.values(), by_label.keys(), loc='lower right')

    # Tidy axis
    if ylim:
        plt.ylim(ylim)
    else:
        plt.ylim(df['auc'].min() * 1.2, 0.96)
    plt.xlim(0, df.index.max())
    plt.ylabel('AUC-ROC', size=12)
    plt.xlabel('Batches (over 5 epochs)', size=12)
    _ = plt.title('AUC-ROC on sample val set over 5 epochs', size=15)

# %% [markdown]
# https://github.com/eugeneyan/recsys-nlp-graph
