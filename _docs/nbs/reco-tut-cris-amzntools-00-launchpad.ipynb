# %%
import os
project_name = "reco-tut-cris"; branch = "main"; account = "sparsh-ai"
project_path = os.path.join('/content', project_name)

if not os.path.exists(project_path):
    # !cp /content/drive/MyDrive/mykeys.py /content
    import mykeys
    # !rm /content/mykeys.py
    path = "/content/" + project_name; 
    # !mkdir "{path}"
    # %cd "{path}"
    import sys; sys.path.append(path)
    # !git config --global user.email "recotut@recohut.com"
    # !git config --global user.name  "reco-tut"
    # !git init
    # !git remote add origin https://"{mykeys.git_token}":x-oauth-basic@github.com/"{account}"/"{project_name}".git
    # !git pull origin "{branch}"
    # !git checkout main
else:
    # %cd "{project_path}"
# Out:
# /content/reco-tut-cris
# Initialized empty Git repository in /content/reco-tut-cris/.git/
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 55 (delta 12), reused 47 (delta 5), pack-reused 0
# Unpacking objects: 100% (55/55), done.
# From https://github.com/sparsh-ai/reco-tut-cris
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Switched to a new branch 'main'

# %%
import glob
files = sorted(glob.glob('/content/drive/MyDrive/Colab Notebooks/reco-tut-cris*.ipynb'))
files
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/reco-tut-cris-amzntools-00-launchpad.ipynb',
#  '/content/drive/MyDrive/Colab Notebooks/reco-tut-cris-amzntools-01-data-ingestion.ipynb',
#  '/content/drive/MyDrive/Colab Notebooks/reco-tut-cris-amzntools-02-data-wrangling.ipynb',
#  '/content/drive/MyDrive/Colab Notebooks/reco-tut-cris-amzntools-03-eda.ipynb',
#  '/content/drive/MyDrive/Colab Notebooks/reco-tut-cris-amzntools-04-data-preprocessing.ipynb',
#  '/content/drive/MyDrive/Colab Notebooks/reco-tut-cris-amzntools-05-dataloaders.ipynb',
#  '/content/drive/MyDrive/Colab Notebooks/reco-tut-cris-amzntools-06-model-interest-predictor.ipynb',
#  '/content/drive/MyDrive/Colab Notebooks/reco-tut-cris-amzntools-06-model-recommender.ipynb']

# %%
from shutil import copy
for fpath in files[1:]:
    copy(fpath, './notebooks')

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	notebooks/reco-tut-cris-amzntools-01-data-ingestion.ipynb
# 	notebooks/reco-tut-cris-amzntools-02-data-wrangling.ipynb
# 	notebooks/reco-tut-cris-amzntools-03-eda.ipynb
# 	notebooks/reco-tut-cris-amzntools-04-data-preprocessing.ipynb
# 	notebooks/reco-tut-cris-amzntools-05-dataloaders.ipynb
# 	notebooks/reco-tut-cris-amzntools-06-model-interest-predictor.ipynb
# 	notebooks/reco-tut-cris-amzntools-06-model-recommender.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add . && git commit -m 'commit' && git push origin main
# Out:
# [main 5aaa253] commit
#  7 files changed, 7 insertions(+)
#  create mode 100644 notebooks/reco-tut-cris-amzntools-01-data-ingestion.ipynb
#  create mode 100644 notebooks/reco-tut-cris-amzntools-02-data-wrangling.ipynb
#  create mode 100644 notebooks/reco-tut-cris-amzntools-03-eda.ipynb
#  create mode 100644 notebooks/reco-tut-cris-amzntools-04-data-preprocessing.ipynb
#  create mode 100644 notebooks/reco-tut-cris-amzntools-05-dataloaders.ipynb
#  create mode 100644 notebooks/reco-tut-cris-amzntools-06-model-interest-predictor.ipynb
#  create mode 100644 notebooks/reco-tut-cris-amzntools-06-model-recommender.ipynb
# Counting objects: 10, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (10/10), 157.12 KiB | 9.82 MiB/s, done.
# Total 10 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 1 local object.
# To https://github.com/sparsh-ai/reco-tut-cris.git
#    2df5c70..5aaa253  main -> main
