# %% [markdown]
# # Training Factorization Machine (FM) RecSys Model on Dota dataset in PyTorch

# %%
import os
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
from datetime import datetime
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import train_test_split

import warnings, random
warnings.filterwarnings('ignore')

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# GPU not available, CPU used

# %%
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
# !wget -q --show-progress https://github.com/RecoHut-Datasets/dota/raw/v1/dota-heroes-binary.zip
# !unzip dota-heroes-binary.zip
# Out:
# dota-heroes-binary. 100%[===================>]   3.12M  --.-KB/s    in 0.07s
# Archive:  dota-heroes-binary.zip
#   inflating: dota_test_binary_heroes.csv
#   inflating: dota_train_binary_heroes.csv
#   inflating: train_targets.csv

# %%
train_df = pd.read_csv('/content/dota_train_binary_heroes.csv')
test_df = pd.read_csv('/content/dota_test_binary_heroes.csv')
target = pd.read_csv('/content/train_targets.csv')

train_df.set_index('match_id_hash', inplace=True)
test_df.set_index('match_id_hash', inplace=True)
target.set_index('match_id_hash', inplace=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(train_df.values, target['radiant_win'].values, test_size=0.2, random_state=1995)

# %%
class Config:
    learning_rate = 0.01/2
    weight_decay = 0.1/2
    early_stopping_round = 0
    epochs = 30
    seed = 1995
    dim_f = 20
    alpha = 100
    batch_size = 64
    
config = Config()

# %%
class Dataset(Dataset):
    def __init__(self, data, target, train):
        self.data = data
        self.train = train
        
        if train:
            self.target = target
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        if self.train:
            return {
                'x' : torch.tensor(self.data[idx, :], dtype=torch.float).to(device),
                'y' : torch.tensor(self.target[idx], dtype=torch.float).to(device)
            }
        else:
            return {
                'x' : torch.tensor(self.data[idx, :], dtype=torch.float).to(device),
            }

# %%
class FM(nn.Module):
    def __init__(self, input_dim, embed_dim):
        super(FM, self).__init__()
        self.W = nn.Parameter(torch.randn(input_dim, dtype=torch.float))
        self.V = nn.Parameter(torch.randn((input_dim, embed_dim), dtype=torch.float))
        self.bias = nn.Parameter(torch.tensor([1], dtype=torch.float))

    def forward(self, batch_data):
        feature_effect = torch.matmul(batch_data, self.W)
        temp = torch.matmul(batch_data, self.V)**2 - torch.matmul(batch_data**2, self.V**2)
        interaction_effect = torch.sum(temp, axis=1) / 2     

        return self.bias + feature_effect + interaction_effect

# %%
seed_everything(config.seed)

train_dataset = Dataset(x_train, y_train, train=True)
train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True, drop_last=False)

test_dataset = Dataset(x_test, y_test, train=True)
test_loader = DataLoader(test_dataset, batch_size=config.batch_size*100, shuffle=False, drop_last=False)

model = FM(input_dim=train_df.shape[1],
           embed_dim=config.dim_f)
model = model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate, weight_decay=config.weight_decay)
loss_fn = nn.BCEWithLogitsLoss()

start = datetime.now()
history = defaultdict(list)
history['best_loss'] = np.inf

for epoch in range(config.epochs):
    
    model.train()
    losses = 0

    for batch_data in train_loader:
        x = batch_data['x']
        y = batch_data['y']

        optimizer.zero_grad()
        
        pred = model(x)
        loss = loss_fn(pred, y)
        loss.backward()
        optimizer.step()

        losses += loss.item()
    losses /= len(train_loader) 
    history['train_losses'].append(losses)
    
    losses_val = 0

    for bacth_data in test_loader:
        x = batch_data['x']
        y = batch_data['y']

        with torch.no_grad():

            pred = model(x)
            loss = loss_fn(pred, y)
            losses_val += loss.item()
    
    losses_val /= len(test_loader)
    history['val_losses'].append(losses_val)
    print(f'EPOCH {epoch+1} TRAIN LogLoss : {losses:.6f}, TEST LogLoss : {losses_val:.6f}')
    
    if history['best_loss'] > losses_val:
        history['best_loss'] = losses_val
        # torch.save(model.state_dict(), f'../paper_review/4. Deep learning based/FM/FM.pth')
        print('The Model Saving...')
    # if epoch==0 or (epoch + 1) % 10 == 0 or epoch == config.epochs:
    
end = datetime.now()
print(f'Training takes time {end-start}')
# Out:
# EPOCH 1 TRAIN LogLoss : 10.167667, TEST LogLoss : 8.689508
# The Model Saving...
# EPOCH 2 TRAIN LogLoss : 7.552812, TEST LogLoss : 6.222735
# The Model Saving...
# EPOCH 3 TRAIN LogLoss : 5.645339, TEST LogLoss : 5.550408
# The Model Saving...
# EPOCH 4 TRAIN LogLoss : 4.243169, TEST LogLoss : 3.947579
# The Model Saving...
# EPOCH 5 TRAIN LogLoss : 3.223651, TEST LogLoss : 3.005708
# The Model Saving...
# EPOCH 6 TRAIN LogLoss : 2.472993, TEST LogLoss : 2.130956
# The Model Saving...
# EPOCH 7 TRAIN LogLoss : 1.926187, TEST LogLoss : 2.284874
# EPOCH 8 TRAIN LogLoss : 1.538880, TEST LogLoss : 1.407978
# The Model Saving...
# EPOCH 9 TRAIN LogLoss : 1.264784, TEST LogLoss : 0.948185
# The Model Saving...
# EPOCH 10 TRAIN LogLoss : 1.072153, TEST LogLoss : 1.006382
# EPOCH 11 TRAIN LogLoss : 0.939853, TEST LogLoss : 0.805522
# The Model Saving...
# EPOCH 12 TRAIN LogLoss : 0.850821, TEST LogLoss : 0.718277
# The Model Saving...
# EPOCH 13 TRAIN LogLoss : 0.792013, TEST LogLoss : 0.669478
# The Model Saving...
# EPOCH 14 TRAIN LogLoss : 0.753274, TEST LogLoss : 0.726988
# EPOCH 15 TRAIN LogLoss : 0.728542, TEST LogLoss : 0.653163
# The Model Saving...
# EPOCH 16 TRAIN LogLoss : 0.712335, TEST LogLoss : 0.680731
# EPOCH 17 TRAIN LogLoss : 0.702220, TEST LogLoss : 0.688956
# EPOCH 18 TRAIN LogLoss : 0.695543, TEST LogLoss : 0.708612
# EPOCH 19 TRAIN LogLoss : 0.691351, TEST LogLoss : 0.692877
# EPOCH 20 TRAIN LogLoss : 0.688591, TEST LogLoss : 0.684861
# EPOCH 21 TRAIN LogLoss : 0.686822, TEST LogLoss : 0.675217
# EPOCH 22 TRAIN LogLoss : 0.685659, TEST LogLoss : 0.674660
# EPOCH 23 TRAIN LogLoss : 0.684991, TEST LogLoss : 0.684547
# EPOCH 24 TRAIN LogLoss : 0.684510, TEST LogLoss : 0.686645
# EPOCH 25 TRAIN LogLoss : 0.684199, TEST LogLoss : 0.675305
# EPOCH 26 TRAIN LogLoss : 0.684059, TEST LogLoss : 0.672032
# EPOCH 27 TRAIN LogLoss : 0.683907, TEST LogLoss : 0.677141
# EPOCH 28 TRAIN LogLoss : 0.683846, TEST LogLoss : 0.689688
# EPOCH 29 TRAIN LogLoss : 0.683789, TEST LogLoss : 0.670102
# EPOCH 30 TRAIN LogLoss : 0.683789, TEST LogLoss : 0.679676
# Training takes time 0:00:30.463238

# %% [markdown]
# ---

# %%
# !pip install -q watermark
# %reload_ext watermark
# %watermark -a "Sparsh A." -m -iv -u -t -d
# Out:
# Author: Sparsh A.
#
# Last updated: 2021-11-28 12:29:41
#
# Compiler    : GCC 7.5.0
# OS          : Linux
# Release     : 5.4.104+
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 2
# Architecture: 64bit
#
# torch     : 1.10.0+cu111
# IPython   : 5.5.0
# numpy     : 1.19.5
# matplotlib: 3.2.2
# pandas    : 1.1.5

# %% [markdown]
# ---

# %% [markdown]
# **END**
