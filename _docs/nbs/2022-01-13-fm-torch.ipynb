# %% [markdown]
# # Comparing DCN, DeepFM and xDeepFM in PyTorch

# %% [markdown]
# ![](https://github.com/RecoHut-Stanzas/S516304/raw/main/images/process_flow.svg)

# %%
# !mkdir recohut && git clone https://github.com/RecoHut-Stanzas/S516304.git recohut
# %cd recohut
# Out:
# Cloning into 'stanza'...
# remote: Enumerating objects: 1016, done.
# remote: Counting objects: 100% (1016/1016), done.
# remote: Compressing objects: 100% (837/837), done.
# remote: Total 1016 (delta 259), reused 832 (delta 149), pack-reused 0
# Receiving objects: 100% (1016/1016), 185.63 MiB | 24.93 MiB/s, done.
# Resolving deltas: 100% (259/259), done.
# /content/stanza

# %%
import logging
from datetime import datetime
import sys
import os

from recohut.code.pytorch.models import DCN, DeepFM, xDeepFM
from recohut.code.pytorch.utils import seed_everything
from recohut.code.datasets import data_generator
from recohut.code.datasets.taobao import FeatureEncoder
from recohut.code.utils import set_logger, print_to_json

# %%
sys.path.insert(0,'.')

# %% [markdown]
# ## DCN

# %%
if __name__ == '__main__':
    feature_cols = [{'name': ["userid","adgroup_id","pid","cate_id","campaign_id","customer","brand","cms_segid",
                              "cms_group_id","final_gender_code","age_level","pvalue_level","shopping_level","occupation"],
                     'active': True, 'dtype': 'str', 'type': 'categorical'}]
    label_col = {'name': 'clk', 'dtype': float}

    params = {'model_id': 'DCN_demo',
              'dataset_id': 'tiny_data_demo',
              'train_data': './data/tiny_data/train_sample.csv',
              'valid_data': './data/tiny_data/valid_sample.csv',
              'test_data': './data/tiny_data/test_sample.csv',
              'model_root': '../checkpoints/',
              'data_root': './data/',
              'feature_cols': feature_cols,
              'label_col': label_col,
              'embedding_regularizer': 0,
              'net_regularizer': 0,
              'dnn_hidden_units': [64, 64],
              'dnn_activations': "relu",
              'crossing_layers': 3,
              'learning_rate': 1e-3,
              'net_dropout': 0,
              'batch_norm': False,
              'optimizer': 'adam',
              'task': 'binary_classification',
              'loss': 'binary_crossentropy',
              'metrics': ['logloss', 'AUC'],
              'min_categr_count': 1,
              'embedding_dim': 10,
              'batch_size': 64,
              'epochs': 3,
              'shuffle': True,
              'seed': 2019,
              'monitor': 'AUC',
              'monitor_mode': 'max',
              'use_hdf5': True,
              'pickle_feature_encoder': True,
              'save_best_only': True,
              'every_x_epochs': 1,
              'patience': 2,
              'workers': 1,
              'verbose': 0,
              'version': 'pytorch',
              'gpu': -1}

    set_logger(params)
    logging.info('Start the demo...')
    logging.info(print_to_json(params))
    seed_everything(seed=params['seed'])

    feature_encoder = FeatureEncoder(feature_cols, 
                                     label_col, 
                                     dataset_id=params['dataset_id'], 
                                     data_root=params["data_root"],
                                     version=params['version'])
    feature_encoder.fit(train_data=params['train_data'], 
                        min_categr_count=params['min_categr_count'])

    train_gen, valid_gen, test_gen = data_generator(feature_encoder,
                                                    train_data=params['train_data'],
                                                    valid_data=params['valid_data'],
                                                    test_data=params['test_data'],
                                                    batch_size=params['batch_size'],
                                                    shuffle=params['shuffle'],
                                                    use_hdf5=params['use_hdf5'])
    model = DCN(feature_encoder.feature_map, **params)
    model.fit_generator(train_gen, validation_data=valid_gen, epochs=params['epochs'],
                        verbose=params['verbose'])
    model.load_weights(model.checkpoint)
    
    logging.info('***** validation/test results *****')
    model.evaluate_generator(valid_gen)
    model.evaluate_generator(test_gen)
# Out:
# 2021-12-02 16:33:53,369 P322 INFO Start the demo...
# 2021-12-02 16:33:53,371 P322 INFO {
#     "batch_norm": "False",
#     "batch_size": "64",
#     "crossing_layers": "3",
#     "data_root": "./data/",
#     "dataset_id": "tiny_data_demo",
#     "dnn_activations": "relu",
#     "dnn_hidden_units": "[64, 64]",
#     "embedding_dim": "10",
#     "embedding_regularizer": "0",
#     "epochs": "3",
#     "every_x_epochs": "1",
#     "feature_cols": "[{'name': ['userid', 'adgroup_id', 'pid', 'cate_id', 'campaign_id', 'customer', 'brand', 'cms_segid', 'cms_group_id', 'final_gender_code', 'age_level', 'pvalue_level', 'shopping_level', 'occupation'], 'active': True, 'dtype': 'str', 'type': 'categorical'}]",
#     "gpu": "-1",
#     "label_col": "{'name': 'clk', 'dtype': <class 'float'>}",
#     "learning_rate": "0.001",
#     "loss": "binary_crossentropy",
#     "metrics": "['logloss', 'AUC']",
#     "min_categr_count": "1",
#     "model_id": "DCN_demo",
#     "model_root": "../checkpoints/",
#     "monitor": "AUC",
#     "monitor_mode": "max",
#     "net_dropout": "0",
#     "net_regularizer": "0",
#     "optimizer": "adam",
#     "patience": "2",
#     "pickle_feature_encoder": "True",
#     "save_best_only": "True",
#     "seed": "2019",
#     "shuffle": "True",
#     "task": "binary_classification",
#     "test_data": "./data/tiny_data/test_sample.csv",
#     "train_data": "./data/tiny_data/train_sample.csv",
#     "use_hdf5": "True",
#     "valid_data": "./data/tiny_data/valid_sample.csv",
#     "verbose": "0",
#     "version": "pytorch",
#     "workers": "1"
# }
# 2021-12-02 16:33:53,375 P322 INFO Set up feature encoder...
# 2021-12-02 16:33:53,381 P322 INFO Reading file: ./data/tiny_data/train_sample.csv
# 2021-12-02 16:33:53,392 P322 INFO Preprocess feature columns...
# 2021-12-02 16:33:53,413 P322 INFO Fit feature encoder...
# 2021-12-02 16:33:53,414 P322 INFO Processing column: {'name': 'userid', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,417 P322 INFO Processing column: {'name': 'adgroup_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,420 P322 INFO Processing column: {'name': 'pid', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,424 P322 INFO Processing column: {'name': 'cate_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,426 P322 INFO Processing column: {'name': 'campaign_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,429 P322 INFO Processing column: {'name': 'customer', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,432 P322 INFO Processing column: {'name': 'brand', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,435 P322 INFO Processing column: {'name': 'cms_segid', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,437 P322 INFO Processing column: {'name': 'cms_group_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,439 P322 INFO Processing column: {'name': 'final_gender_code', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,442 P322 INFO Processing column: {'name': 'age_level', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,445 P322 INFO Processing column: {'name': 'pvalue_level', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,449 P322 INFO Processing column: {'name': 'shopping_level', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,452 P322 INFO Processing column: {'name': 'occupation', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:33:53,454 P322 INFO Set feature index...
# 2021-12-02 16:33:53,460 P322 INFO Pickle feature_encode: ./data/tiny_data_demo/feature_encoder.pkl
# 2021-12-02 16:33:53,465 P322 INFO Save feature_map to json: ./data/tiny_data_demo/feature_map.json
# 2021-12-02 16:33:53,467 P322 INFO Set feature encoder done.
# 2021-12-02 16:33:53,468 P322 INFO Loading data...
# 2021-12-02 16:33:53,472 P322 INFO Reading file: ./data/tiny_data/train_sample.csv
# 2021-12-02 16:33:53,488 P322 INFO Preprocess feature columns...
# 2021-12-02 16:33:53,509 P322 INFO Transform feature columns...
# 2021-12-02 16:33:53,513 P322 INFO Saving data to h5: ./data/tiny_data_demo/train_sample.h5
# 2021-12-02 16:33:53,519 P322 INFO Reading file: ./data/tiny_data/valid_sample.csv
# 2021-12-02 16:33:53,528 P322 INFO Preprocess feature columns...
# 2021-12-02 16:33:53,538 P322 INFO Transform feature columns...
# 2021-12-02 16:33:53,542 P322 INFO Saving data to h5: ./data/tiny_data_demo/valid_sample.h5
# 2021-12-02 16:33:53,546 P322 INFO Train samples: total/100, pos/4, neg/96, ratio/4.00%
# 2021-12-02 16:33:53,548 P322 INFO Validation samples: total/100, pos/4, neg/96, ratio/4.00%
# 2021-12-02 16:33:53,551 P322 INFO Reading file: ./data/tiny_data/test_sample.csv
# 2021-12-02 16:33:53,561 P322 INFO Preprocess feature columns...
# 2021-12-02 16:33:53,570 P322 INFO Transform feature columns...
# 2021-12-02 16:33:53,576 P322 INFO Saving data to h5: ./data/tiny_data_demo/test_sample.h5
# 2021-12-02 16:33:53,582 P322 INFO Test samples: total/100, pos/4, neg/96, ratio/4.00%
# 2021-12-02 16:33:53,584 P322 INFO Loading data done.
# 2021-12-02 16:33:53,650 P322 INFO Start training: 2 batches/epoch
# 2021-12-02 16:33:53,652 P322 INFO ************ Epoch=1 start ************
# 2021-12-02 16:33:53,942 P322 INFO [Metrics] logloss: 0.650336 - AUC: 1.000000
# 2021-12-02 16:33:53,945 P322 INFO Save best model: monitor(max): 1.000000
# 2021-12-02 16:33:53,951 P322 INFO --- 2/2 batches finished ---
# 2021-12-02 16:33:53,964 P322 INFO Train loss: 0.682738
# 2021-12-02 16:33:53,966 P322 INFO ************ Epoch=1 end ************
# 2021-12-02 16:33:54,054 P322 INFO [Metrics] logloss: 0.607055 - AUC: 1.000000
# 2021-12-02 16:33:54,057 P322 INFO Monitor(max) STOP: 1.000000 !
# 2021-12-02 16:33:54,062 P322 INFO Reduce learning rate on plateau: 0.000100
# 2021-12-02 16:33:54,063 P322 INFO --- 2/2 batches finished ---
# 2021-12-02 16:33:54,082 P322 INFO Train loss: 0.639184
# 2021-12-02 16:33:54,085 P322 INFO ************ Epoch=2 end ************
# 2021-12-02 16:33:54,170 P322 INFO [Metrics] logloss: 0.602700 - AUC: 1.000000
# 2021-12-02 16:33:54,172 P322 INFO Monitor(max) STOP: 1.000000 !
# 2021-12-02 16:33:54,176 P322 INFO Reduce learning rate on plateau: 0.000010
# 2021-12-02 16:33:54,180 P322 INFO Early stopping at epoch=3
# 2021-12-02 16:33:54,182 P322 INFO --- 2/2 batches finished ---
# 2021-12-02 16:33:54,197 P322 INFO Train loss: 0.606670
# 2021-12-02 16:33:54,198 P322 INFO Training finished.
# 2021-12-02 16:33:54,201 P322 INFO Load best model: /content/checkpoints/tiny_data_demo/DCN_demo_model.ckpt
# 2021-12-02 16:33:54,211 P322 INFO ***** validation/test results *****
# 2021-12-02 16:33:54,261 P322 INFO [Metrics] logloss: 0.650336 - AUC: 1.000000
# 2021-12-02 16:33:54,311 P322 INFO [Metrics] logloss: 0.650336 - AUC: 1.000000

# %% [markdown]
# ## DeepFM

# %%
if __name__ == '__main__':
    feature_cols = [{'name': ["userid","adgroup_id","pid","cate_id","campaign_id","customer","brand","cms_segid",
                              "cms_group_id","final_gender_code","age_level","pvalue_level","shopping_level","occupation"],
                     'active': True, 'dtype': 'str', 'type': 'categorical'}]
    label_col = {'name': 'clk', 'dtype': float}

    params = {'model_id': 'DeepFM_demo',
              'dataset_id': 'tiny_data_demo',
              'train_data': './data/tiny_data/train_sample.csv',
              'valid_data': './data/tiny_data/valid_sample.csv',
              'test_data': './data/tiny_data/test_sample.csv',
              'model_root': '../checkpoints/',
              'data_root': './data/',
              'feature_cols': feature_cols,
              'label_col': label_col,
              'embedding_regularizer': 0,
              'net_regularizer': 0,
              'hidden_units': [64, 64],
              'hidden_activations': "relu",
              'learning_rate': 1e-3,
              'net_dropout': 0,
              'batch_norm': False,
              'optimizer': 'adam',
              'task': 'binary_classification',
              'loss': 'binary_crossentropy',
              'metrics': ['logloss', 'AUC'],
              'min_categr_count': 1,
              'embedding_dim': 10,
              'batch_size': 16,
              'epochs': 3,
              'shuffle': True,
              'seed': 2019,
              'monitor': 'AUC',
              'monitor_mode': 'max',
              'use_hdf5': True,
              'pickle_feature_encoder': True,
              'save_best_only': True,
              'every_x_epochs': 1,
              'patience': 2,
              'workers': 1,
              'verbose': 0,
              'version': 'pytorch',
              'gpu': -1}

    set_logger(params)
    logging.info('Start the demo...')
    logging.info(print_to_json(params))
    seed_everything(seed=params['seed'])

    feature_encoder = FeatureEncoder(feature_cols, 
                                     label_col, 
                                     dataset_id=params['dataset_id'], 
                                     data_root=params["data_root"],
                                     version=params['version'])
    feature_encoder.fit(train_data=params['train_data'], 
                        min_categr_count=params['min_categr_count'])

    train_gen, valid_gen, test_gen = data_generator(feature_encoder,
                                                    train_data=params['train_data'],
                                                    valid_data=params['valid_data'],
                                                    test_data=params['test_data'],
                                                    batch_size=params['batch_size'],
                                                    shuffle=params['shuffle'],
                                                    use_hdf5=params['use_hdf5'])
    model = DeepFM(feature_encoder.feature_map, **params)
    model.fit_generator(train_gen, validation_data=valid_gen, epochs=params['epochs'],
                        verbose=params['verbose'])
    model.load_weights(model.checkpoint)
    
    logging.info('***** validation/test results *****')
    model.evaluate_generator(valid_gen)
    model.evaluate_generator(test_gen)
# Out:
# 2021-12-02 16:35:58,268 P322 INFO Start the demo...
# 2021-12-02 16:35:58,270 P322 INFO {
#     "batch_norm": "False",
#     "batch_size": "16",
#     "data_root": "./data/",
#     "dataset_id": "tiny_data_demo",
#     "embedding_dim": "10",
#     "embedding_regularizer": "0",
#     "epochs": "3",
#     "every_x_epochs": "1",
#     "feature_cols": "[{'name': ['userid', 'adgroup_id', 'pid', 'cate_id', 'campaign_id', 'customer', 'brand', 'cms_segid', 'cms_group_id', 'final_gender_code', 'age_level', 'pvalue_level', 'shopping_level', 'occupation'], 'active': True, 'dtype': 'str', 'type': 'categorical'}]",
#     "gpu": "-1",
#     "hidden_activations": "relu",
#     "hidden_units": "[64, 64]",
#     "label_col": "{'name': 'clk', 'dtype': <class 'float'>}",
#     "learning_rate": "0.001",
#     "loss": "binary_crossentropy",
#     "metrics": "['logloss', 'AUC']",
#     "min_categr_count": "1",
#     "model_id": "DeepFM_demo",
#     "model_root": "../checkpoints/",
#     "monitor": "AUC",
#     "monitor_mode": "max",
#     "net_dropout": "0",
#     "net_regularizer": "0",
#     "optimizer": "adam",
#     "patience": "2",
#     "pickle_feature_encoder": "True",
#     "save_best_only": "True",
#     "seed": "2019",
#     "shuffle": "True",
#     "task": "binary_classification",
#     "test_data": "./data/tiny_data/test_sample.csv",
#     "train_data": "./data/tiny_data/train_sample.csv",
#     "use_hdf5": "True",
#     "valid_data": "./data/tiny_data/valid_sample.csv",
#     "verbose": "0",
#     "version": "pytorch",
#     "workers": "1"
# }
# 2021-12-02 16:35:58,274 P322 INFO Set up feature encoder...
# 2021-12-02 16:35:58,277 P322 INFO Reading file: ./data/tiny_data/train_sample.csv
# 2021-12-02 16:35:58,287 P322 INFO Preprocess feature columns...
# 2021-12-02 16:35:58,296 P322 INFO Fit feature encoder...
# 2021-12-02 16:35:58,298 P322 INFO Processing column: {'name': 'userid', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,301 P322 INFO Processing column: {'name': 'adgroup_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,304 P322 INFO Processing column: {'name': 'pid', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,306 P322 INFO Processing column: {'name': 'cate_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,309 P322 INFO Processing column: {'name': 'campaign_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,311 P322 INFO Processing column: {'name': 'customer', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,313 P322 INFO Processing column: {'name': 'brand', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,315 P322 INFO Processing column: {'name': 'cms_segid', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,317 P322 INFO Processing column: {'name': 'cms_group_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,319 P322 INFO Processing column: {'name': 'final_gender_code', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,321 P322 INFO Processing column: {'name': 'age_level', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,322 P322 INFO Processing column: {'name': 'pvalue_level', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,324 P322 INFO Processing column: {'name': 'shopping_level', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,326 P322 INFO Processing column: {'name': 'occupation', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:35:58,327 P322 INFO Set feature index...
# 2021-12-02 16:35:58,329 P322 INFO Pickle feature_encode: ./data/tiny_data_demo/feature_encoder.pkl
# 2021-12-02 16:35:58,331 P322 INFO Save feature_map to json: ./data/tiny_data_demo/feature_map.json
# 2021-12-02 16:35:58,333 P322 INFO Set feature encoder done.
# 2021-12-02 16:35:58,335 P322 INFO Loading data...
# 2021-12-02 16:35:58,336 P322 INFO Loading data from h5: ./data/tiny_data_demo/train_sample.h5
# 2021-12-02 16:35:58,341 P322 INFO Loading data from h5: ./data/tiny_data_demo/valid_sample.h5
# 2021-12-02 16:35:58,344 P322 INFO Train samples: total/100, pos/4, neg/96, ratio/4.00%
# 2021-12-02 16:35:58,346 P322 INFO Validation samples: total/100, pos/4, neg/96, ratio/4.00%
# 2021-12-02 16:35:58,348 P322 INFO Loading data from h5: ./data/tiny_data_demo/test_sample.h5
# 2021-12-02 16:35:58,351 P322 INFO Test samples: total/100, pos/4, neg/96, ratio/4.00%
# 2021-12-02 16:35:58,352 P322 INFO Loading data done.
# 2021-12-02 16:35:58,377 P322 INFO Start training: 7 batches/epoch
# 2021-12-02 16:35:58,379 P322 INFO ************ Epoch=1 start ************
# 2021-12-02 16:35:58,515 P322 INFO [Metrics] logloss: 0.607313 - AUC: 0.981771
# 2021-12-02 16:35:58,520 P322 INFO Save best model: monitor(max): 0.981771
# 2021-12-02 16:35:58,527 P322 INFO --- 7/7 batches finished ---
# 2021-12-02 16:35:58,540 P322 INFO Train loss: 0.662116
# 2021-12-02 16:35:58,542 P322 INFO ************ Epoch=1 end ************
# 2021-12-02 16:35:58,668 P322 INFO [Metrics] logloss: 0.488870 - AUC: 0.994792
# 2021-12-02 16:35:58,672 P322 INFO Save best model: monitor(max): 0.994792
# 2021-12-02 16:35:58,678 P322 INFO --- 7/7 batches finished ---
# 2021-12-02 16:35:58,703 P322 INFO Train loss: 0.558030
# 2021-12-02 16:35:58,704 P322 INFO ************ Epoch=2 end ************
# 2021-12-02 16:35:58,835 P322 INFO [Metrics] logloss: 0.343586 - AUC: 0.994792
# 2021-12-02 16:35:58,838 P322 INFO Monitor(max) STOP: 0.994792 !
# 2021-12-02 16:35:58,843 P322 INFO Reduce learning rate on plateau: 0.000100
# 2021-12-02 16:35:58,846 P322 INFO --- 7/7 batches finished ---
# 2021-12-02 16:35:58,862 P322 INFO Train loss: 0.426792
# 2021-12-02 16:35:58,864 P322 INFO ************ Epoch=3 end ************
# 2021-12-02 16:35:58,868 P322 INFO Training finished.
# 2021-12-02 16:35:58,871 P322 INFO Load best model: /content/checkpoints/tiny_data_demo/DeepFM_demo_model.ckpt
# 2021-12-02 16:35:58,883 P322 INFO ***** validation/test results *****
# 2021-12-02 16:35:58,942 P322 INFO [Metrics] logloss: 0.488870 - AUC: 0.994792
# 2021-12-02 16:35:59,006 P322 INFO [Metrics] logloss: 0.488870 - AUC: 0.994792

# %% [markdown]
# ## xDeepFM

# %%
if __name__ == '__main__':
    feature_cols = [{'name': ["userid","adgroup_id","pid","cate_id","campaign_id","customer","brand","cms_segid",
                              "cms_group_id","final_gender_code","age_level","pvalue_level","shopping_level","occupation"],
                     'active': True, 'dtype': 'str', 'type': 'categorical'}]
    label_col = {'name': 'clk', 'dtype': float}

    params = {'model_id': 'xDeepFM_demo',
              'dataset_id': 'tiny_data_demo',
              'train_data': './data/tiny_data/train_sample.csv',
              'valid_data': './data/tiny_data/valid_sample.csv',
              'test_data': './data/tiny_data/test_sample.csv',
              'model_root': '../checkpoints/',
              'data_root': './data/',
              'feature_cols': feature_cols,
              'label_col': label_col,
              'embedding_regularizer': 0,
              'net_regularizer': 0,
              'dnn_hidden_units': [64, 64],
              'dnn_activations': "relu",
              'learning_rate': 1e-3,
              'net_dropout': 0,
              'cin_layer_units': [16, 16, 16],
              'batch_norm': False,
              'optimizer': 'adam',
              'task': 'binary_classification',
              'loss': 'binary_crossentropy',
              'metrics': ['logloss', 'AUC'],
              'min_categr_count': 1,
              'embedding_dim': 10,
              'batch_size': 16,
              'epochs': 3,
              'shuffle': True,
              'seed': 2019,
              'monitor': 'AUC',
              'monitor_mode': 'max',
              'use_hdf5': True,
              'pickle_feature_encoder': True,
              'save_best_only': True,
              'every_x_epochs': 1,
              'patience': 2,
              'workers': 1,
              'verbose': 0,
              'version': 'pytorch',
              'gpu': -1}

    set_logger(params)
    logging.info('Start the demo...')
    logging.info(print_to_json(params))
    seed_everything(seed=params['seed'])

    feature_encoder = FeatureEncoder(feature_cols, 
                                     label_col, 
                                     dataset_id=params['dataset_id'], 
                                     data_root=params["data_root"],
                                     version=params['version'])
    feature_encoder.fit(train_data=params['train_data'], 
                        min_categr_count=params['min_categr_count'])

    train_gen, valid_gen, test_gen = data_generator(feature_encoder,
                                                    train_data=params['train_data'],
                                                    valid_data=params['valid_data'],
                                                    test_data=params['test_data'],
                                                    batch_size=params['batch_size'],
                                                    shuffle=params['shuffle'],
                                                    use_hdf5=params['use_hdf5'])
    model = xDeepFM(feature_encoder.feature_map, **params)
    model.fit_generator(train_gen, validation_data=valid_gen, epochs=params['epochs'],
                        verbose=params['verbose'])
    model.load_weights(model.checkpoint)
    
    logging.info('***** Train/validation/test results *****')
    model.evaluate_generator(train_gen)
    model.evaluate_generator(valid_gen)
    model.evaluate_generator(test_gen)
# Out:
# 2021-12-02 16:36:53,603 P322 INFO Start the demo...
# 2021-12-02 16:36:53,606 P322 INFO {
#     "batch_norm": "False",
#     "batch_size": "16",
#     "cin_layer_units": "[16, 16, 16]",
#     "data_root": "./data/",
#     "dataset_id": "tiny_data_demo",
#     "dnn_activations": "relu",
#     "dnn_hidden_units": "[64, 64]",
#     "embedding_dim": "10",
#     "embedding_regularizer": "0",
#     "epochs": "3",
#     "every_x_epochs": "1",
#     "feature_cols": "[{'name': ['userid', 'adgroup_id', 'pid', 'cate_id', 'campaign_id', 'customer', 'brand', 'cms_segid', 'cms_group_id', 'final_gender_code', 'age_level', 'pvalue_level', 'shopping_level', 'occupation'], 'active': True, 'dtype': 'str', 'type': 'categorical'}]",
#     "gpu": "-1",
#     "label_col": "{'name': 'clk', 'dtype': <class 'float'>}",
#     "learning_rate": "0.001",
#     "loss": "binary_crossentropy",
#     "metrics": "['logloss', 'AUC']",
#     "min_categr_count": "1",
#     "model_id": "xDeepFM_demo",
#     "model_root": "../checkpoints/",
#     "monitor": "AUC",
#     "monitor_mode": "max",
#     "net_dropout": "0",
#     "net_regularizer": "0",
#     "optimizer": "adam",
#     "patience": "2",
#     "pickle_feature_encoder": "True",
#     "save_best_only": "True",
#     "seed": "2019",
#     "shuffle": "True",
#     "task": "binary_classification",
#     "test_data": "./data/tiny_data/test_sample.csv",
#     "train_data": "./data/tiny_data/train_sample.csv",
#     "use_hdf5": "True",
#     "valid_data": "./data/tiny_data/valid_sample.csv",
#     "verbose": "0",
#     "version": "pytorch",
#     "workers": "1"
# }
# 2021-12-02 16:36:53,609 P322 INFO Set up feature encoder...
# 2021-12-02 16:36:53,611 P322 INFO Reading file: ./data/tiny_data/train_sample.csv
# 2021-12-02 16:36:53,621 P322 INFO Preprocess feature columns...
# 2021-12-02 16:36:53,630 P322 INFO Fit feature encoder...
# 2021-12-02 16:36:53,632 P322 INFO Processing column: {'name': 'userid', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,633 P322 INFO Processing column: {'name': 'adgroup_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,635 P322 INFO Processing column: {'name': 'pid', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,636 P322 INFO Processing column: {'name': 'cate_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,638 P322 INFO Processing column: {'name': 'campaign_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,639 P322 INFO Processing column: {'name': 'customer', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,641 P322 INFO Processing column: {'name': 'brand', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,643 P322 INFO Processing column: {'name': 'cms_segid', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,645 P322 INFO Processing column: {'name': 'cms_group_id', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,646 P322 INFO Processing column: {'name': 'final_gender_code', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,648 P322 INFO Processing column: {'name': 'age_level', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,650 P322 INFO Processing column: {'name': 'pvalue_level', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,651 P322 INFO Processing column: {'name': 'shopping_level', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,653 P322 INFO Processing column: {'name': 'occupation', 'active': True, 'dtype': 'str', 'type': 'categorical'}
# 2021-12-02 16:36:53,655 P322 INFO Set feature index...
# 2021-12-02 16:36:53,657 P322 INFO Pickle feature_encode: ./data/tiny_data_demo/feature_encoder.pkl
# 2021-12-02 16:36:53,659 P322 INFO Save feature_map to json: ./data/tiny_data_demo/feature_map.json
# 2021-12-02 16:36:53,661 P322 INFO Set feature encoder done.
# 2021-12-02 16:36:53,662 P322 INFO Loading data...
# 2021-12-02 16:36:53,664 P322 INFO Loading data from h5: ./data/tiny_data_demo/train_sample.h5
# 2021-12-02 16:36:53,669 P322 INFO Loading data from h5: ./data/tiny_data_demo/valid_sample.h5
# 2021-12-02 16:36:53,673 P322 INFO Train samples: total/100, pos/4, neg/96, ratio/4.00%
# 2021-12-02 16:36:53,674 P322 INFO Validation samples: total/100, pos/4, neg/96, ratio/4.00%
# 2021-12-02 16:36:53,676 P322 INFO Loading data from h5: ./data/tiny_data_demo/test_sample.h5
# 2021-12-02 16:36:53,679 P322 INFO Test samples: total/100, pos/4, neg/96, ratio/4.00%
# 2021-12-02 16:36:53,681 P322 INFO Loading data done.
# 2021-12-02 16:36:53,708 P322 INFO Start training: 7 batches/epoch
# 2021-12-02 16:36:53,715 P322 INFO ************ Epoch=1 start ************
# 2021-12-02 16:36:53,958 P322 INFO [Metrics] logloss: 0.507094 - AUC: 0.914062
# 2021-12-02 16:36:53,962 P322 INFO Save best model: monitor(max): 0.914062
# 2021-12-02 16:36:53,969 P322 INFO --- 7/7 batches finished ---
# 2021-12-02 16:36:53,981 P322 INFO Train loss: 0.707044
# 2021-12-02 16:36:53,983 P322 INFO ************ Epoch=1 end ************
# 2021-12-02 16:36:54,144 P322 INFO [Metrics] logloss: 0.288558 - AUC: 0.940104
# 2021-12-02 16:36:54,147 P322 INFO Save best model: monitor(max): 0.940104
# 2021-12-02 16:36:54,156 P322 INFO --- 7/7 batches finished ---
# 2021-12-02 16:36:54,169 P322 INFO Train loss: 0.430710
# 2021-12-02 16:36:54,171 P322 INFO ************ Epoch=2 end ************
# 2021-12-02 16:36:54,318 P322 INFO [Metrics] logloss: 0.191915 - AUC: 0.971354
# 2021-12-02 16:36:54,325 P322 INFO Save best model: monitor(max): 0.971354
# 2021-12-02 16:36:54,332 P322 INFO --- 7/7 batches finished ---
# 2021-12-02 16:36:54,346 P322 INFO Train loss: 0.283049
# 2021-12-02 16:36:54,349 P322 INFO ************ Epoch=3 end ************
# 2021-12-02 16:36:54,352 P322 INFO Training finished.
# 2021-12-02 16:36:54,355 P322 INFO Load best model: /content/checkpoints/tiny_data_demo/xDeepFM_demo_model.ckpt
# 2021-12-02 16:36:54,365 P322 INFO ***** Train/validation/test results *****
# 2021-12-02 16:36:54,424 P322 INFO [Metrics] logloss: 0.191915 - AUC: 0.971354
# 2021-12-02 16:36:54,488 P322 INFO [Metrics] logloss: 0.191915 - AUC: 0.971354
# 2021-12-02 16:36:54,558 P322 INFO [Metrics] logloss: 0.191915 - AUC: 0.971354

# %% [markdown]
# ---

# %%
# !apt-get -qq install tree

# %%
# !tree -h --du ../checkpoints
# Out:
# ../checkpoints
# └── [321K]  tiny_data_demo
#     ├── [6.7K]  DCN_demo.log
#     ├── [ 83K]  DCN_demo_model.ckpt
#     ├── [6.0K]  DeepFM_demo.log
#     ├── [ 88K]  DeepFM_demo_model.ckpt
#     ├── [6.1K]  xDeepFM_demo.log
#     └── [128K]  xDeepFM_demo_model.ckpt
#
#  325K used in 1 directory, 6 files

# %%
# !pip install -q watermark
# %reload_ext watermark
# %watermark -a "Sparsh A." -m -iv -u -t -d
# Out:
# Author: Sparsh A.
#
# Last updated: 2021-12-02 16:51:41
#
# Compiler    : GCC 7.5.0
# OS          : Linux
# Release     : 5.4.104+
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 2
# Architecture: 64bit
#
# logging: 0.5.1.2
# IPython: 5.5.0
# sys    : 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ---

# %% [markdown]
# **END**
