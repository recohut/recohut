# %% [markdown]
# ## Environment Setup

# %%
project_name = 'daly_nlp'; branch = 'main'; account = 'sparsh-ai'
import os
project_path = os.path.join('/content', branch)
if not os.path.exists(project_path):
    # !apt-get -qq install tree
    # !cp -r /content/drive/MyDrive/git_credentials/. ~
    # !mkdir "{project_path}"
    # %cd "{project_path}"
    # !git init
    # !git remote add origin https://github.com/"{account}"/"{project_name}".git
    # !git pull origin "{branch}"
    # !git checkout -b "{branch}"
else:
    # %cd "{project_path}"
# Out:
# Selecting previously unselected package tree.
# (Reading database ... 155113 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# /content/main
# Initialized empty Git repository in /content/main/.git/
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 228 (delta 109), reused 109 (delta 30), pack-reused 0
# Receiving objects: 100% (228/228), 60.31 MiB | 32.68 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# From https://github.com/sparsh-ai/daly_nlp
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Switched to a new branch 'main'

# %%
# !cd /content/"{branch}" && git add .
# !cd /content/"{branch}" && git commit -m 'commit'
# !cd /content/"{branch}" && git pull --rebase origin "{branch}"
# !cd /content/"{branch}" && git push origin "{branch}"

# %% [markdown]
# ## Code

# %%
import pandas as pd
import requests
from tqdm import tqdm

# %%
url_link = f'https://finance.yahoo.com/screener/unsaved/250a16f6-3cda-4062-8d6a-0d17d2ce4867?count=100&offset={i}'
r = requests.get(url_link,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
read_html_pandas_data = pd.read_html(r.text)
data.append(pd.DataFrame(read_html_pandas_data[0])[['Symbol','Name']])

# %%
data = []

for i in tqdm(range(0,70000,100)):
    try:
        url_link = f'https://finance.yahoo.com/screener/unsaved/250a16f6-3cda-4062-8d6a-0d17d2ce4867?count=100&offset={i}'
        r = requests.get(url_link,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
        read_html_pandas_data = pd.read_html(r.text)
        data.append(pd.DataFrame(read_html_pandas_data[0])[['Symbol','Name']])
    except:
        print(f'Skipped at i={i}')

# %%
len(data)
# Out:
# 100

# %%
pd.concat(data, axis=0).to_excel('./data/processed/yahoo_finance_stocklist.xlsx')

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
pd.read_excel('/content/main/data/processed/yahoo_finance_stocklist.xlsx', index_col=[0])
# Out:
#         Symbol                                 Name
# 0    005935.KS        Samsung Electronics Co., Ltd.
# 1    005930.KS        Samsung Electronics Co., Ltd.
# 2       ADI.BA                 Analog Devices, Inc.
# 3       MDT.BA                        Medtronic plc
# 4       ADP.BA      Automatic Data Processing, Inc.
# ..         ...                                  ...
# 95         GPN                 Global Payments Inc.
# 96  LAOPALA.NS                  La Opala RG Limited
# 97     6213.TW                     ITEQ Corporation
# 98      5202.T  Nippon Sheet Glass Company, Limited
# 99      0IJN.L                   Exelon Corporation
#
# [10000 rows x 2 columns]
