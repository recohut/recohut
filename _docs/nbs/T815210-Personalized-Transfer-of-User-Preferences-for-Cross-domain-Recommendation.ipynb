# %% [markdown]
# # Personalized Transfer of User Preferences for Cross-domain Recommendation

# %% [markdown]
# ## API Run

# %%
# !git clone https://github.com/easezyc/WSDM2022-PTUPCDR.git
# %cd WSDM2022-PTUPCDR
# Out:
# Cloning into 'WSDM2022-PTUPCDR'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 16 (delta 1), reused 16 (delta 1), pack-reused 0
# Unpacking objects: 100% (16/16), done.
# /content/WSDM2022-PTUPCDR

# %%
# !apt-get -qq install tree
# Out:
# Selecting previously unselected package tree.
# (Reading database ... 155062 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !tree .
# Out:
# .
# ├── config.json
# ├── data
# │   ├── mid
# │   │   └── readme.md
# │   └── raw
# │       └── readme.md
# ├── entry.py
# ├── models.py
# ├── preprocessing.py
# ├── readme.md
# ├── run.py
# └── WSDM22_PTUPCDR.pdf
#
# 3 directories, 9 files

# %%
# !gdown --id 1B1eIpDpecongoygrXdFIrgy1qIAabpq7
# !gdown --id 10j3J18W9RdmEtreOq9TyF0ndJGf-USN6
# !gdown --id 1l-EKL0JVZ7vgIxNx3oMmC-vuxQcyHtCz
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1B1eIpDpecongoygrXdFIrgy1qIAabpq7
# To: /content/WSDM2022-PTUPCDR/reviews_Movies_and_TV_5.json.gz
# 100% 709M/709M [00:06<00:00, 112MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=10j3J18W9RdmEtreOq9TyF0ndJGf-USN6
# To: /content/WSDM2022-PTUPCDR/reviews_Books_5.json.gz
# 100% 3.22G/3.22G [01:10<00:00, 109MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1l-EKL0JVZ7vgIxNx3oMmC-vuxQcyHtCz
# To: /content/WSDM2022-PTUPCDR/reviews_CDs_and_Vinyl_5.json.gz
# 100% 491M/491M [00:29<00:00, 16.9MB/s]

# %%
# !mv *.gz data/raw

# %%
# !tree --du -h -C .
# Out:
# .
# ├── [1.1K]  config.json
# ├── [4.1G]  data
# │   ├── [4.1K]  mid
# │   │   └── [ 141]  readme.md
# │   └── [4.1G]  raw
# │       ├── [ 119]  readme.md
# │       ├── [3.0G]  reviews_Books_5.json.gz
# │       ├── [468M]  reviews_CDs_and_Vinyl_5.json.gz
# │       └── [676M]  reviews_Movies_and_TV_5.json.gz
# ├── [1.9K]  entry.py
# ├── [8.5K]  models.py
# ├── [4.0K]  preprocessing.py
# ├── [5.0K]  readme.md
# ├── [ 11K]  run.py
# └── [6.3M]  WSDM22_PTUPCDR.pdf
#
#  4.1G used in 3 directories, 12 files

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !python entry.py --process_data_mid 1 --process_data_ready 1
# Out:
# Parsing Books Mid...
# 8898041it [03:19, 44541.37it/s]
# Books Mid Done.
# Parsing CDs_and_Vinyl Mid...
# 1097592it [00:28, 38886.26it/s]
# CDs_and_Vinyl Mid Done.
# Parsing Movies_and_TV Mid...
# 1697533it [00:42, 39837.03it/s]
# Movies_and_TV Mid Done.
# Source inters: 1697533, uid: 123960, iid: 50052.
# Target inters: 1097592, uid: 75258, iid: 64443.
# All uid: 181187, Co uid: 18031.
# All iid: 114495.
# 100% 18031/18031 [02:26<00:00, 122.96it/s]
# /content/WSDM2022-PTUPCDR/preprocessing.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_meta['pos_seq'] = train_meta['uid'].map(pos_seq_dict)
# /content/WSDM2022-PTUPCDR/preprocessing.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['pos_seq'] = test['uid'].map(pos_seq_dict)
# ./data/ready/_8_2/tgt_CDs_and_Vinyl_src_Movies_and_TV
# Source inters: 8898041, uid: 603668, iid: 367982.
# Target inters: 1697533, uid: 123960, iid: 50052.
# All uid: 690240, Co uid: 37388.
# All iid: 418034.
#  52% 19317/37388 [11:37<09:47, 30.75it/s]

# %%
import os
project_name = "coldstart-recsys"; branch = "main"; account = "sparsh-ai"
project_path = os.path.join('/content', branch)

if not os.path.exists(project_path):
    # !cp -r /content/drive/MyDrive/git_credentials/. ~
    # !mkdir "{project_path}"
    # %cd "{project_path}"
    # !git init
    # !git remote add origin https://github.com/"{account}"/"{project_name}".git
    # !git pull origin "{branch}"
    # !git checkout -b "{branch}"
else:
    # %cd "{project_path}"
